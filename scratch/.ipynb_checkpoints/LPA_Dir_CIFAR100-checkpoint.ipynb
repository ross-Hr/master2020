# %%
"""
Quick example: A small second-order optimizer with BackPACK
on the classic MNIST example from PyTorch,
https://github.com/pytorch/examples/blob/master/mnist/main.py

The optimizer we implement uses a constant damping parameter
and uses the diagonal of the GGN/Fisher matrix as a preconditioner;

```
x_{t+1} = x_t - (G_t + bI)^{-1} g_t
```

- `x_t` are the parameters of the model
- `G_t` is the diagonal of the Gauss-Newton/Fisher matrix at `x_t`
- `b` is a damping parameter
- `g_t` is the gradient

"""

import torch
import numpy as np
import torchvision
# The main BackPACK functionalities
#from backpack import backpack, extend
# The diagonal GGN extension
#from backpack.extensions import DiagGGNMC
# This layer did not exist in Pytorch 1.0
#from backpack.core.layers import Flatten

# Hyperparameters
BATCH_SIZE = 64
STEP_SIZE_TRAIN = 0.00001 #from 0.01
STEP_SIZE_HESS = 0.0001
DAMPING = 1.0
MAX_ITER = 6
torch.manual_seed(0)

def get_accuracy(output, targets):
    """Helper function to print the accuracy"""
    predictions = output.argmax(dim=1, keepdim=True).view_as(targets)
    return predictions.eq(targets).float().mean().item()

# %%
"""
Step 2: Create the optimizer.

After we call the backward pass with backpack,
every parameter will have a `diag_ggn_mc` field
in addition to a `grad` field.

We can use it to compute the search direction for that parameter,
```
step_direction = p.grad / (p.diag_ggn_mc + group["damping"])
```
and update the weights
"""


class DiagGGNOptimizer(torch.optim.Optimizer):
    def __init__(self, parameters, step_size, damping):
        super().__init__(
            parameters, 
            dict(step_size=step_size, damping=damping)
        )

    def step(self):
        for group in self.param_groups:
            for p in group["params"]:
                step_direction = p.grad / (p.diag_ggn_mc + group["damping"])
                p.data.add_(-group["step_size"], step_direction)
        return loss

# %%
def get_second_order_infos(model, data_loader, optimizer, num_classes, batch_size, save_path):
    print("get the second order information for the trained model")

    mus_last_layer_w = []
    mus_last_layer_b = []
    sigmas_last_layer_w = []
    sigmas_last_layer_b = []
    
    extend(model)
    extend(loss_function)


    for hessian_idx, (x,y) in enumerate(data_loader):

        output = model(x)
        max_len = int(np.ceil(len(data_loader.dataset)/batch_size))

        accuracy = get_accuracy(output, y)

        with backpack(DiagGGNMC()):
            loss = loss_function(output, y)
            loss.backward()
            optimizer.step()

        print("{}/{} batches \t acc: {:3f}".format(hessian_idx, max_len, accuracy))
        groups = optimizer.param_groups
        #print("groups: ", groups)
        mus = []
        sigmas = []
        for g in groups:
            for p in g['params']:
                #print("p.size: ", p.size())
                mus.append(p)
                #print("diag size: ", p.diag_ggn_mc.size())
                sigmas.append(p.diag_ggn_mc)


        #print("mus w: ", mus[-2])
        #print("sigma w: ", sigmas[-2])
        mus_last_layer_w.append(mus[-2].detach())
        mus_last_layer_b.append(mus[-1].detach())
        sigmas_last_layer_w.append(sigmas[-2].detach())
        sigmas_last_layer_b.append(sigmas[-1].detach())

        #if hessian_idx >= 10:
        #    break

    print("saving model at: {}".format(save_path))
    torch.save(model.state_dict(), save_path)

    #print(mus_last_layer_w).size()
    mus_w_mean = torch.cat(mus_last_layer_w).view(-1, num_classes, 500).mean(dim=0)
    mus_b_mean = torch.cat(mus_last_layer_b).view(-1, num_classes).mean(dim=0)
    sigmas_w_mean = torch.cat(sigmas_last_layer_w).view(-1, num_classes, 500).mean(dim=0)
    sigmas_b_mean = torch.cat(sigmas_last_layer_b).view(-1, num_classes).mean(dim=0)
    print("mus w mean: ", mus_w_mean.size())
    print("mus b mean: ", mus_b_mean.size())
    print("sigmas w mean: ", sigmas_w_mean.size())
    print("sigmas b mean: ", sigmas_b_mean.size())
    
    return(mus_w_mean, mus_b_mean, sigmas_w_mean, sigmas_b_mean)

# %%
def get_mu_from_Dirichlet(alpha):
    K = len(alpha)
    mu = torch.zeros(K)
    for i in range(K):
        mu_i = torch.log(alpha[i]) - 1/K * torch.sum(torch.log(alpha))
        mu[i] = mu_i
        
    return(torch.Tensor(mu))

def get_Sigma_from_Dirichlet(alpha):
    K = len(alpha)
    sum_of_inv = 1/K * torch.sum(1/alpha)
    Sigma = torch.zeros((K,K))
    for k in range(K):
        for l in range(K):
            delta = 1 if k==l else 0
            Sigma[k][l] = delta * 1/alpha[k] - 1/K*(1/alpha[k] + 1/alpha[l] - sum_of_inv)
            
    return(torch.Tensor(Sigma))


def get_alpha_from_Normal(mu, Sigma):
    alpha = []
    K = len(Sigma[0])
    sum_exp = torch.sum(torch.exp(-1*torch.Tensor(mu)))
    for k in range(K):
        alpha.append(1/Sigma[k][k]*(1 - 2/K + torch.exp(mu[k])/K**2 * sum_exp))
        
    return(torch.Tensor(alpha))

def get_Gaussian_output(x, mu_w, mu_b, sigma_w, sigma_b):
    #get the distributions per class
    n = len(mu_b)
    x = x.view(-1)
    #per_class_mus = []
    per_class_sigmas = []
    for i in range(n):
        #per_class_mus.append(torch.matmul(mu_w[i], x) + mu_b[i])
        #create a diagonal Hessian
        hess = torch.diag(sigma_w[i])
        per_class_sigmas.append(torch.matmul(torch.matmul(x, hess), x) + sigma_b[i])
    
    per_class_mus = torch.matmul(mu_w, x) + mu_b
    mu = torch.tensor(per_class_mus)
    Sigma = torch.diag(torch.tensor(per_class_sigmas))
    #print(mu.size(), Sigma.size())
    return(mu, Sigma)

alpha_test = torch.Tensor([1.3, 1.3])
#print("alpha start: ", alpha_test)
mu_test = get_mu_from_Dirichlet(alpha_test)
#print("mu: ", mu_test)
Sigma_test = get_Sigma_from_Dirichlet(alpha_test)
#print("Sigma: ", Sigma_test)
alpha_end = get_alpha_from_Normal(mu_test, Sigma_test)
#print("alpha end: ", alpha_end)
assert(alpha_test.equal(alpha_end))

# %%
STEP_SIZE_TRAIN_CIFAR100_DN = 1 * 10e-6
BATCH_SIZE_CIFAR100_DN = 128
MAX_ITER_CIFAR100_DN = 70
TEST_BATCH_SIZE_CIFAR100_DN = 1
HESS_BATCH_SIZE_CIFAR100_DN = 128
STEP_SIZE_HESS_CIFAR100_DN = 1 * 10e-8

# %%
transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR100(root='./cifar100', train=True,
                                        download=True, transform=transform)

train_size = int(0.8 * len(trainset))
val_size = len(trainset) - train_size
CIFAR100_train_dataset, CIFAR100_val_dataset = torch.utils.data.random_split(trainset, [train_size, val_size])

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])


CIFAR100_train_loader = torch.utils.data.DataLoader(CIFAR100_train_dataset, batch_size=BATCH_SIZE_CIFAR100_DN,
                                          shuffle=True)

CIFAR100_val_loader = torch.utils.data.DataLoader(CIFAR100_val_dataset, batch_size=BATCH_SIZE_CIFAR100_DN,
                                          shuffle=True)

testset = torchvision.datasets.CIFAR100(root='./cifar100', train=False,
                                       download=True, transform=transform)
CIFAR100_test_loader = torch.utils.data.DataLoader(testset, batch_size=TEST_BATCH_SIZE_CIFAR100_DN,
                                         shuffle=False)

CIFAR100_classes = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# just rip the code of densenet on pytorch
import re
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.checkpoint as cp
from collections import OrderedDict
from torchvision.models.utils import load_state_dict_from_url


__all__ = ['DenseNet', 'densenet121', 'densenet169', 'densenet201', 'densenet161']

model_urls = {
    'densenet121': 'https://download.pytorch.org/models/densenet121-a639ec97.pth',
    'densenet169': 'https://download.pytorch.org/models/densenet169-b2777c0a.pth',
    'densenet201': 'https://download.pytorch.org/models/densenet201-c1103571.pth',
    'densenet161': 'https://download.pytorch.org/models/densenet161-8d451a50.pth',
}


def _bn_function_factory(norm, relu, conv):
    def bn_function(*inputs):
        concated_features = torch.cat(inputs, 1)
        bottleneck_output = conv(relu(norm(concated_features)))
        return bottleneck_output

    return bn_function


class _DenseLayer(nn.Sequential):
    def __init__(self, num_input_features, growth_rate, bn_size, drop_rate, memory_efficient=False):
        super(_DenseLayer, self).__init__()
        self.add_module('norm1', nn.BatchNorm2d(num_input_features)),
        self.add_module('relu1', nn.ReLU(inplace=True)),
        self.add_module('conv1', nn.Conv2d(num_input_features, bn_size *
                                           growth_rate, kernel_size=1, stride=1,
                                           bias=False)),
        self.add_module('norm2', nn.BatchNorm2d(bn_size * growth_rate)),
        self.add_module('relu2', nn.ReLU(inplace=True)),
        self.add_module('conv2', nn.Conv2d(bn_size * growth_rate, growth_rate,
                                           kernel_size=3, stride=1, padding=1,
                                           bias=False)),
        self.drop_rate = drop_rate
        self.memory_efficient = memory_efficient

    def forward(self, *prev_features):
        bn_function = _bn_function_factory(self.norm1, self.relu1, self.conv1)
        if self.memory_efficient and any(prev_feature.requires_grad for prev_feature in prev_features):
            bottleneck_output = cp.checkpoint(bn_function, *prev_features)
        else:
            bottleneck_output = bn_function(*prev_features)
        new_features = self.conv2(self.relu2(self.norm2(bottleneck_output)))
        if self.drop_rate > 0:
            new_features = F.dropout(new_features, p=self.drop_rate,
                                     training=self.training)
        return new_features


class _DenseBlock(nn.Module):
    def __init__(self, num_layers, num_input_features, bn_size, growth_rate, drop_rate, memory_efficient=False):
        super(_DenseBlock, self).__init__()
        for i in range(num_layers):
            layer = _DenseLayer(
                num_input_features + i * growth_rate,
                growth_rate=growth_rate,
                bn_size=bn_size,
                drop_rate=drop_rate,
                memory_efficient=memory_efficient,
            )
            self.add_module('denselayer%d' % (i + 1), layer)

    def forward(self, init_features):
        features = [init_features]
        for name, layer in self.named_children():
            new_features = layer(*features)
            features.append(new_features)
        return torch.cat(features, 1)


class _Transition(nn.Sequential):
    def __init__(self, num_input_features, num_output_features):
        super(_Transition, self).__init__()
        self.add_module('norm', nn.BatchNorm2d(num_input_features))
        self.add_module('relu', nn.ReLU(inplace=True))
        self.add_module('conv', nn.Conv2d(num_input_features, num_output_features,
                                          kernel_size=1, stride=1, bias=False))
        self.add_module('pool', nn.AvgPool2d(kernel_size=2, stride=2))


class DenseNet(nn.Module):
    r"""Densenet-BC model class, based on
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_

    Args:
        growth_rate (int) - how many filters to add each layer (`k` in paper)
        block_config (list of 4 ints) - how many layers in each pooling block
        num_init_features (int) - the number of filters to learn in the first convolution layer
        bn_size (int) - multiplicative factor for number of bottle neck layers
          (i.e. bn_size * k features in the bottleneck layer)
        drop_rate (float) - dropout rate after each dense layer
        num_classes (int) - number of classification classes
        memory_efficient (bool) - If True, uses checkpointing. Much more memory efficient,
          but slower. Default: *False*. See `"paper" <https://arxiv.org/pdf/1707.06990.pdf>`_
    """

    def __init__(self, growth_rate=32, block_config=(6, 12, 24, 16),
                 num_init_features=64, bn_size=4, drop_rate=0, num_classes=1000, memory_efficient=False):

        super(DenseNet, self).__init__()

        # First convolution
        self.features = nn.Sequential(OrderedDict([
            ('conv0', nn.Conv2d(3, num_init_features, kernel_size=7, stride=2,
                                padding=3, bias=False)),
            ('norm0', nn.BatchNorm2d(num_init_features)),
            ('relu0', nn.ReLU(inplace=True)),
            ('pool0', nn.MaxPool2d(kernel_size=3, stride=2, padding=1)),
        ]))

        # Each denseblock
        num_features = num_init_features
        for i, num_layers in enumerate(block_config):
            block = _DenseBlock(
                num_layers=num_layers,
                num_input_features=num_features,
                bn_size=bn_size,
                growth_rate=growth_rate,
                drop_rate=drop_rate,
                memory_efficient=memory_efficient
            )
            self.features.add_module('denseblock%d' % (i + 1), block)
            num_features = num_features + num_layers * growth_rate
            if i != len(block_config) - 1:
                trans = _Transition(num_input_features=num_features,
                                    num_output_features=num_features // 2)
                self.features.add_module('transition%d' % (i + 1), trans)
                num_features = num_features // 2

        # Final batch norm
        self.features.add_module('norm5', nn.BatchNorm2d(num_features))

        # Linear layer
        self.classifier = nn.Linear(num_features, num_classes)

        # Official init from torch repo.
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.constant_(m.bias, 0)

    def forward(self, x, phi=False):  #added phi
        features = self.features(x)
        out = F.relu(features, inplace=True)
        out = F.adaptive_avg_pool2d(out, (1, 1))
        out = torch.flatten(out, 1)
        if phi:              #changed
            return(out)      #changed
        else:               #changed
            out = self.classifier(out)     #changed
            return out            #changed


def _load_state_dict(model, model_url, progress):
    # '.'s are no longer allowed in module names, but previous _DenseLayer
    # has keys 'norm.1', 'relu.1', 'conv.1', 'norm.2', 'relu.2', 'conv.2'.
    # They are also in the checkpoints in model_urls. This pattern is used
    # to find such keys.
    pattern = re.compile(
        r'^(.*denselayer\d+\.(?:norm|relu|conv))\.((?:[12])\.(?:weight|bias|running_mean|running_var))$')

    state_dict = load_state_dict_from_url(model_url, progress=progress)
    for key in list(state_dict.keys()):
        res = pattern.match(key)
        if res:
            new_key = res.group(1) + res.group(2)
            state_dict[new_key] = state_dict[key]
            del state_dict[key]
    model.load_state_dict(state_dict)


def _densenet(arch, growth_rate, block_config, num_init_features, pretrained, progress,
              **kwargs):
    model = DenseNet(growth_rate, block_config, num_init_features, **kwargs)
    if pretrained:
        _load_state_dict(model, model_urls[arch], progress)
    return model


def densenet121(pretrained=False, progress=True, **kwargs):
    r"""Densenet-121 model from
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
        memory_efficient (bool) - If True, uses checkpointing. Much more memory efficient,
          but slower. Default: *False*. See `"paper" <https://arxiv.org/pdf/1707.06990.pdf>`_
    """
    return _densenet('densenet121', 32, (6, 12, 24, 16), 64, pretrained, progress,
                     **kwargs)



def densenet161(pretrained=False, progress=True, **kwargs):
    r"""Densenet-161 model from
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
        memory_efficient (bool) - If True, uses checkpointing. Much more memory efficient,
          but slower. Default: *False*. See `"paper" <https://arxiv.org/pdf/1707.06990.pdf>`_
    """
    return _densenet('densenet161', 48, (6, 12, 36, 24), 96, pretrained, progress,
                     **kwargs)



def densenet169(pretrained=False, progress=True, **kwargs):
    r"""Densenet-169 model from
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
        memory_efficient (bool) - If True, uses checkpointing. Much more memory efficient,
          but slower. Default: *False*. See `"paper" <https://arxiv.org/pdf/1707.06990.pdf>`_
    """
    return _densenet('densenet169', 32, (6, 12, 32, 32), 64, pretrained, progress,
                     **kwargs)



def densenet201(pretrained=False, progress=True, **kwargs):
    r"""Densenet-201 model from
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
        memory_efficient (bool) - If True, uses checkpointing. Much more memory efficient,
          but slower. Default: *False*. See `"paper" <https://arxiv.org/pdf/1707.06990.pdf>`_
    """
    return _densenet('densenet201', 32, (6, 12, 48, 32), 64, pretrained, progress,
                     **kwargs)

# %%
CIFAR100_model_DN = densenet201(pretrained=True).cuda()
loss_function = torch.nn.CrossEntropyLoss()       

#CIFAR100_DN_train_optimizer = torch.optim.Adam(CIFAR100_model_DN.parameters(), lr=STEP_SIZE_TRAIN_CIFAR100_DN)
CIFAR100_DN_train_optimizer = torch.optim.SGD(CIFAR100_model_DN.parameters(), lr=STEP_SIZE_TRAIN_CIFAR100_DN)

# %%
CIFAR100_DN_PATH = "models/CIFAR100_DN_model_SGD.pth"
current_best_mva = 0

for iter in range(MAX_ITER_CIFAR100_DN):
    train_acc = []
    for batch_idx, (x, y) in enumerate(CIFAR100_train_loader):
        x, y = x.cuda(), y.cuda()
        max_len = int(np.ceil(len(CIFAR100_train_loader.dataset)/BATCH_SIZE_CIFAR100_DN))
        output = CIFAR100_model_DN(x, phi=False)

        accuracy = get_accuracy(output, y)
        train_acc.append(accuracy)

        #with backpack(DiagGGNMC()):
        #    loss = loss_function(output, y)
        #    loss.backward()
        #    mnist_optimizer.step()
        
        loss = loss_function(output, y)
        loss.backward()
        CIFAR100_DN_train_optimizer.step()

        print(
            "Iteration {}; {}/{} \t".format(iter, batch_idx, max_len) +
            "Minibatch Loss %.3f  " % (loss) +
            "Accuracy %.0f" % (accuracy * 100) + "%"
        )
        
    val_acc = []
    for batch_idx, (x, y) in enumerate(CIFAR100_val_loader):
        x, y = x.cuda(), y.cuda()
        max_len = int(np.ceil(len(CIFAR100_val_loader.dataset)/BATCH_SIZE_CIFAR100_DN))
        output = CIFAR100_model_DN(x, phi=False)

        accuracy = get_accuracy(output, y)
        val_acc.append(accuracy)
        print("Iteration {}; {}/{} \t".format(iter, batch_idx, max_len) + 
              "Validation accuracy: {:.03f}".format(accuracy))

    mva = np.mean(val_acc)
    mta = np.mean(train_acc)
    print("mean train acc: ", mta)
    print("mean val acc: ", mva)
    
    
    if mva > current_best_mva:
        current_best_mva = mva
        print("saving model at: {}".format(CIFAR100_DN_PATH))
        torch.save(CIFAR100_model_DN.state_dict(), CIFAR100_DN_PATH)
# Out:
# Iteration 0; 0/313 	Minibatch Loss 9.779  Accuracy 0%
# Iteration 0; 1/313 	Minibatch Loss 9.170  Accuracy 0%
# Iteration 0; 2/313 	Minibatch Loss 9.304  Accuracy 0%
# Iteration 0; 3/313 	Minibatch Loss 9.435  Accuracy 0%
# Iteration 0; 4/313 	Minibatch Loss 8.949  Accuracy 0%
# Iteration 0; 5/313 	Minibatch Loss 9.350  Accuracy 0%
# Iteration 0; 6/313 	Minibatch Loss 8.802  Accuracy 0%
# Iteration 0; 7/313 	Minibatch Loss 9.332  Accuracy 1%
# Iteration 0; 8/313 	Minibatch Loss 9.372  Accuracy 0%
# Iteration 0; 9/313 	Minibatch Loss 9.247  Accuracy 0%
# Iteration 0; 10/313 	Minibatch Loss 9.236  Accuracy 0%
# Iteration 0; 11/313 	Minibatch Loss 9.262  Accuracy 0%
# Iteration 0; 12/313 	Minibatch Loss 8.950  Accuracy 0%
# Iteration 0; 13/313 	Minibatch Loss 9.413  Accuracy 0%
# Iteration 0; 14/313 	Minibatch Loss 9.066  Accuracy 0%
# Iteration 0; 15/313 	Minibatch Loss 8.923  Accuracy 0%
# Iteration 0; 16/313 	Minibatch Loss 8.750  Accuracy 1%
# Iteration 0; 17/313 	Minibatch Loss 9.249  Accuracy 0%
# Iteration 0; 18/313 	Minibatch Loss 8.786  Accuracy 0%
# Iteration 0; 19/313 	Minibatch Loss 8.748  Accuracy 0%
# Iteration 0; 20/313 	Minibatch Loss 9.122  Accuracy 0%
# Iteration 0; 21/313 	Minibatch Loss 8.634  Accuracy 0%
# Iteration 0; 22/313 	Minibatch Loss 8.765  Accuracy 0%
# Iteration 0; 23/313 	Minibatch Loss 8.937  Accuracy 0%
# Iteration 0; 24/313 	Minibatch Loss 8.923  Accuracy 1%
# Iteration 0; 25/313 	Minibatch Loss 8.671  Accuracy 0%
# Iteration 0; 26/313 	Minibatch Loss 9.011  Accuracy 0%
# Iteration 0; 27/313 	Minibatch Loss 9.110  Accuracy 0%
# Iteration 0; 28/313 	Minibatch Loss 8.784  Accuracy 0%
# Iteration 0; 29/313 	Minibatch Loss 8.673  Accuracy 0%
# Iteration 0; 30/313 	Minibatch Loss 8.860  Accuracy 0%
# Iteration 0; 31/313 	Minibatch Loss 8.466  Accuracy 1%
# Iteration 0; 32/313 	Minibatch Loss 8.667  Accuracy 1%
# Iteration 0; 33/313 	Minibatch Loss 8.718  Accuracy 0%
# Iteration 0; 34/313 	Minibatch Loss 8.555  Accuracy 0%
# Iteration 0; 35/313 	Minibatch Loss 8.558  Accuracy 0%
# Iteration 0; 36/313 	Minibatch Loss 8.279  Accuracy 0%
# Iteration 0; 37/313 	Minibatch Loss 8.625  Accuracy 0%
# Iteration 0; 38/313 	Minibatch Loss 8.636  Accuracy 0%
# Iteration 0; 39/313 	Minibatch Loss 8.387  Accuracy 0%
# Iteration 0; 40/313 	Minibatch Loss 8.546  Accuracy 0%
# Iteration 0; 41/313 	Minibatch Loss 8.480  Accuracy 0%
# Iteration 0; 42/313 	Minibatch Loss 8.299  Accuracy 0%
# Iteration 0; 43/313 	Minibatch Loss 8.346  Accuracy 0%
# Iteration 0; 44/313 	Minibatch Loss 8.347  Accuracy 0%
# Iteration 0; 45/313 	Minibatch Loss 8.428  Accuracy 0%
# Iteration 0; 46/313 	Minibatch Loss 8.312  Accuracy 0%
# Iteration 0; 47/313 	Minibatch Loss 8.081  Accuracy 0%
# Iteration 0; 48/313 	Minibatch Loss 8.173  Accuracy 0%
# Iteration 0; 49/313 	Minibatch Loss 8.026  Accuracy 0%
# Iteration 0; 50/313 	Minibatch Loss 8.035  Accuracy 0%
# Iteration 0; 51/313 	Minibatch Loss 7.977  Accuracy 0%
# Iteration 0; 52/313 	Minibatch Loss 7.956  Accuracy 0%
# Iteration 0; 53/313 	Minibatch Loss 7.989  Accuracy 0%
# Iteration 0; 54/313 	Minibatch Loss 7.871  Accuracy 0%
# Iteration 0; 55/313 	Minibatch Loss 8.033  Accuracy 0%
# Iteration 0; 56/313 	Minibatch Loss 7.861  Accuracy 0%
# Iteration 0; 57/313 	Minibatch Loss 7.795  Accuracy 0%
# Iteration 0; 58/313 	Minibatch Loss 7.711  Accuracy 0%
# Iteration 0; 59/313 	Minibatch Loss 7.790  Accuracy 0%
# Iteration 0; 60/313 	Minibatch Loss 8.006  Accuracy 0%
# Iteration 0; 61/313 	Minibatch Loss 7.807  Accuracy 0%
# Iteration 0; 62/313 	Minibatch Loss 7.695  Accuracy 0%
# Iteration 0; 63/313 	Minibatch Loss 7.812  Accuracy 0%
# Iteration 0; 64/313 	Minibatch Loss 7.682  Accuracy 0%
# Iteration 0; 65/313 	Minibatch Loss 7.820  Accuracy 0%
# Iteration 0; 66/313 	Minibatch Loss 7.878  Accuracy 0%
# Iteration 0; 67/313 	Minibatch Loss 7.823  Accuracy 0%
# Iteration 0; 68/313 	Minibatch Loss 7.619  Accuracy 0%
# Iteration 0; 69/313 	Minibatch Loss 7.719  Accuracy 0%
# Iteration 0; 70/313 	Minibatch Loss 7.776  Accuracy 0%
# Iteration 0; 71/313 	Minibatch Loss 7.504  Accuracy 0%
# Iteration 0; 72/313 	Minibatch Loss 7.570  Accuracy 0%
# Iteration 0; 73/313 	Minibatch Loss 7.454  Accuracy 1%
# Iteration 0; 74/313 	Minibatch Loss 7.519  Accuracy 1%
# Iteration 0; 75/313 	Minibatch Loss 7.676  Accuracy 0%
# Iteration 0; 76/313 	Minibatch Loss 7.706  Accuracy 0%
# Iteration 0; 77/313 	Minibatch Loss 7.653  Accuracy 0%
# Iteration 0; 78/313 	Minibatch Loss 7.482  Accuracy 0%
# Iteration 0; 79/313 	Minibatch Loss 7.343  Accuracy 0%
# Iteration 0; 80/313 	Minibatch Loss 7.504  Accuracy 0%
# Iteration 0; 81/313 	Minibatch Loss 7.532  Accuracy 0%
# Iteration 0; 82/313 	Minibatch Loss 7.386  Accuracy 0%
# Iteration 0; 83/313 	Minibatch Loss 7.442  Accuracy 0%
# Iteration 0; 84/313 	Minibatch Loss 7.414  Accuracy 0%
# Iteration 0; 85/313 	Minibatch Loss 7.306  Accuracy 0%
# Iteration 0; 86/313 	Minibatch Loss 7.550  Accuracy 1%
# Iteration 0; 87/313 	Minibatch Loss 7.375  Accuracy 0%
# Iteration 0; 88/313 	Minibatch Loss 7.371  Accuracy 0%
# Iteration 0; 89/313 	Minibatch Loss 7.287  Accuracy 0%
# Iteration 0; 90/313 	Minibatch Loss 7.453  Accuracy 0%
# Iteration 0; 91/313 	Minibatch Loss 7.347  Accuracy 0%
# Iteration 0; 92/313 	Minibatch Loss 7.273  Accuracy 0%
# Iteration 0; 93/313 	Minibatch Loss 7.190  Accuracy 1%
# Iteration 0; 94/313 	Minibatch Loss 7.325  Accuracy 0%
# Iteration 0; 95/313 	Minibatch Loss 7.332  Accuracy 0%
# Iteration 0; 96/313 	Minibatch Loss 7.262  Accuracy 0%
# Iteration 0; 97/313 	Minibatch Loss 7.321  Accuracy 0%
# Iteration 0; 98/313 	Minibatch Loss 7.161  Accuracy 0%
# Iteration 0; 99/313 	Minibatch Loss 7.330  Accuracy 1%
# Iteration 0; 100/313 	Minibatch Loss 7.072  Accuracy 1%
# Iteration 0; 101/313 	Minibatch Loss 7.385  Accuracy 0%
# Iteration 0; 102/313 	Minibatch Loss 7.273  Accuracy 1%
# Iteration 0; 103/313 	Minibatch Loss 7.288  Accuracy 0%
# Iteration 0; 104/313 	Minibatch Loss 7.314  Accuracy 0%
# Iteration 0; 105/313 	Minibatch Loss 7.382  Accuracy 0%
# Iteration 0; 106/313 	Minibatch Loss 7.043  Accuracy 0%
# Iteration 0; 107/313 	Minibatch Loss 7.240  Accuracy 0%
# Iteration 0; 108/313 	Minibatch Loss 7.233  Accuracy 0%
# Iteration 0; 109/313 	Minibatch Loss 7.100  Accuracy 0%
# Iteration 0; 110/313 	Minibatch Loss 7.167  Accuracy 0%
# Iteration 0; 111/313 	Minibatch Loss 7.277  Accuracy 0%
# Iteration 0; 112/313 	Minibatch Loss 7.221  Accuracy 0%
# Iteration 0; 113/313 	Minibatch Loss 7.046  Accuracy 1%
# Iteration 0; 114/313 	Minibatch Loss 7.136  Accuracy 0%
# Iteration 0; 115/313 	Minibatch Loss 7.147  Accuracy 1%
# Iteration 0; 116/313 	Minibatch Loss 7.071  Accuracy 0%
# Iteration 0; 117/313 	Minibatch Loss 7.089  Accuracy 0%
# Iteration 0; 118/313 	Minibatch Loss 7.048  Accuracy 0%
# Iteration 0; 119/313 	Minibatch Loss 7.050  Accuracy 0%
# Iteration 0; 120/313 	Minibatch Loss 7.199  Accuracy 0%
# Iteration 0; 121/313 	Minibatch Loss 7.163  Accuracy 0%
# Iteration 0; 122/313 	Minibatch Loss 7.102  Accuracy 0%
# Iteration 0; 123/313 	Minibatch Loss 7.244  Accuracy 1%
# Iteration 0; 124/313 	Minibatch Loss 6.906  Accuracy 0%
# Iteration 0; 125/313 	Minibatch Loss 6.855  Accuracy 1%
# Iteration 0; 126/313 	Minibatch Loss 7.035  Accuracy 0%
# Iteration 0; 127/313 	Minibatch Loss 6.878  Accuracy 1%
# Iteration 0; 128/313 	Minibatch Loss 6.965  Accuracy 0%
# Iteration 0; 129/313 	Minibatch Loss 7.035  Accuracy 0%
# Iteration 0; 130/313 	Minibatch Loss 6.924  Accuracy 0%
# Iteration 0; 131/313 	Minibatch Loss 6.958  Accuracy 1%
# Iteration 0; 132/313 	Minibatch Loss 6.939  Accuracy 0%
# Iteration 0; 133/313 	Minibatch Loss 7.140  Accuracy 0%
# Iteration 0; 134/313 	Minibatch Loss 7.065  Accuracy 0%
# Iteration 0; 135/313 	Minibatch Loss 7.119  Accuracy 0%
# Iteration 0; 136/313 	Minibatch Loss 7.097  Accuracy 0%
# Iteration 0; 137/313 	Minibatch Loss 7.028  Accuracy 0%
# Iteration 0; 138/313 	Minibatch Loss 6.956  Accuracy 1%
# Iteration 0; 139/313 	Minibatch Loss 6.941  Accuracy 2%
# Iteration 0; 140/313 	Minibatch Loss 7.106  Accuracy 1%
# Iteration 0; 141/313 	Minibatch Loss 6.964  Accuracy 0%
# Iteration 0; 142/313 	Minibatch Loss 7.031  Accuracy 1%
# Iteration 0; 143/313 	Minibatch Loss 6.849  Accuracy 1%
# Iteration 0; 144/313 	Minibatch Loss 6.700  Accuracy 0%
# Iteration 0; 145/313 	Minibatch Loss 6.930  Accuracy 0%
# Iteration 0; 146/313 	Minibatch Loss 6.797  Accuracy 1%
# Iteration 0; 147/313 	Minibatch Loss 6.777  Accuracy 1%
# Iteration 0; 148/313 	Minibatch Loss 6.906  Accuracy 2%
# Iteration 0; 149/313 	Minibatch Loss 6.753  Accuracy 2%
# Iteration 0; 150/313 	Minibatch Loss 6.848  Accuracy 0%
# Iteration 0; 151/313 	Minibatch Loss 6.766  Accuracy 2%
# Iteration 0; 152/313 	Minibatch Loss 7.018  Accuracy 1%
# Iteration 0; 153/313 	Minibatch Loss 6.680  Accuracy 2%
# Iteration 0; 154/313 	Minibatch Loss 6.667  Accuracy 2%
# Iteration 0; 155/313 	Minibatch Loss 7.006  Accuracy 2%
# Iteration 0; 156/313 	Minibatch Loss 6.757  Accuracy 1%
# Iteration 0; 157/313 	Minibatch Loss 6.985  Accuracy 0%
# Iteration 0; 158/313 	Minibatch Loss 7.035  Accuracy 0%
# Iteration 0; 159/313 	Minibatch Loss 7.008  Accuracy 0%
# Iteration 0; 160/313 	Minibatch Loss 6.523  Accuracy 2%
# Iteration 0; 161/313 	Minibatch Loss 7.009  Accuracy 2%
# Iteration 0; 162/313 	Minibatch Loss 6.844  Accuracy 0%
# Iteration 0; 163/313 	Minibatch Loss 6.704  Accuracy 2%
# Iteration 0; 164/313 	Minibatch Loss 6.920  Accuracy 0%
# Iteration 0; 165/313 	Minibatch Loss 6.609  Accuracy 2%
# Iteration 0; 166/313 	Minibatch Loss 6.532  Accuracy 2%
# Iteration 0; 167/313 	Minibatch Loss 6.785  Accuracy 2%
# Iteration 0; 168/313 	Minibatch Loss 6.812  Accuracy 0%
# Iteration 0; 169/313 	Minibatch Loss 6.595  Accuracy 2%
# Iteration 0; 170/313 	Minibatch Loss 6.698  Accuracy 0%
# Iteration 0; 171/313 	Minibatch Loss 6.702  Accuracy 1%
# Iteration 0; 172/313 	Minibatch Loss 6.742  Accuracy 1%
# Iteration 0; 173/313 	Minibatch Loss 6.575  Accuracy 3%
# Iteration 0; 174/313 	Minibatch Loss 6.766  Accuracy 2%
# Iteration 0; 175/313 	Minibatch Loss 6.749  Accuracy 0%
# Iteration 0; 176/313 	Minibatch Loss 6.632  Accuracy 2%
# Iteration 0; 177/313 	Minibatch Loss 6.688  Accuracy 2%
# Iteration 0; 178/313 	Minibatch Loss 6.533  Accuracy 4%
# Iteration 0; 179/313 	Minibatch Loss 6.635  Accuracy 2%
# Iteration 0; 180/313 	Minibatch Loss 6.741  Accuracy 2%
# Iteration 0; 181/313 	Minibatch Loss 6.503  Accuracy 2%
# Iteration 0; 182/313 	Minibatch Loss 6.493  Accuracy 2%
# Iteration 0; 183/313 	Minibatch Loss 6.561  Accuracy 1%
# Iteration 0; 184/313 	Minibatch Loss 6.408  Accuracy 4%
# Iteration 0; 185/313 	Minibatch Loss 6.496  Accuracy 2%
# Iteration 0; 186/313 	Minibatch Loss 6.542  Accuracy 2%
# Iteration 0; 187/313 	Minibatch Loss 6.448  Accuracy 3%
# Iteration 0; 188/313 	Minibatch Loss 6.648  Accuracy 2%
# Iteration 0; 189/313 	Minibatch Loss 6.626  Accuracy 2%
# Iteration 0; 190/313 	Minibatch Loss 6.786  Accuracy 2%
# Iteration 0; 191/313 	Minibatch Loss 6.693  Accuracy 1%
# Iteration 0; 192/313 	Minibatch Loss 6.477  Accuracy 1%
# Iteration 0; 193/313 	Minibatch Loss 6.665  Accuracy 1%
# Iteration 0; 194/313 	Minibatch Loss 6.593  Accuracy 1%
# Iteration 0; 195/313 	Minibatch Loss 6.514  Accuracy 2%
# Iteration 0; 196/313 	Minibatch Loss 6.471  Accuracy 3%
# Iteration 0; 197/313 	Minibatch Loss 6.370  Accuracy 4%
# Iteration 0; 198/313 	Minibatch Loss 6.435  Accuracy 3%
# Iteration 0; 199/313 	Minibatch Loss 6.305  Accuracy 2%
# Iteration 0; 200/313 	Minibatch Loss 6.447  Accuracy 5%
# Iteration 0; 201/313 	Minibatch Loss 6.477  Accuracy 3%
# Iteration 0; 202/313 	Minibatch Loss 6.392  Accuracy 5%
# Iteration 0; 203/313 	Minibatch Loss 6.268  Accuracy 2%
# Iteration 0; 204/313 	Minibatch Loss 6.533  Accuracy 3%
# Iteration 0; 205/313 	Minibatch Loss 6.529  Accuracy 3%
# Iteration 0; 206/313 	Minibatch Loss 6.364  Accuracy 2%
# Iteration 0; 207/313 	Minibatch Loss 6.296  Accuracy 1%
# Iteration 0; 208/313 	Minibatch Loss 6.462  Accuracy 5%
# Iteration 0; 209/313 	Minibatch Loss 6.467  Accuracy 2%
# Iteration 0; 210/313 	Minibatch Loss 6.437  Accuracy 1%
# Iteration 0; 211/313 	Minibatch Loss 6.379  Accuracy 2%
# Iteration 0; 212/313 	Minibatch Loss 6.460  Accuracy 5%
# Iteration 0; 213/313 	Minibatch Loss 6.399  Accuracy 5%
# Iteration 0; 214/313 	Minibatch Loss 6.265  Accuracy 0%
# Iteration 0; 215/313 	Minibatch Loss 6.386  Accuracy 1%
# Iteration 0; 216/313 	Minibatch Loss 6.401  Accuracy 4%
# Iteration 0; 217/313 	Minibatch Loss 6.533  Accuracy 2%
# Iteration 0; 218/313 	Minibatch Loss 6.461  Accuracy 4%
# Iteration 0; 219/313 	Minibatch Loss 6.209  Accuracy 5%
# Iteration 0; 220/313 	Minibatch Loss 6.507  Accuracy 3%
# Iteration 0; 221/313 	Minibatch Loss 6.276  Accuracy 5%
# Iteration 0; 222/313 	Minibatch Loss 6.393  Accuracy 2%
# Iteration 0; 223/313 	Minibatch Loss 6.196  Accuracy 3%
# Iteration 0; 224/313 	Minibatch Loss 6.302  Accuracy 5%
# Iteration 0; 225/313 	Minibatch Loss 6.164  Accuracy 2%
# Iteration 0; 226/313 	Minibatch Loss 6.093  Accuracy 3%
# Iteration 0; 227/313 	Minibatch Loss 6.531  Accuracy 2%
# Iteration 0; 228/313 	Minibatch Loss 6.234  Accuracy 3%
# Iteration 0; 229/313 	Minibatch Loss 6.178  Accuracy 2%
# Iteration 0; 230/313 	Minibatch Loss 6.394  Accuracy 2%
# Iteration 0; 231/313 	Minibatch Loss 6.200  Accuracy 3%
# Iteration 0; 232/313 	Minibatch Loss 6.391  Accuracy 3%
# Iteration 0; 233/313 	Minibatch Loss 6.243  Accuracy 3%
# Iteration 0; 234/313 	Minibatch Loss 5.987  Accuracy 5%
# Iteration 0; 235/313 	Minibatch Loss 6.322  Accuracy 2%
# Iteration 0; 236/313 	Minibatch Loss 6.342  Accuracy 5%
# Iteration 0; 237/313 	Minibatch Loss 6.078  Accuracy 6%
# Iteration 0; 238/313 	Minibatch Loss 6.211  Accuracy 3%
# Iteration 0; 239/313 	Minibatch Loss 6.439  Accuracy 2%
# Iteration 0; 240/313 	Minibatch Loss 6.218  Accuracy 2%
# Iteration 0; 241/313 	Minibatch Loss 6.298  Accuracy 3%
# Iteration 0; 242/313 	Minibatch Loss 5.911  Accuracy 9%
# Iteration 0; 243/313 	Minibatch Loss 6.116  Accuracy 5%
# Iteration 0; 244/313 	Minibatch Loss 6.126  Accuracy 2%
# Iteration 0; 245/313 	Minibatch Loss 6.087  Accuracy 2%
# Iteration 0; 246/313 	Minibatch Loss 6.343  Accuracy 1%
# Iteration 0; 247/313 	Minibatch Loss 5.918  Accuracy 3%
# Iteration 0; 248/313 	Minibatch Loss 5.914  Accuracy 5%
# Iteration 0; 249/313 	Minibatch Loss 5.923  Accuracy 7%
# Iteration 0; 250/313 	Minibatch Loss 6.041  Accuracy 2%
# Iteration 0; 251/313 	Minibatch Loss 6.250  Accuracy 4%
# Iteration 0; 252/313 	Minibatch Loss 5.892  Accuracy 5%
# Iteration 0; 253/313 	Minibatch Loss 5.863  Accuracy 4%
# Iteration 0; 254/313 	Minibatch Loss 6.045  Accuracy 4%
# Iteration 0; 255/313 	Minibatch Loss 5.981  Accuracy 5%
# Iteration 0; 256/313 	Minibatch Loss 6.095  Accuracy 4%
# Iteration 0; 257/313 	Minibatch Loss 6.212  Accuracy 3%
# Iteration 0; 258/313 	Minibatch Loss 6.093  Accuracy 5%
# Iteration 0; 259/313 	Minibatch Loss 6.032  Accuracy 4%
# Iteration 0; 260/313 	Minibatch Loss 6.287  Accuracy 3%
# Iteration 0; 261/313 	Minibatch Loss 5.890  Accuracy 5%
# Iteration 0; 262/313 	Minibatch Loss 5.840  Accuracy 5%
# Iteration 0; 263/313 	Minibatch Loss 6.017  Accuracy 5%
# Iteration 0; 264/313 	Minibatch Loss 5.755  Accuracy 6%
# Iteration 0; 265/313 	Minibatch Loss 5.994  Accuracy 5%
# Iteration 0; 266/313 	Minibatch Loss 6.219  Accuracy 2%
# Iteration 0; 267/313 	Minibatch Loss 5.955  Accuracy 2%
# Iteration 0; 268/313 	Minibatch Loss 6.085  Accuracy 2%
# Iteration 0; 269/313 	Minibatch Loss 6.060  Accuracy 5%
# Iteration 0; 270/313 	Minibatch Loss 5.844  Accuracy 4%
# Iteration 0; 271/313 	Minibatch Loss 5.714  Accuracy 9%
# Iteration 0; 272/313 	Minibatch Loss 5.511  Accuracy 9%
# Iteration 0; 273/313 	Minibatch Loss 6.245  Accuracy 0%
# Iteration 0; 274/313 	Minibatch Loss 6.382  Accuracy 2%
# Iteration 0; 275/313 	Minibatch Loss 6.095  Accuracy 4%
# Iteration 0; 276/313 	Minibatch Loss 6.277  Accuracy 2%
# Iteration 0; 277/313 	Minibatch Loss 5.898  Accuracy 6%
# Iteration 0; 278/313 	Minibatch Loss 5.929  Accuracy 6%
# Iteration 0; 279/313 	Minibatch Loss 5.831  Accuracy 5%
# Iteration 0; 280/313 	Minibatch Loss 5.835  Accuracy 2%
# Iteration 0; 281/313 	Minibatch Loss 5.770  Accuracy 5%
# Iteration 0; 282/313 	Minibatch Loss 5.875  Accuracy 3%
# Iteration 0; 283/313 	Minibatch Loss 5.767  Accuracy 5%
# Iteration 0; 284/313 	Minibatch Loss 5.928  Accuracy 4%
# Iteration 0; 285/313 	Minibatch Loss 6.036  Accuracy 8%
# Iteration 0; 286/313 	Minibatch Loss 5.678  Accuracy 3%
# Iteration 0; 287/313 	Minibatch Loss 5.668  Accuracy 5%
# Iteration 0; 288/313 	Minibatch Loss 6.223  Accuracy 2%
# Iteration 0; 289/313 	Minibatch Loss 6.095  Accuracy 3%
# Iteration 0; 290/313 	Minibatch Loss 5.832  Accuracy 4%
# Iteration 0; 291/313 	Minibatch Loss 5.547  Accuracy 5%
# Iteration 0; 292/313 	Minibatch Loss 5.733  Accuracy 7%
# Iteration 0; 293/313 	Minibatch Loss 5.651  Accuracy 4%
# Iteration 0; 294/313 	Minibatch Loss 5.909  Accuracy 5%
# Iteration 0; 295/313 	Minibatch Loss 5.455  Accuracy 6%
# Iteration 0; 296/313 	Minibatch Loss 5.832  Accuracy 6%
# Iteration 0; 297/313 	Minibatch Loss 5.494  Accuracy 3%
# Iteration 0; 298/313 	Minibatch Loss 5.620  Accuracy 8%
# Iteration 0; 299/313 	Minibatch Loss 5.555  Accuracy 5%
# Iteration 0; 300/313 	Minibatch Loss 5.942  Accuracy 5%
# Iteration 0; 301/313 	Minibatch Loss 5.659  Accuracy 6%
# Iteration 0; 302/313 	Minibatch Loss 5.688  Accuracy 5%
# Iteration 0; 303/313 	Minibatch Loss 5.650  Accuracy 5%
# Iteration 0; 304/313 	Minibatch Loss 6.069  Accuracy 2%
# Iteration 0; 305/313 	Minibatch Loss 5.692  Accuracy 4%
# Iteration 0; 306/313 	Minibatch Loss 5.712  Accuracy 4%
# Iteration 0; 307/313 	Minibatch Loss 5.519  Accuracy 5%
# Iteration 0; 308/313 	Minibatch Loss 5.811  Accuracy 5%
# Iteration 0; 309/313 	Minibatch Loss 5.581  Accuracy 3%
# Iteration 0; 310/313 	Minibatch Loss 5.587  Accuracy 8%
# Iteration 0; 311/313 	Minibatch Loss 5.790  Accuracy 2%
# Iteration 0; 312/313 	Minibatch Loss 6.303  Accuracy 5%
# Iteration 0; 0/79 	Validation accuracy: 0.039
# Iteration 0; 1/79 	Validation accuracy: 0.047
# Iteration 0; 2/79 	Validation accuracy: 0.047
# Iteration 0; 3/79 	Validation accuracy: 0.055
# Iteration 0; 4/79 	Validation accuracy: 0.039
# Iteration 0; 5/79 	Validation accuracy: 0.062
# Iteration 0; 6/79 	Validation accuracy: 0.062
# Iteration 0; 7/79 	Validation accuracy: 0.078
# Iteration 0; 8/79 	Validation accuracy: 0.023
# Iteration 0; 9/79 	Validation accuracy: 0.047
# Iteration 0; 10/79 	Validation accuracy: 0.023
# Iteration 0; 11/79 	Validation accuracy: 0.031
# Iteration 0; 12/79 	Validation accuracy: 0.055
# Iteration 0; 13/79 	Validation accuracy: 0.055
# Iteration 0; 14/79 	Validation accuracy: 0.031
# Iteration 0; 15/79 	Validation accuracy: 0.086
# Iteration 0; 16/79 	Validation accuracy: 0.031
# Iteration 0; 17/79 	Validation accuracy: 0.055
# Iteration 0; 18/79 	Validation accuracy: 0.047
# Iteration 0; 19/79 	Validation accuracy: 0.047
# Iteration 0; 20/79 	Validation accuracy: 0.023
# Iteration 0; 21/79 	Validation accuracy: 0.047
# Iteration 0; 22/79 	Validation accuracy: 0.031
# Iteration 0; 23/79 	Validation accuracy: 0.047
# Iteration 0; 24/79 	Validation accuracy: 0.047
# Iteration 0; 25/79 	Validation accuracy: 0.062
# Iteration 0; 26/79 	Validation accuracy: 0.023
# Iteration 0; 27/79 	Validation accuracy: 0.055
# Iteration 0; 28/79 	Validation accuracy: 0.047
# Iteration 0; 29/79 	Validation accuracy: 0.039
# Iteration 0; 30/79 	Validation accuracy: 0.086
# Iteration 0; 31/79 	Validation accuracy: 0.062
# Iteration 0; 32/79 	Validation accuracy: 0.031
# Iteration 0; 33/79 	Validation accuracy: 0.094
# Iteration 0; 34/79 	Validation accuracy: 0.055
# Iteration 0; 35/79 	Validation accuracy: 0.055
# Iteration 0; 36/79 	Validation accuracy: 0.062
# Iteration 0; 37/79 	Validation accuracy: 0.031
# Iteration 0; 38/79 	Validation accuracy: 0.055
# Iteration 0; 39/79 	Validation accuracy: 0.039
# Iteration 0; 40/79 	Validation accuracy: 0.062
# Iteration 0; 41/79 	Validation accuracy: 0.039
# Iteration 0; 42/79 	Validation accuracy: 0.047
# Iteration 0; 43/79 	Validation accuracy: 0.086
# Iteration 0; 44/79 	Validation accuracy: 0.078
# Iteration 0; 45/79 	Validation accuracy: 0.023
# Iteration 0; 46/79 	Validation accuracy: 0.031
# Iteration 0; 47/79 	Validation accuracy: 0.023
# Iteration 0; 48/79 	Validation accuracy: 0.023
# Iteration 0; 49/79 	Validation accuracy: 0.000
# Iteration 0; 50/79 	Validation accuracy: 0.016
# Iteration 0; 51/79 	Validation accuracy: 0.039
# Iteration 0; 52/79 	Validation accuracy: 0.023
# Iteration 0; 53/79 	Validation accuracy: 0.023
# Iteration 0; 54/79 	Validation accuracy: 0.047
# Iteration 0; 55/79 	Validation accuracy: 0.047
# Iteration 0; 56/79 	Validation accuracy: 0.086
# Iteration 0; 57/79 	Validation accuracy: 0.023
# Iteration 0; 58/79 	Validation accuracy: 0.031
# Iteration 0; 59/79 	Validation accuracy: 0.055
# Iteration 0; 60/79 	Validation accuracy: 0.039
# Iteration 0; 61/79 	Validation accuracy: 0.039
# Iteration 0; 62/79 	Validation accuracy: 0.039
# Iteration 0; 63/79 	Validation accuracy: 0.062
# Iteration 0; 64/79 	Validation accuracy: 0.008
# Iteration 0; 65/79 	Validation accuracy: 0.047
# Iteration 0; 66/79 	Validation accuracy: 0.031
# Iteration 0; 67/79 	Validation accuracy: 0.031
# Iteration 0; 68/79 	Validation accuracy: 0.016
# Iteration 0; 69/79 	Validation accuracy: 0.031
# Iteration 0; 70/79 	Validation accuracy: 0.008
# Iteration 0; 71/79 	Validation accuracy: 0.031
# Iteration 0; 72/79 	Validation accuracy: 0.078
# Iteration 0; 73/79 	Validation accuracy: 0.062
# Iteration 0; 74/79 	Validation accuracy: 0.039
# Iteration 0; 75/79 	Validation accuracy: 0.023
# Iteration 0; 76/79 	Validation accuracy: 0.039
# Iteration 0; 77/79 	Validation accuracy: 0.047
# Iteration 0; 78/79 	Validation accuracy: 0.000
# mean train acc:  0.017347244408945688
# mean val acc:  0.04341376582278481
# saving model at: models/CIFAR100_DN_model_SGD.pth
# Iteration 1; 0/313 	Minibatch Loss 5.562  Accuracy 5%
# Iteration 1; 1/313 	Minibatch Loss 6.127  Accuracy 4%
# Iteration 1; 2/313 	Minibatch Loss 5.752  Accuracy 5%
# Iteration 1; 3/313 	Minibatch Loss 5.479  Accuracy 6%
# Iteration 1; 4/313 	Minibatch Loss 5.682  Accuracy 3%
# Iteration 1; 5/313 	Minibatch Loss 5.912  Accuracy 6%
# Iteration 1; 6/313 	Minibatch Loss 5.794  Accuracy 3%
# Iteration 1; 7/313 	Minibatch Loss 6.050  Accuracy 5%
# Iteration 1; 8/313 	Minibatch Loss 5.448  Accuracy 5%
# Iteration 1; 9/313 	Minibatch Loss 5.604  Accuracy 9%
# Iteration 1; 10/313 	Minibatch Loss 5.454  Accuracy 5%
# Iteration 1; 11/313 	Minibatch Loss 5.488  Accuracy 5%
# Iteration 1; 12/313 	Minibatch Loss 5.772  Accuracy 3%
# Iteration 1; 13/313 	Minibatch Loss 5.880  Accuracy 1%
# Iteration 1; 14/313 	Minibatch Loss 5.492  Accuracy 6%
# Iteration 1; 15/313 	Minibatch Loss 5.454  Accuracy 5%
# Iteration 1; 16/313 	Minibatch Loss 5.420  Accuracy 6%
# Iteration 1; 17/313 	Minibatch Loss 5.863  Accuracy 5%
# Iteration 1; 18/313 	Minibatch Loss 5.538  Accuracy 5%
# Iteration 1; 19/313 	Minibatch Loss 5.818  Accuracy 7%
# Iteration 1; 20/313 	Minibatch Loss 5.896  Accuracy 5%
# Iteration 1; 21/313 	Minibatch Loss 5.431  Accuracy 2%
# Iteration 1; 22/313 	Minibatch Loss 5.384  Accuracy 3%
# Iteration 1; 23/313 	Minibatch Loss 5.278  Accuracy 5%
# Iteration 1; 24/313 	Minibatch Loss 5.190  Accuracy 9%
# Iteration 1; 25/313 	Minibatch Loss 5.634  Accuracy 3%
# Iteration 1; 26/313 	Minibatch Loss 5.388  Accuracy 5%
# Iteration 1; 27/313 	Minibatch Loss 5.378  Accuracy 5%
# Iteration 1; 28/313 	Minibatch Loss 5.327  Accuracy 3%
# Iteration 1; 29/313 	Minibatch Loss 5.448  Accuracy 5%
# Iteration 1; 30/313 	Minibatch Loss 5.553  Accuracy 5%
# Iteration 1; 31/313 	Minibatch Loss 5.771  Accuracy 7%
# Iteration 1; 32/313 	Minibatch Loss 5.338  Accuracy 6%
# Iteration 1; 33/313 	Minibatch Loss 5.200  Accuracy 8%
# Iteration 1; 34/313 	Minibatch Loss 5.368  Accuracy 7%
# Iteration 1; 35/313 	Minibatch Loss 5.201  Accuracy 8%
# Iteration 1; 36/313 	Minibatch Loss 5.279  Accuracy 5%
# Iteration 1; 37/313 	Minibatch Loss 5.335  Accuracy 5%
# Iteration 1; 38/313 	Minibatch Loss 5.396  Accuracy 7%
# Iteration 1; 39/313 	Minibatch Loss 5.543  Accuracy 1%
# Iteration 1; 40/313 	Minibatch Loss 5.717  Accuracy 6%
# Iteration 1; 41/313 	Minibatch Loss 5.430  Accuracy 5%
# Iteration 1; 42/313 	Minibatch Loss 5.417  Accuracy 4%
# Iteration 1; 43/313 	Minibatch Loss 5.463  Accuracy 3%
# Iteration 1; 44/313 	Minibatch Loss 5.367  Accuracy 6%
# Iteration 1; 45/313 	Minibatch Loss 5.438  Accuracy 5%
# Iteration 1; 46/313 	Minibatch Loss 5.735  Accuracy 5%
# Iteration 1; 47/313 	Minibatch Loss 5.270  Accuracy 4%
# Iteration 1; 48/313 	Minibatch Loss 5.414  Accuracy 2%
# Iteration 1; 49/313 	Minibatch Loss 5.206  Accuracy 5%
# Iteration 1; 50/313 	Minibatch Loss 5.390  Accuracy 5%
# Iteration 1; 51/313 	Minibatch Loss 5.642  Accuracy 9%
# Iteration 1; 52/313 	Minibatch Loss 5.487  Accuracy 6%
# Iteration 1; 53/313 	Minibatch Loss 5.770  Accuracy 3%
# Iteration 1; 54/313 	Minibatch Loss 5.377  Accuracy 6%
# Iteration 1; 55/313 	Minibatch Loss 5.386  Accuracy 5%
# Iteration 1; 56/313 	Minibatch Loss 5.561  Accuracy 5%
# Iteration 1; 57/313 	Minibatch Loss 5.365  Accuracy 5%
# Iteration 1; 58/313 	Minibatch Loss 5.129  Accuracy 7%
# Iteration 1; 59/313 	Minibatch Loss 6.016  Accuracy 2%
# Iteration 1; 60/313 	Minibatch Loss 5.220  Accuracy 5%
# Iteration 1; 61/313 	Minibatch Loss 5.074  Accuracy 5%
# Iteration 1; 62/313 	Minibatch Loss 5.352  Accuracy 5%
# Iteration 1; 63/313 	Minibatch Loss 5.153  Accuracy 5%
# Iteration 1; 64/313 	Minibatch Loss 4.984  Accuracy 9%
# Iteration 1; 65/313 	Minibatch Loss 5.179  Accuracy 5%
# Iteration 1; 66/313 	Minibatch Loss 5.094  Accuracy 3%
# Iteration 1; 67/313 	Minibatch Loss 5.164  Accuracy 5%
# Iteration 1; 68/313 	Minibatch Loss 5.202  Accuracy 7%
# Iteration 1; 69/313 	Minibatch Loss 5.265  Accuracy 2%
# Iteration 1; 70/313 	Minibatch Loss 5.119  Accuracy 5%
# Iteration 1; 71/313 	Minibatch Loss 5.152  Accuracy 6%
# Iteration 1; 72/313 	Minibatch Loss 5.169  Accuracy 5%
# Iteration 1; 73/313 	Minibatch Loss 5.362  Accuracy 6%
# Iteration 1; 74/313 	Minibatch Loss 5.011  Accuracy 9%
# Iteration 1; 75/313 	Minibatch Loss 5.177  Accuracy 6%
# Iteration 1; 76/313 	Minibatch Loss 5.526  Accuracy 5%
# Iteration 1; 77/313 	Minibatch Loss 4.727  Accuracy 9%
# Iteration 1; 78/313 	Minibatch Loss 5.106  Accuracy 6%
# Iteration 1; 79/313 	Minibatch Loss 5.095  Accuracy 2%
# Iteration 1; 80/313 	Minibatch Loss 4.785  Accuracy 9%
# Iteration 1; 81/313 	Minibatch Loss 5.180  Accuracy 8%
# Iteration 1; 82/313 	Minibatch Loss 5.055  Accuracy 3%
# Iteration 1; 83/313 	Minibatch Loss 5.256  Accuracy 6%
# Iteration 1; 84/313 	Minibatch Loss 5.016  Accuracy 9%
# Iteration 1; 85/313 	Minibatch Loss 5.067  Accuracy 5%
# Iteration 1; 86/313 	Minibatch Loss 5.734  Accuracy 5%
# Iteration 1; 87/313 	Minibatch Loss 5.011  Accuracy 11%
# Iteration 1; 88/313 	Minibatch Loss 5.480  Accuracy 3%
# Iteration 1; 89/313 	Minibatch Loss 5.089  Accuracy 5%
# Iteration 1; 90/313 	Minibatch Loss 4.858  Accuracy 9%
# Iteration 1; 91/313 	Minibatch Loss 5.416  Accuracy 5%
# Iteration 1; 92/313 	Minibatch Loss 5.068  Accuracy 6%
# Iteration 1; 93/313 	Minibatch Loss 5.185  Accuracy 8%
# Iteration 1; 94/313 	Minibatch Loss 5.456  Accuracy 5%
# Iteration 1; 95/313 	Minibatch Loss 4.964  Accuracy 10%
# Iteration 1; 96/313 	Minibatch Loss 5.385  Accuracy 5%
# Iteration 1; 97/313 	Minibatch Loss 4.864  Accuracy 9%
# Iteration 1; 98/313 	Minibatch Loss 5.121  Accuracy 3%
# Iteration 1; 99/313 	Minibatch Loss 5.152  Accuracy 8%
# Iteration 1; 100/313 	Minibatch Loss 5.143  Accuracy 5%
# Iteration 1; 101/313 	Minibatch Loss 5.516  Accuracy 4%
# Iteration 1; 102/313 	Minibatch Loss 4.928  Accuracy 11%
# Iteration 1; 103/313 	Minibatch Loss 5.179  Accuracy 6%
# Iteration 1; 104/313 	Minibatch Loss 5.211  Accuracy 4%
# Iteration 1; 105/313 	Minibatch Loss 4.921  Accuracy 5%
# Iteration 1; 106/313 	Minibatch Loss 5.222  Accuracy 5%
# Iteration 1; 107/313 	Minibatch Loss 5.167  Accuracy 3%
# Iteration 1; 108/313 	Minibatch Loss 4.978  Accuracy 5%
# Iteration 1; 109/313 	Minibatch Loss 4.934  Accuracy 5%
# Iteration 1; 110/313 	Minibatch Loss 4.783  Accuracy 7%
# Iteration 1; 111/313 	Minibatch Loss 5.454  Accuracy 4%
# Iteration 1; 112/313 	Minibatch Loss 5.097  Accuracy 4%
# Iteration 1; 113/313 	Minibatch Loss 4.792  Accuracy 6%
# Iteration 1; 114/313 	Minibatch Loss 4.773  Accuracy 7%
# Iteration 1; 115/313 	Minibatch Loss 5.050  Accuracy 7%
# Iteration 1; 116/313 	Minibatch Loss 5.148  Accuracy 7%
# Iteration 1; 117/313 	Minibatch Loss 4.958  Accuracy 5%
# Iteration 1; 118/313 	Minibatch Loss 4.958  Accuracy 4%
# Iteration 1; 119/313 	Minibatch Loss 5.006  Accuracy 4%
# Iteration 1; 120/313 	Minibatch Loss 5.194  Accuracy 4%
# Iteration 1; 121/313 	Minibatch Loss 4.930  Accuracy 3%
# Iteration 1; 122/313 	Minibatch Loss 4.885  Accuracy 7%
# Iteration 1; 123/313 	Minibatch Loss 5.186  Accuracy 3%
# Iteration 1; 124/313 	Minibatch Loss 5.139  Accuracy 4%
# Iteration 1; 125/313 	Minibatch Loss 5.221  Accuracy 8%
# Iteration 1; 126/313 	Minibatch Loss 5.030  Accuracy 9%
# Iteration 1; 127/313 	Minibatch Loss 5.113  Accuracy 5%
# Iteration 1; 128/313 	Minibatch Loss 5.187  Accuracy 6%
# Iteration 1; 129/313 	Minibatch Loss 4.630  Accuracy 13%
# Iteration 1; 130/313 	Minibatch Loss 5.022  Accuracy 7%
# Iteration 1; 131/313 	Minibatch Loss 4.800  Accuracy 7%
# Iteration 1; 132/313 	Minibatch Loss 5.012  Accuracy 6%
# Iteration 1; 133/313 	Minibatch Loss 4.924  Accuracy 2%
# Iteration 1; 134/313 	Minibatch Loss 5.058  Accuracy 5%
# Iteration 1; 135/313 	Minibatch Loss 5.276  Accuracy 5%
# Iteration 1; 136/313 	Minibatch Loss 4.869  Accuracy 4%
# Iteration 1; 137/313 	Minibatch Loss 5.274  Accuracy 9%
# Iteration 1; 138/313 	Minibatch Loss 4.713  Accuracy 9%
# Iteration 1; 139/313 	Minibatch Loss 5.722  Accuracy 6%
# Iteration 1; 140/313 	Minibatch Loss 4.985  Accuracy 6%
# Iteration 1; 141/313 	Minibatch Loss 5.345  Accuracy 3%
# Iteration 1; 142/313 	Minibatch Loss 4.872  Accuracy 6%
# Iteration 1; 143/313 	Minibatch Loss 5.356  Accuracy 5%
# Iteration 1; 144/313 	Minibatch Loss 4.924  Accuracy 9%
# Iteration 1; 145/313 	Minibatch Loss 5.084  Accuracy 7%
# Iteration 1; 146/313 	Minibatch Loss 5.002  Accuracy 9%
# Iteration 1; 147/313 	Minibatch Loss 4.875  Accuracy 5%
# Iteration 1; 148/313 	Minibatch Loss 4.837  Accuracy 8%
# Iteration 1; 149/313 	Minibatch Loss 4.693  Accuracy 6%
# Iteration 1; 150/313 	Minibatch Loss 4.656  Accuracy 8%
# Iteration 1; 151/313 	Minibatch Loss 4.818  Accuracy 7%
# Iteration 1; 152/313 	Minibatch Loss 4.681  Accuracy 6%
# Iteration 1; 153/313 	Minibatch Loss 5.248  Accuracy 7%
# Iteration 1; 154/313 	Minibatch Loss 5.097  Accuracy 8%
# Iteration 1; 155/313 	Minibatch Loss 4.820  Accuracy 10%
# Iteration 1; 156/313 	Minibatch Loss 4.911  Accuracy 4%
# Iteration 1; 157/313 	Minibatch Loss 5.121  Accuracy 5%
# Iteration 1; 158/313 	Minibatch Loss 4.896  Accuracy 11%
# Iteration 1; 159/313 	Minibatch Loss 4.834  Accuracy 8%
# Iteration 1; 160/313 	Minibatch Loss 4.772  Accuracy 9%
# Iteration 1; 161/313 	Minibatch Loss 4.834  Accuracy 6%
# Iteration 1; 162/313 	Minibatch Loss 4.663  Accuracy 8%
# Iteration 1; 163/313 	Minibatch Loss 4.995  Accuracy 4%
# Iteration 1; 164/313 	Minibatch Loss 4.535  Accuracy 12%
# Iteration 1; 165/313 	Minibatch Loss 4.390  Accuracy 12%
# Iteration 1; 166/313 	Minibatch Loss 4.914  Accuracy 9%
# Iteration 1; 167/313 	Minibatch Loss 4.748  Accuracy 6%
# Iteration 1; 168/313 	Minibatch Loss 5.045  Accuracy 9%
# Iteration 1; 169/313 	Minibatch Loss 5.225  Accuracy 2%
# Iteration 1; 170/313 	Minibatch Loss 4.731  Accuracy 10%
# Iteration 1; 171/313 	Minibatch Loss 4.836  Accuracy 6%
# Iteration 1; 172/313 	Minibatch Loss 4.725  Accuracy 9%
# Iteration 1; 173/313 	Minibatch Loss 4.971  Accuracy 9%
# Iteration 1; 174/313 	Minibatch Loss 4.870  Accuracy 4%
# Iteration 1; 175/313 	Minibatch Loss 5.435  Accuracy 6%
# Iteration 1; 176/313 	Minibatch Loss 4.726  Accuracy 9%
# Iteration 1; 177/313 	Minibatch Loss 4.632  Accuracy 12%
# Iteration 1; 178/313 	Minibatch Loss 4.942  Accuracy 7%
# Iteration 1; 179/313 	Minibatch Loss 4.986  Accuracy 11%
# Iteration 1; 180/313 	Minibatch Loss 4.676  Accuracy 10%
# Iteration 1; 181/313 	Minibatch Loss 4.916  Accuracy 7%
# Iteration 1; 182/313 	Minibatch Loss 4.668  Accuracy 5%
# Iteration 1; 183/313 	Minibatch Loss 4.658  Accuracy 10%
# Iteration 1; 184/313 	Minibatch Loss 4.909  Accuracy 5%
# Iteration 1; 185/313 	Minibatch Loss 4.667  Accuracy 7%
# Iteration 1; 186/313 	Minibatch Loss 4.662  Accuracy 8%
# Iteration 1; 187/313 	Minibatch Loss 4.800  Accuracy 7%
# Iteration 1; 188/313 	Minibatch Loss 4.477  Accuracy 12%
# Iteration 1; 189/313 	Minibatch Loss 4.599  Accuracy 5%
# Iteration 1; 190/313 	Minibatch Loss 4.461  Accuracy 10%
# Iteration 1; 191/313 	Minibatch Loss 4.662  Accuracy 6%
# Iteration 1; 192/313 	Minibatch Loss 4.538  Accuracy 5%
# Iteration 1; 193/313 	Minibatch Loss 4.419  Accuracy 6%
# Iteration 1; 194/313 	Minibatch Loss 4.580  Accuracy 9%
# Iteration 1; 195/313 	Minibatch Loss 5.229  Accuracy 7%
# Iteration 1; 196/313 	Minibatch Loss 4.639  Accuracy 7%
# Iteration 1; 197/313 	Minibatch Loss 4.540  Accuracy 10%
# Iteration 1; 198/313 	Minibatch Loss 4.514  Accuracy 9%
# Iteration 1; 199/313 	Minibatch Loss 4.690  Accuracy 3%
# Iteration 1; 200/313 	Minibatch Loss 4.669  Accuracy 5%
# Iteration 1; 201/313 	Minibatch Loss 4.887  Accuracy 8%
# Iteration 1; 202/313 	Minibatch Loss 4.894  Accuracy 9%
# Iteration 1; 203/313 	Minibatch Loss 4.492  Accuracy 9%
# Iteration 1; 204/313 	Minibatch Loss 5.182  Accuracy 6%
# Iteration 1; 205/313 	Minibatch Loss 4.703  Accuracy 7%
# Iteration 1; 206/313 	Minibatch Loss 4.620  Accuracy 8%
# Iteration 1; 207/313 	Minibatch Loss 4.718  Accuracy 9%
# Iteration 1; 208/313 	Minibatch Loss 4.956  Accuracy 5%
# Iteration 1; 209/313 	Minibatch Loss 4.706  Accuracy 6%
# Iteration 1; 210/313 	Minibatch Loss 4.579  Accuracy 7%
# Iteration 1; 211/313 	Minibatch Loss 4.700  Accuracy 9%
# Iteration 1; 212/313 	Minibatch Loss 5.013  Accuracy 3%
# Iteration 1; 213/313 	Minibatch Loss 4.489  Accuracy 8%
# Iteration 1; 214/313 	Minibatch Loss 4.588  Accuracy 5%
# Iteration 1; 215/313 	Minibatch Loss 4.695  Accuracy 6%
# Iteration 1; 216/313 	Minibatch Loss 5.008  Accuracy 5%
# Iteration 1; 217/313 	Minibatch Loss 4.671  Accuracy 13%
# Iteration 1; 218/313 	Minibatch Loss 4.625  Accuracy 9%
# Iteration 1; 219/313 	Minibatch Loss 4.492  Accuracy 5%
# Iteration 1; 220/313 	Minibatch Loss 4.556  Accuracy 7%
# Iteration 1; 221/313 	Minibatch Loss 4.621  Accuracy 9%
# Iteration 1; 222/313 	Minibatch Loss 4.545  Accuracy 11%
# Iteration 1; 223/313 	Minibatch Loss 4.521  Accuracy 9%
# Iteration 1; 224/313 	Minibatch Loss 4.463  Accuracy 12%
# Iteration 1; 225/313 	Minibatch Loss 4.652  Accuracy 7%
# Iteration 1; 226/313 	Minibatch Loss 4.565  Accuracy 6%
# Iteration 1; 227/313 	Minibatch Loss 4.758  Accuracy 11%
# Iteration 1; 228/313 	Minibatch Loss 4.770  Accuracy 9%
# Iteration 1; 229/313 	Minibatch Loss 4.735  Accuracy 4%
# Iteration 1; 230/313 	Minibatch Loss 4.552  Accuracy 8%
# Iteration 1; 231/313 	Minibatch Loss 4.805  Accuracy 6%
# Iteration 1; 232/313 	Minibatch Loss 4.503  Accuracy 8%
# Iteration 1; 233/313 	Minibatch Loss 4.328  Accuracy 12%
# Iteration 1; 234/313 	Minibatch Loss 4.852  Accuracy 4%
# Iteration 1; 235/313 	Minibatch Loss 4.921  Accuracy 5%
# Iteration 1; 236/313 	Minibatch Loss 4.258  Accuracy 10%
# Iteration 1; 237/313 	Minibatch Loss 4.629  Accuracy 5%
# Iteration 1; 238/313 	Minibatch Loss 4.640  Accuracy 7%
# Iteration 1; 239/313 	Minibatch Loss 4.422  Accuracy 8%
# Iteration 1; 240/313 	Minibatch Loss 4.626  Accuracy 6%
# Iteration 1; 241/313 	Minibatch Loss 4.853  Accuracy 10%
# Iteration 1; 242/313 	Minibatch Loss 4.734  Accuracy 6%
# Iteration 1; 243/313 	Minibatch Loss 4.673  Accuracy 8%
# Iteration 1; 244/313 	Minibatch Loss 4.557  Accuracy 10%
# Iteration 1; 245/313 	Minibatch Loss 4.718  Accuracy 9%
# Iteration 1; 246/313 	Minibatch Loss 4.543  Accuracy 7%
# Iteration 1; 247/313 	Minibatch Loss 4.482  Accuracy 10%
# Iteration 1; 248/313 	Minibatch Loss 4.762  Accuracy 5%
# Iteration 1; 249/313 	Minibatch Loss 4.374  Accuracy 9%
# Iteration 1; 250/313 	Minibatch Loss 4.555  Accuracy 10%
# Iteration 1; 251/313 	Minibatch Loss 4.439  Accuracy 9%
# Iteration 1; 252/313 	Minibatch Loss 4.819  Accuracy 8%
# Iteration 1; 253/313 	Minibatch Loss 4.514  Accuracy 12%
# Iteration 1; 254/313 	Minibatch Loss 4.659  Accuracy 5%
# Iteration 1; 255/313 	Minibatch Loss 4.384  Accuracy 11%
# Iteration 1; 256/313 	Minibatch Loss 4.576  Accuracy 5%
# Iteration 1; 257/313 	Minibatch Loss 4.736  Accuracy 9%
# Iteration 1; 258/313 	Minibatch Loss 4.420  Accuracy 12%
# Iteration 1; 259/313 	Minibatch Loss 4.567  Accuracy 8%
# Iteration 1; 260/313 	Minibatch Loss 4.724  Accuracy 9%
# Iteration 1; 261/313 	Minibatch Loss 4.643  Accuracy 8%
# Iteration 1; 262/313 	Minibatch Loss 4.525  Accuracy 5%
# Iteration 1; 263/313 	Minibatch Loss 4.458  Accuracy 9%
# Iteration 1; 264/313 	Minibatch Loss 4.837  Accuracy 12%
# Iteration 1; 265/313 	Minibatch Loss 4.743  Accuracy 10%
# Iteration 1; 266/313 	Minibatch Loss 4.203  Accuracy 11%
# Iteration 1; 267/313 	Minibatch Loss 4.295  Accuracy 13%
# Iteration 1; 268/313 	Minibatch Loss 4.522  Accuracy 13%
# Iteration 1; 269/313 	Minibatch Loss 4.740  Accuracy 9%
# Iteration 1; 270/313 	Minibatch Loss 4.267  Accuracy 11%
# Iteration 1; 271/313 	Minibatch Loss 5.142  Accuracy 12%
# Iteration 1; 272/313 	Minibatch Loss 4.570  Accuracy 11%
# Iteration 1; 273/313 	Minibatch Loss 4.625  Accuracy 6%
# Iteration 1; 274/313 	Minibatch Loss 4.833  Accuracy 9%
# Iteration 1; 275/313 	Minibatch Loss 4.181  Accuracy 12%
# Iteration 1; 276/313 	Minibatch Loss 4.414  Accuracy 9%
# Iteration 1; 277/313 	Minibatch Loss 4.331  Accuracy 9%
# Iteration 1; 278/313 	Minibatch Loss 4.466  Accuracy 7%
# Iteration 1; 279/313 	Minibatch Loss 4.411  Accuracy 8%
# Iteration 1; 280/313 	Minibatch Loss 4.370  Accuracy 10%
# Iteration 1; 281/313 	Minibatch Loss 5.287  Accuracy 7%
# Iteration 1; 282/313 	Minibatch Loss 4.557  Accuracy 12%
# Iteration 1; 283/313 	Minibatch Loss 4.439  Accuracy 9%
# Iteration 1; 284/313 	Minibatch Loss 4.351  Accuracy 5%
# Iteration 1; 285/313 	Minibatch Loss 4.445  Accuracy 5%
# Iteration 1; 286/313 	Minibatch Loss 4.440  Accuracy 8%
# Iteration 1; 287/313 	Minibatch Loss 4.180  Accuracy 14%
# Iteration 1; 288/313 	Minibatch Loss 4.360  Accuracy 12%
# Iteration 1; 289/313 	Minibatch Loss 4.520  Accuracy 10%
# Iteration 1; 290/313 	Minibatch Loss 4.315  Accuracy 9%
# Iteration 1; 291/313 	Minibatch Loss 4.595  Accuracy 5%
# Iteration 1; 292/313 	Minibatch Loss 4.648  Accuracy 8%
# Iteration 1; 293/313 	Minibatch Loss 4.488  Accuracy 11%
# Iteration 1; 294/313 	Minibatch Loss 4.371  Accuracy 7%
# Iteration 1; 295/313 	Minibatch Loss 4.347  Accuracy 5%
# Iteration 1; 296/313 	Minibatch Loss 4.512  Accuracy 9%
# Iteration 1; 297/313 	Minibatch Loss 4.407  Accuracy 9%
# Iteration 1; 298/313 	Minibatch Loss 4.527  Accuracy 9%
# Iteration 1; 299/313 	Minibatch Loss 4.660  Accuracy 7%
# Iteration 1; 300/313 	Minibatch Loss 4.235  Accuracy 16%
# Iteration 1; 301/313 	Minibatch Loss 4.291  Accuracy 11%
# Iteration 1; 302/313 	Minibatch Loss 4.452  Accuracy 5%
# Iteration 1; 303/313 	Minibatch Loss 4.561  Accuracy 6%
# Iteration 1; 304/313 	Minibatch Loss 4.690  Accuracy 9%
# Iteration 1; 305/313 	Minibatch Loss 4.509  Accuracy 5%
# Iteration 1; 306/313 	Minibatch Loss 4.188  Accuracy 7%
# Iteration 1; 307/313 	Minibatch Loss 4.457  Accuracy 9%
# Iteration 1; 308/313 	Minibatch Loss 4.205  Accuracy 9%
# Iteration 1; 309/313 	Minibatch Loss 4.376  Accuracy 8%
# Iteration 1; 310/313 	Minibatch Loss 4.311  Accuracy 8%
# Iteration 1; 311/313 	Minibatch Loss 4.440  Accuracy 9%
# Iteration 1; 312/313 	Minibatch Loss 4.372  Accuracy 6%
# Iteration 1; 0/79 	Validation accuracy: 0.109
# Iteration 1; 1/79 	Validation accuracy: 0.086
# Iteration 1; 2/79 	Validation accuracy: 0.109
# Iteration 1; 3/79 	Validation accuracy: 0.086
# Iteration 1; 4/79 	Validation accuracy: 0.141
# Iteration 1; 5/79 	Validation accuracy: 0.133
# Iteration 1; 6/79 	Validation accuracy: 0.125
# Iteration 1; 7/79 	Validation accuracy: 0.039
# Iteration 1; 8/79 	Validation accuracy: 0.070
# Iteration 1; 9/79 	Validation accuracy: 0.086
# Iteration 1; 10/79 	Validation accuracy: 0.094
# Iteration 1; 11/79 	Validation accuracy: 0.070
# Iteration 1; 12/79 	Validation accuracy: 0.148
# Iteration 1; 13/79 	Validation accuracy: 0.070
# Iteration 1; 14/79 	Validation accuracy: 0.086
# Iteration 1; 15/79 	Validation accuracy: 0.070
# Iteration 1; 16/79 	Validation accuracy: 0.070
# Iteration 1; 17/79 	Validation accuracy: 0.086
# Iteration 1; 18/79 	Validation accuracy: 0.078
# Iteration 1; 19/79 	Validation accuracy: 0.078
# Iteration 1; 20/79 	Validation accuracy: 0.047
# Iteration 1; 21/79 	Validation accuracy: 0.102
# Iteration 1; 22/79 	Validation accuracy: 0.086
# Iteration 1; 23/79 	Validation accuracy: 0.109
# Iteration 1; 24/79 	Validation accuracy: 0.070
# Iteration 1; 25/79 	Validation accuracy: 0.102
# Iteration 1; 26/79 	Validation accuracy: 0.109
# Iteration 1; 27/79 	Validation accuracy: 0.086
# Iteration 1; 28/79 	Validation accuracy: 0.062
# Iteration 1; 29/79 	Validation accuracy: 0.078
# Iteration 1; 30/79 	Validation accuracy: 0.062
# Iteration 1; 31/79 	Validation accuracy: 0.094
# Iteration 1; 32/79 	Validation accuracy: 0.109
# Iteration 1; 33/79 	Validation accuracy: 0.133
# Iteration 1; 34/79 	Validation accuracy: 0.078
# Iteration 1; 35/79 	Validation accuracy: 0.078
# Iteration 1; 36/79 	Validation accuracy: 0.078
# Iteration 1; 37/79 	Validation accuracy: 0.086
# Iteration 1; 38/79 	Validation accuracy: 0.062
# Iteration 1; 39/79 	Validation accuracy: 0.109
# Iteration 1; 40/79 	Validation accuracy: 0.062
# Iteration 1; 41/79 	Validation accuracy: 0.102
# Iteration 1; 42/79 	Validation accuracy: 0.094
# Iteration 1; 43/79 	Validation accuracy: 0.062
# Iteration 1; 44/79 	Validation accuracy: 0.102
# Iteration 1; 45/79 	Validation accuracy: 0.094
# Iteration 1; 46/79 	Validation accuracy: 0.133
# Iteration 1; 47/79 	Validation accuracy: 0.078
# Iteration 1; 48/79 	Validation accuracy: 0.078
# Iteration 1; 49/79 	Validation accuracy: 0.125
# Iteration 1; 50/79 	Validation accuracy: 0.094
# Iteration 1; 51/79 	Validation accuracy: 0.078
# Iteration 1; 52/79 	Validation accuracy: 0.141
# Iteration 1; 53/79 	Validation accuracy: 0.094
# Iteration 1; 54/79 	Validation accuracy: 0.078
# Iteration 1; 55/79 	Validation accuracy: 0.102
# Iteration 1; 56/79 	Validation accuracy: 0.070
# Iteration 1; 57/79 	Validation accuracy: 0.055
# Iteration 1; 58/79 	Validation accuracy: 0.102
# Iteration 1; 59/79 	Validation accuracy: 0.070
# Iteration 1; 60/79 	Validation accuracy: 0.117
# Iteration 1; 61/79 	Validation accuracy: 0.070
# Iteration 1; 62/79 	Validation accuracy: 0.039
# Iteration 1; 63/79 	Validation accuracy: 0.094
# Iteration 1; 64/79 	Validation accuracy: 0.070
# Iteration 1; 65/79 	Validation accuracy: 0.094
# Iteration 1; 66/79 	Validation accuracy: 0.086
# Iteration 1; 67/79 	Validation accuracy: 0.086
# Iteration 1; 68/79 	Validation accuracy: 0.133
# Iteration 1; 69/79 	Validation accuracy: 0.086
# Iteration 1; 70/79 	Validation accuracy: 0.086
# Iteration 1; 71/79 	Validation accuracy: 0.078
# Iteration 1; 72/79 	Validation accuracy: 0.086
# Iteration 1; 73/79 	Validation accuracy: 0.070
# Iteration 1; 74/79 	Validation accuracy: 0.070
# Iteration 1; 75/79 	Validation accuracy: 0.117
# Iteration 1; 76/79 	Validation accuracy: 0.062
# Iteration 1; 77/79 	Validation accuracy: 0.070
# Iteration 1; 78/79 	Validation accuracy: 0.000
# mean train acc:  0.06943889776357827
# mean val acc:  0.08742088607594936
# saving model at: models/CIFAR100_DN_model_SGD.pth
# Iteration 2; 0/313 	Minibatch Loss 4.243  Accuracy 15%
# Iteration 2; 1/313 	Minibatch Loss 4.593  Accuracy 12%
# Iteration 2; 2/313 	Minibatch Loss 4.220  Accuracy 8%
# Iteration 2; 3/313 	Minibatch Loss 4.233  Accuracy 9%
# Iteration 2; 4/313 	Minibatch Loss 4.399  Accuracy 6%
# Iteration 2; 5/313 	Minibatch Loss 4.509  Accuracy 9%
# Iteration 2; 6/313 	Minibatch Loss 4.423  Accuracy 6%
# Iteration 2; 7/313 	Minibatch Loss 4.374  Accuracy 6%
# Iteration 2; 8/313 	Minibatch Loss 4.402  Accuracy 11%
# Iteration 2; 9/313 	Minibatch Loss 4.431  Accuracy 10%
# Iteration 2; 10/313 	Minibatch Loss 3.904  Accuracy 12%
# Iteration 2; 11/313 	Minibatch Loss 4.386  Accuracy 7%
# Iteration 2; 12/313 	Minibatch Loss 4.288  Accuracy 8%
# Iteration 2; 13/313 	Minibatch Loss 4.276  Accuracy 10%
# Iteration 2; 14/313 	Minibatch Loss 4.172  Accuracy 10%
# Iteration 2; 15/313 	Minibatch Loss 4.401  Accuracy 7%
# Iteration 2; 16/313 	Minibatch Loss 4.364  Accuracy 12%
# Iteration 2; 17/313 	Minibatch Loss 4.269  Accuracy 9%
# Iteration 2; 18/313 	Minibatch Loss 4.270  Accuracy 9%
# Iteration 2; 19/313 	Minibatch Loss 4.409  Accuracy 10%
# Iteration 2; 20/313 	Minibatch Loss 4.320  Accuracy 13%
# Iteration 2; 21/313 	Minibatch Loss 4.058  Accuracy 12%
# Iteration 2; 22/313 	Minibatch Loss 4.741  Accuracy 9%
# Iteration 2; 23/313 	Minibatch Loss 4.287  Accuracy 9%
# Iteration 2; 24/313 	Minibatch Loss 4.217  Accuracy 11%
# Iteration 2; 25/313 	Minibatch Loss 4.270  Accuracy 11%
# Iteration 2; 26/313 	Minibatch Loss 4.419  Accuracy 11%
# Iteration 2; 27/313 	Minibatch Loss 4.399  Accuracy 11%
# Iteration 2; 28/313 	Minibatch Loss 4.031  Accuracy 14%
# Iteration 2; 29/313 	Minibatch Loss 4.102  Accuracy 15%
# Iteration 2; 30/313 	Minibatch Loss 4.297  Accuracy 12%
# Iteration 2; 31/313 	Minibatch Loss 4.231  Accuracy 16%
# Iteration 2; 32/313 	Minibatch Loss 4.231  Accuracy 7%
# Iteration 2; 33/313 	Minibatch Loss 4.499  Accuracy 12%
# Iteration 2; 34/313 	Minibatch Loss 4.183  Accuracy 13%
# Iteration 2; 35/313 	Minibatch Loss 4.114  Accuracy 12%
# Iteration 2; 36/313 	Minibatch Loss 4.034  Accuracy 12%
# Iteration 2; 37/313 	Minibatch Loss 4.144  Accuracy 12%
# Iteration 2; 38/313 	Minibatch Loss 4.266  Accuracy 11%
# Iteration 2; 39/313 	Minibatch Loss 4.110  Accuracy 10%
# Iteration 2; 40/313 	Minibatch Loss 4.171  Accuracy 16%
# Iteration 2; 41/313 	Minibatch Loss 4.064  Accuracy 12%
# Iteration 2; 42/313 	Minibatch Loss 3.987  Accuracy 15%
# Iteration 2; 43/313 	Minibatch Loss 4.189  Accuracy 9%
# Iteration 2; 44/313 	Minibatch Loss 4.274  Accuracy 12%
# Iteration 2; 45/313 	Minibatch Loss 4.316  Accuracy 11%
# Iteration 2; 46/313 	Minibatch Loss 3.990  Accuracy 14%
# Iteration 2; 47/313 	Minibatch Loss 4.516  Accuracy 7%
# Iteration 2; 48/313 	Minibatch Loss 4.272  Accuracy 9%
# Iteration 2; 49/313 	Minibatch Loss 4.330  Accuracy 8%
# Iteration 2; 50/313 	Minibatch Loss 4.236  Accuracy 11%
# Iteration 2; 51/313 	Minibatch Loss 4.731  Accuracy 14%
# Iteration 2; 52/313 	Minibatch Loss 4.539  Accuracy 8%
# Iteration 2; 53/313 	Minibatch Loss 4.383  Accuracy 9%
# Iteration 2; 54/313 	Minibatch Loss 4.135  Accuracy 14%
# Iteration 2; 55/313 	Minibatch Loss 4.455  Accuracy 11%
# Iteration 2; 56/313 	Minibatch Loss 4.499  Accuracy 14%
# Iteration 2; 57/313 	Minibatch Loss 3.941  Accuracy 18%
# Iteration 2; 58/313 	Minibatch Loss 4.332  Accuracy 8%
# Iteration 2; 59/313 	Minibatch Loss 4.215  Accuracy 11%
# Iteration 2; 60/313 	Minibatch Loss 4.145  Accuracy 12%
# Iteration 2; 61/313 	Minibatch Loss 4.163  Accuracy 10%
# Iteration 2; 62/313 	Minibatch Loss 4.050  Accuracy 14%
# Iteration 2; 63/313 	Minibatch Loss 4.176  Accuracy 11%
# Iteration 2; 64/313 	Minibatch Loss 3.985  Accuracy 18%
# Iteration 2; 65/313 	Minibatch Loss 4.161  Accuracy 7%
# Iteration 2; 66/313 	Minibatch Loss 4.136  Accuracy 12%
# Iteration 2; 67/313 	Minibatch Loss 3.963  Accuracy 11%
# Iteration 2; 68/313 	Minibatch Loss 4.559  Accuracy 6%
# Iteration 2; 69/313 	Minibatch Loss 3.971  Accuracy 14%
# Iteration 2; 70/313 	Minibatch Loss 4.138  Accuracy 11%
# Iteration 2; 71/313 	Minibatch Loss 4.215  Accuracy 12%
# Iteration 2; 72/313 	Minibatch Loss 4.224  Accuracy 5%
# Iteration 2; 73/313 	Minibatch Loss 4.210  Accuracy 12%
# Iteration 2; 74/313 	Minibatch Loss 3.952  Accuracy 14%
# Iteration 2; 75/313 	Minibatch Loss 4.087  Accuracy 12%
# Iteration 2; 76/313 	Minibatch Loss 4.148  Accuracy 9%
# Iteration 2; 77/313 	Minibatch Loss 4.133  Accuracy 9%
# Iteration 2; 78/313 	Minibatch Loss 4.646  Accuracy 6%
# Iteration 2; 79/313 	Minibatch Loss 4.118  Accuracy 12%
# Iteration 2; 80/313 	Minibatch Loss 4.326  Accuracy 8%
# Iteration 2; 81/313 	Minibatch Loss 4.035  Accuracy 11%
# Iteration 2; 82/313 	Minibatch Loss 4.284  Accuracy 13%
# Iteration 2; 83/313 	Minibatch Loss 4.048  Accuracy 14%
# Iteration 2; 84/313 	Minibatch Loss 4.081  Accuracy 11%
# Iteration 2; 85/313 	Minibatch Loss 3.980  Accuracy 12%
# Iteration 2; 86/313 	Minibatch Loss 3.897  Accuracy 15%
# Iteration 2; 87/313 	Minibatch Loss 4.382  Accuracy 9%
# Iteration 2; 88/313 	Minibatch Loss 4.080  Accuracy 11%
# Iteration 2; 89/313 	Minibatch Loss 4.083  Accuracy 12%
# Iteration 2; 90/313 	Minibatch Loss 4.242  Accuracy 12%
# Iteration 2; 91/313 	Minibatch Loss 4.129  Accuracy 12%
# Iteration 2; 92/313 	Minibatch Loss 3.886  Accuracy 12%
# Iteration 2; 93/313 	Minibatch Loss 4.021  Accuracy 11%
# Iteration 2; 94/313 	Minibatch Loss 4.320  Accuracy 16%
# Iteration 2; 95/313 	Minibatch Loss 3.730  Accuracy 20%
# Iteration 2; 96/313 	Minibatch Loss 4.071  Accuracy 14%
# Iteration 2; 97/313 	Minibatch Loss 4.172  Accuracy 10%
# ...
# Iteration 69; 101/313 	Minibatch Loss 4.767  Accuracy 7%
# Iteration 69; 102/313 	Minibatch Loss 7.164  Accuracy 4%
# Iteration 69; 103/313 	Minibatch Loss 5.599  Accuracy 5%
# Iteration 69; 104/313 	Minibatch Loss 4.159  Accuracy 7%
# Iteration 69; 105/313 	Minibatch Loss 6.464  Accuracy 8%
# Iteration 69; 106/313 	Minibatch Loss 8.580  Accuracy 2%
# Iteration 69; 107/313 	Minibatch Loss 5.424  Accuracy 8%
# Iteration 69; 108/313 	Minibatch Loss 4.271  Accuracy 5%
# Iteration 69; 109/313 	Minibatch Loss 4.126  Accuracy 11%
# Iteration 69; 110/313 	Minibatch Loss 4.272  Accuracy 4%
# Iteration 69; 111/313 	Minibatch Loss 7.079  Accuracy 3%
# Iteration 69; 112/313 	Minibatch Loss 8.408  Accuracy 9%
# Iteration 69; 113/313 	Minibatch Loss 4.844  Accuracy 5%
# Iteration 69; 114/313 	Minibatch Loss 5.506  Accuracy 7%
# Iteration 69; 115/313 	Minibatch Loss 5.274  Accuracy 10%
# Iteration 69; 116/313 	Minibatch Loss 4.287  Accuracy 7%
# Iteration 69; 117/313 	Minibatch Loss 4.924  Accuracy 5%
# Iteration 69; 118/313 	Minibatch Loss 4.474  Accuracy 7%
# Iteration 69; 119/313 	Minibatch Loss 8.957  Accuracy 7%
# Iteration 69; 120/313 	Minibatch Loss 4.735  Accuracy 9%
# Iteration 69; 121/313 	Minibatch Loss 5.412  Accuracy 5%
# Iteration 69; 122/313 	Minibatch Loss 4.251  Accuracy 5%
# Iteration 69; 123/313 	Minibatch Loss 5.080  Accuracy 8%
# Iteration 69; 124/313 	Minibatch Loss 3.960  Accuracy 10%
# Iteration 69; 125/313 	Minibatch Loss 4.481  Accuracy 12%
# Iteration 69; 126/313 	Minibatch Loss 5.249  Accuracy 11%
# Iteration 69; 127/313 	Minibatch Loss 6.162  Accuracy 6%
# Iteration 69; 128/313 	Minibatch Loss 5.418  Accuracy 7%
# Iteration 69; 129/313 	Minibatch Loss 3.967  Accuracy 8%
# Iteration 69; 130/313 	Minibatch Loss 4.174  Accuracy 5%
# Iteration 69; 131/313 	Minibatch Loss 4.179  Accuracy 8%
# Iteration 69; 132/313 	Minibatch Loss 4.790  Accuracy 2%
# Iteration 69; 133/313 	Minibatch Loss 4.524  Accuracy 5%
# Iteration 69; 134/313 	Minibatch Loss 4.834  Accuracy 3%
# Iteration 69; 135/313 	Minibatch Loss 6.880  Accuracy 9%
# Iteration 69; 136/313 	Minibatch Loss 4.526  Accuracy 6%
# Iteration 69; 137/313 	Minibatch Loss 7.026  Accuracy 6%
# Iteration 69; 138/313 	Minibatch Loss 4.774  Accuracy 4%
# Iteration 69; 139/313 	Minibatch Loss 4.321  Accuracy 9%
# Iteration 69; 140/313 	Minibatch Loss 4.430  Accuracy 5%
# Iteration 69; 141/313 	Minibatch Loss 7.069  Accuracy 8%
# Iteration 69; 142/313 	Minibatch Loss 4.299  Accuracy 9%
# Iteration 69; 143/313 	Minibatch Loss 4.206  Accuracy 8%
# Iteration 69; 144/313 	Minibatch Loss 4.336  Accuracy 11%
# Iteration 69; 145/313 	Minibatch Loss 5.852  Accuracy 6%
# Iteration 69; 146/313 	Minibatch Loss 4.955  Accuracy 6%
# Iteration 69; 147/313 	Minibatch Loss 4.868  Accuracy 9%
# Iteration 69; 148/313 	Minibatch Loss 5.010  Accuracy 5%
# Iteration 69; 149/313 	Minibatch Loss 4.311  Accuracy 4%
# Iteration 69; 150/313 	Minibatch Loss 4.839  Accuracy 6%
# Iteration 69; 151/313 	Minibatch Loss 4.228  Accuracy 7%
# Iteration 69; 152/313 	Minibatch Loss 4.182  Accuracy 10%
# Iteration 69; 153/313 	Minibatch Loss 4.839  Accuracy 12%
# Iteration 69; 154/313 	Minibatch Loss 5.634  Accuracy 6%
# Iteration 69; 155/313 	Minibatch Loss 4.641  Accuracy 5%
# Iteration 69; 156/313 	Minibatch Loss 4.992  Accuracy 2%
# Iteration 69; 157/313 	Minibatch Loss 4.451  Accuracy 8%
# Iteration 69; 158/313 	Minibatch Loss 8.389  Accuracy 5%
# Iteration 69; 159/313 	Minibatch Loss 4.976  Accuracy 9%
# Iteration 69; 160/313 	Minibatch Loss 5.109  Accuracy 10%
# Iteration 69; 161/313 	Minibatch Loss 5.223  Accuracy 8%
# Iteration 69; 162/313 	Minibatch Loss 4.341  Accuracy 5%
# Iteration 69; 163/313 	Minibatch Loss 4.786  Accuracy 9%
# Iteration 69; 164/313 	Minibatch Loss 4.383  Accuracy 4%
# Iteration 69; 165/313 	Minibatch Loss 4.433  Accuracy 9%
# Iteration 69; 166/313 	Minibatch Loss 4.187  Accuracy 12%
# Iteration 69; 167/313 	Minibatch Loss 4.498  Accuracy 4%
# Iteration 69; 168/313 	Minibatch Loss 4.349  Accuracy 5%
# Iteration 69; 169/313 	Minibatch Loss 4.400  Accuracy 8%
# Iteration 69; 170/313 	Minibatch Loss 5.287  Accuracy 9%
# Iteration 69; 171/313 	Minibatch Loss 4.063  Accuracy 9%
# Iteration 69; 172/313 	Minibatch Loss 5.724  Accuracy 3%
# Iteration 69; 173/313 	Minibatch Loss 5.391  Accuracy 5%
# Iteration 69; 174/313 	Minibatch Loss 4.380  Accuracy 7%
# Iteration 69; 175/313 	Minibatch Loss 5.003  Accuracy 12%
# Iteration 69; 176/313 	Minibatch Loss 5.293  Accuracy 8%
# Iteration 69; 177/313 	Minibatch Loss 5.018  Accuracy 9%
# Iteration 69; 178/313 	Minibatch Loss 4.240  Accuracy 5%
# Iteration 69; 179/313 	Minibatch Loss 4.870  Accuracy 9%
# Iteration 69; 180/313 	Minibatch Loss 6.945  Accuracy 8%
# Iteration 69; 181/313 	Minibatch Loss 4.098  Accuracy 9%
# Iteration 69; 182/313 	Minibatch Loss 4.940  Accuracy 6%
# Iteration 69; 183/313 	Minibatch Loss 8.570  Accuracy 9%
# Iteration 69; 184/313 	Minibatch Loss 4.244  Accuracy 12%
# Iteration 69; 185/313 	Minibatch Loss 4.356  Accuracy 4%
# Iteration 69; 186/313 	Minibatch Loss 4.609  Accuracy 7%
# Iteration 69; 187/313 	Minibatch Loss 4.160  Accuracy 5%
# Iteration 69; 188/313 	Minibatch Loss 7.295  Accuracy 8%
# Iteration 69; 189/313 	Minibatch Loss 4.856  Accuracy 11%
# Iteration 69; 190/313 	Minibatch Loss 5.567  Accuracy 5%
# Iteration 69; 191/313 	Minibatch Loss 4.171  Accuracy 5%
# Iteration 69; 192/313 	Minibatch Loss 5.306  Accuracy 9%
# Iteration 69; 193/313 	Minibatch Loss 4.569  Accuracy 7%
# Iteration 69; 194/313 	Minibatch Loss 4.174  Accuracy 9%
# Iteration 69; 195/313 	Minibatch Loss 4.543  Accuracy 9%
# Iteration 69; 196/313 	Minibatch Loss 4.393  Accuracy 5%
# Iteration 69; 197/313 	Minibatch Loss 4.626  Accuracy 9%
# Iteration 69; 198/313 	Minibatch Loss 4.094  Accuracy 10%
# Iteration 69; 199/313 	Minibatch Loss 5.300  Accuracy 5%
# Iteration 69; 200/313 	Minibatch Loss 4.432  Accuracy 6%
# Iteration 69; 201/313 	Minibatch Loss 5.261  Accuracy 10%
# Iteration 69; 202/313 	Minibatch Loss 4.228  Accuracy 2%
# Iteration 69; 203/313 	Minibatch Loss 4.701  Accuracy 8%
# Iteration 69; 204/313 	Minibatch Loss 5.069  Accuracy 8%
# Iteration 69; 205/313 	Minibatch Loss 4.279  Accuracy 8%
# Iteration 69; 206/313 	Minibatch Loss 6.737  Accuracy 8%
# Iteration 69; 207/313 	Minibatch Loss 5.741  Accuracy 5%
# Iteration 69; 208/313 	Minibatch Loss 4.567  Accuracy 4%
# Iteration 69; 209/313 	Minibatch Loss 5.684  Accuracy 8%
# Iteration 69; 210/313 	Minibatch Loss 4.221  Accuracy 5%
# Iteration 69; 211/313 	Minibatch Loss 5.308  Accuracy 5%
# Iteration 69; 212/313 	Minibatch Loss 8.381  Accuracy 2%
# Iteration 69; 213/313 	Minibatch Loss 4.841  Accuracy 5%
# Iteration 69; 214/313 	Minibatch Loss 13.341  Accuracy 9%
# Iteration 69; 215/313 	Minibatch Loss 4.207  Accuracy 6%
# Iteration 69; 216/313 	Minibatch Loss 4.330  Accuracy 4%
# Iteration 69; 217/313 	Minibatch Loss 4.402  Accuracy 5%
# Iteration 69; 218/313 	Minibatch Loss 4.700  Accuracy 8%
# Iteration 69; 219/313 	Minibatch Loss 5.501  Accuracy 5%
# Iteration 69; 220/313 	Minibatch Loss 4.358  Accuracy 6%
# Iteration 69; 221/313 	Minibatch Loss 4.311  Accuracy 6%
# Iteration 69; 222/313 	Minibatch Loss 8.132  Accuracy 6%
# Iteration 69; 223/313 	Minibatch Loss 4.057  Accuracy 12%
# Iteration 69; 224/313 	Minibatch Loss 4.437  Accuracy 9%
# Iteration 69; 225/313 	Minibatch Loss 6.764  Accuracy 7%
# Iteration 69; 226/313 	Minibatch Loss 4.394  Accuracy 9%
# Iteration 69; 227/313 	Minibatch Loss 5.440  Accuracy 10%
# Iteration 69; 228/313 	Minibatch Loss 5.322  Accuracy 7%
# Iteration 69; 229/313 	Minibatch Loss 11.817  Accuracy 2%
# Iteration 69; 230/313 	Minibatch Loss 4.904  Accuracy 5%
# Iteration 69; 231/313 	Minibatch Loss 4.299  Accuracy 8%
# Iteration 69; 232/313 	Minibatch Loss 4.207  Accuracy 6%
# Iteration 69; 233/313 	Minibatch Loss 8.929  Accuracy 6%
# Iteration 69; 234/313 	Minibatch Loss 4.226  Accuracy 5%
# Iteration 69; 235/313 	Minibatch Loss 6.024  Accuracy 8%
# Iteration 69; 236/313 	Minibatch Loss 5.028  Accuracy 3%
# Iteration 69; 237/313 	Minibatch Loss 4.269  Accuracy 6%
# Iteration 69; 238/313 	Minibatch Loss 5.888  Accuracy 6%
# Iteration 69; 239/313 	Minibatch Loss 4.432  Accuracy 8%
# Iteration 69; 240/313 	Minibatch Loss 4.126  Accuracy 10%
# Iteration 69; 241/313 	Minibatch Loss 4.590  Accuracy 9%
# Iteration 69; 242/313 	Minibatch Loss 4.359  Accuracy 4%
# Iteration 69; 243/313 	Minibatch Loss 5.314  Accuracy 7%
# Iteration 69; 244/313 	Minibatch Loss 4.103  Accuracy 8%
# Iteration 69; 245/313 	Minibatch Loss 4.189  Accuracy 7%
# Iteration 69; 246/313 	Minibatch Loss 4.543  Accuracy 5%
# Iteration 69; 247/313 	Minibatch Loss 4.470  Accuracy 10%
# Iteration 69; 248/313 	Minibatch Loss 5.159  Accuracy 8%
# Iteration 69; 249/313 	Minibatch Loss 4.238  Accuracy 9%
# Iteration 69; 250/313 	Minibatch Loss 4.659  Accuracy 7%
# Iteration 69; 251/313 	Minibatch Loss 3.970  Accuracy 8%
# Iteration 69; 252/313 	Minibatch Loss 4.617  Accuracy 3%
# Iteration 69; 253/313 	Minibatch Loss 4.197  Accuracy 7%
# Iteration 69; 254/313 	Minibatch Loss 4.270  Accuracy 6%
# Iteration 69; 255/313 	Minibatch Loss 4.157  Accuracy 8%
# Iteration 69; 256/313 	Minibatch Loss 3.958  Accuracy 6%
# Iteration 69; 257/313 	Minibatch Loss 4.222  Accuracy 7%
# Iteration 69; 258/313 	Minibatch Loss 5.552  Accuracy 13%
# Iteration 69; 259/313 	Minibatch Loss 8.206  Accuracy 2%
# Iteration 69; 260/313 	Minibatch Loss 4.315  Accuracy 9%
# Iteration 69; 261/313 	Minibatch Loss 5.304  Accuracy 7%
# Iteration 69; 262/313 	Minibatch Loss 4.054  Accuracy 11%
# Iteration 69; 263/313 	Minibatch Loss 4.379  Accuracy 8%
# Iteration 69; 264/313 	Minibatch Loss 4.343  Accuracy 5%
# Iteration 69; 265/313 	Minibatch Loss 6.031  Accuracy 12%
# Iteration 69; 266/313 	Minibatch Loss 4.250  Accuracy 8%
# Iteration 69; 267/313 	Minibatch Loss 7.024  Accuracy 4%
# Iteration 69; 268/313 	Minibatch Loss 3.995  Accuracy 6%
# Iteration 69; 269/313 	Minibatch Loss 6.123  Accuracy 9%
# Iteration 69; 270/313 	Minibatch Loss 4.318  Accuracy 7%
# Iteration 69; 271/313 	Minibatch Loss 4.303  Accuracy 9%
# Iteration 69; 272/313 	Minibatch Loss 4.223  Accuracy 5%
# Iteration 69; 273/313 	Minibatch Loss 5.203  Accuracy 9%
# Iteration 69; 274/313 	Minibatch Loss 5.338  Accuracy 7%
# Iteration 69; 275/313 	Minibatch Loss 4.810  Accuracy 5%
# Iteration 69; 276/313 	Minibatch Loss 4.518  Accuracy 5%
# Iteration 69; 277/313 	Minibatch Loss 4.410  Accuracy 9%
# Iteration 69; 278/313 	Minibatch Loss 4.326  Accuracy 7%
# Iteration 69; 279/313 	Minibatch Loss 4.420  Accuracy 7%
# Iteration 69; 280/313 	Minibatch Loss 4.551  Accuracy 5%
# Iteration 69; 281/313 	Minibatch Loss 4.521  Accuracy 9%
# Iteration 69; 282/313 	Minibatch Loss 5.218  Accuracy 9%
# Iteration 69; 283/313 	Minibatch Loss 4.393  Accuracy 6%
# Iteration 69; 284/313 	Minibatch Loss 5.379  Accuracy 5%
# Iteration 69; 285/313 	Minibatch Loss 5.527  Accuracy 9%
# Iteration 69; 286/313 	Minibatch Loss 4.401  Accuracy 5%
# Iteration 69; 287/313 	Minibatch Loss 4.133  Accuracy 10%
# Iteration 69; 288/313 	Minibatch Loss 4.188  Accuracy 10%
# Iteration 69; 289/313 	Minibatch Loss 4.379  Accuracy 14%
# Iteration 69; 290/313 	Minibatch Loss 7.078  Accuracy 5%
# Iteration 69; 291/313 	Minibatch Loss 6.952  Accuracy 9%
# Iteration 69; 292/313 	Minibatch Loss 5.503  Accuracy 9%
# Iteration 69; 293/313 	Minibatch Loss 5.036  Accuracy 6%
# Iteration 69; 294/313 	Minibatch Loss 4.540  Accuracy 13%
# Iteration 69; 295/313 	Minibatch Loss 4.289  Accuracy 9%
# Iteration 69; 296/313 	Minibatch Loss 4.469  Accuracy 9%
# Iteration 69; 297/313 	Minibatch Loss 4.047  Accuracy 6%
# Iteration 69; 298/313 	Minibatch Loss 8.092  Accuracy 10%
# Iteration 69; 299/313 	Minibatch Loss 4.360  Accuracy 5%
# Iteration 69; 300/313 	Minibatch Loss 11.680  Accuracy 7%
# Iteration 69; 301/313 	Minibatch Loss 4.193  Accuracy 9%
# Iteration 69; 302/313 	Minibatch Loss 4.585  Accuracy 5%
# Iteration 69; 303/313 	Minibatch Loss 3.999  Accuracy 7%
# Iteration 69; 304/313 	Minibatch Loss 4.565  Accuracy 6%
# Iteration 69; 305/313 	Minibatch Loss 5.361  Accuracy 3%
# Iteration 69; 306/313 	Minibatch Loss 8.119  Accuracy 3%
# Iteration 69; 307/313 	Minibatch Loss 5.366  Accuracy 7%
# Iteration 69; 308/313 	Minibatch Loss 5.184  Accuracy 8%
# Iteration 69; 309/313 	Minibatch Loss 4.408  Accuracy 9%
# Iteration 69; 310/313 	Minibatch Loss 4.274  Accuracy 7%
# Iteration 69; 311/313 	Minibatch Loss 6.202  Accuracy 8%
# Iteration 69; 312/313 	Minibatch Loss 9.480  Accuracy 8%
# Iteration 69; 0/79 	Validation accuracy: 0.031
# Iteration 69; 1/79 	Validation accuracy: 0.047
# Iteration 69; 2/79 	Validation accuracy: 0.070
# Iteration 69; 3/79 	Validation accuracy: 0.086
# Iteration 69; 4/79 	Validation accuracy: 0.070
# Iteration 69; 5/79 	Validation accuracy: 0.055
# Iteration 69; 6/79 	Validation accuracy: 0.055
# Iteration 69; 7/79 	Validation accuracy: 0.047
# Iteration 69; 8/79 	Validation accuracy: 0.062
# Iteration 69; 9/79 	Validation accuracy: 0.102
# Iteration 69; 10/79 	Validation accuracy: 0.055
# Iteration 69; 11/79 	Validation accuracy: 0.047
# Iteration 69; 12/79 	Validation accuracy: 0.062
# Iteration 69; 13/79 	Validation accuracy: 0.031
# Iteration 69; 14/79 	Validation accuracy: 0.078
# Iteration 69; 15/79 	Validation accuracy: 0.086
# Iteration 69; 16/79 	Validation accuracy: 0.086
# Iteration 69; 17/79 	Validation accuracy: 0.062
# Iteration 69; 18/79 	Validation accuracy: 0.055
# Iteration 69; 19/79 	Validation accuracy: 0.125
# Iteration 69; 20/79 	Validation accuracy: 0.070
# Iteration 69; 21/79 	Validation accuracy: 0.039
# Iteration 69; 22/79 	Validation accuracy: 0.055
# Iteration 69; 23/79 	Validation accuracy: 0.125
# Iteration 69; 24/79 	Validation accuracy: 0.070
# Iteration 69; 25/79 	Validation accuracy: 0.062
# Iteration 69; 26/79 	Validation accuracy: 0.055
# Iteration 69; 27/79 	Validation accuracy: 0.070
# Iteration 69; 28/79 	Validation accuracy: 0.086
# Iteration 69; 29/79 	Validation accuracy: 0.047
# Iteration 69; 30/79 	Validation accuracy: 0.070
# Iteration 69; 31/79 	Validation accuracy: 0.047
# Iteration 69; 32/79 	Validation accuracy: 0.023
# Iteration 69; 33/79 	Validation accuracy: 0.141
# Iteration 69; 34/79 	Validation accuracy: 0.055
# Iteration 69; 35/79 	Validation accuracy: 0.070
# Iteration 69; 36/79 	Validation accuracy: 0.047
# Iteration 69; 37/79 	Validation accuracy: 0.055
# Iteration 69; 38/79 	Validation accuracy: 0.109
# Iteration 69; 39/79 	Validation accuracy: 0.047
# Iteration 69; 40/79 	Validation accuracy: 0.102
# Iteration 69; 41/79 	Validation accuracy: 0.047
# Iteration 69; 42/79 	Validation accuracy: 0.078
# Iteration 69; 43/79 	Validation accuracy: 0.078
# Iteration 69; 44/79 	Validation accuracy: 0.062
# Iteration 69; 45/79 	Validation accuracy: 0.023
# Iteration 69; 46/79 	Validation accuracy: 0.047
# Iteration 69; 47/79 	Validation accuracy: 0.062
# Iteration 69; 48/79 	Validation accuracy: 0.070
# Iteration 69; 49/79 	Validation accuracy: 0.094
# Iteration 69; 50/79 	Validation accuracy: 0.117
# Iteration 69; 51/79 	Validation accuracy: 0.070
# Iteration 69; 52/79 	Validation accuracy: 0.055
# Iteration 69; 53/79 	Validation accuracy: 0.078
# Iteration 69; 54/79 	Validation accuracy: 0.078
# Iteration 69; 55/79 	Validation accuracy: 0.070
# Iteration 69; 56/79 	Validation accuracy: 0.039
# Iteration 69; 57/79 	Validation accuracy: 0.102
# Iteration 69; 58/79 	Validation accuracy: 0.078
# Iteration 69; 59/79 	Validation accuracy: 0.039
# Iteration 69; 60/79 	Validation accuracy: 0.055
# Iteration 69; 61/79 	Validation accuracy: 0.070
# Iteration 69; 62/79 	Validation accuracy: 0.086
# Iteration 69; 63/79 	Validation accuracy: 0.062
# Iteration 69; 64/79 	Validation accuracy: 0.078
# Iteration 69; 65/79 	Validation accuracy: 0.062
# Iteration 69; 66/79 	Validation accuracy: 0.055
# Iteration 69; 67/79 	Validation accuracy: 0.055
# Iteration 69; 68/79 	Validation accuracy: 0.070
# Iteration 69; 69/79 	Validation accuracy: 0.047
# Iteration 69; 70/79 	Validation accuracy: 0.047
# Iteration 69; 71/79 	Validation accuracy: 0.062
# Iteration 69; 72/79 	Validation accuracy: 0.055
# Iteration 69; 73/79 	Validation accuracy: 0.062
# Iteration 69; 74/79 	Validation accuracy: 0.062
# Iteration 69; 75/79 	Validation accuracy: 0.086
# Iteration 69; 76/79 	Validation accuracy: 0.055
# Iteration 69; 77/79 	Validation accuracy: 0.094
# Iteration 69; 78/79 	Validation accuracy: 0.125
# mean train acc:  0.07068690095846646
# mean val acc:  0.06754351265822785
