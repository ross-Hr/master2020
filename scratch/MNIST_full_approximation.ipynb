# %%
import torch
import torchvision
from torch import nn, optim, autograd
from torch.nn import functional as F
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.autograd import Variable
import numpy as np
#import input_data
from sklearn.utils import shuffle as skshuffle
from math import *
from backpack import backpack, extend
from backpack.extensions import KFAC, DiagHessian, DiagGGNMC
from sklearn.metrics import roc_auc_score
import scipy
from tqdm import tqdm, trange
from backpack.core.layers import Flatten
import pytest
from DirLPA_utils import * 

import matplotlib.pyplot as plt

np.random.seed(123)
torch.manual_seed(123)

# %%
class LPADirNN(torch.nn.Module):
    def __init__(self, num_classes=10, x=400):
        
        super(LPADirNN, self).__init__()
        
        self.features = torch.nn.Sequential(
            torch.nn.Linear(28*28, x),
            torch.nn.ReLU(),
            torch.nn.Linear(x,x),
            torch.nn.ReLU()
        )
        self.fc = torch.nn.Linear(x, num_classes)
        
    def forward(self, x):
        
        x = x.view(-1, 28*28)
        x = self.features(x)
        out = self.fc(x)
        
        return(out)

# %%
BATCH_SIZE_TRAIN_MNIST = 128
BATCH_SIZE_TEST_MNIST = 128
MAX_ITER_MNIST = 6
LR_TRAIN_MNIST = 10e-6

# %%
MNIST_transform = torchvision.transforms.ToTensor()

MNIST_train = torchvision.datasets.MNIST(
        './data',
        train=True,
        download=True,
        transform=MNIST_transform)

mnist_train_loader = torch.utils.data.dataloader.DataLoader(
    MNIST_train,
    batch_size=BATCH_SIZE_TRAIN_MNIST,
    shuffle=True
)


MNIST_test = torchvision.datasets.MNIST(
        './data',
        train=False,
        download=False,
        transform=MNIST_transform)

mnist_test_loader = torch.utils.data.dataloader.DataLoader(
    MNIST_test,
    batch_size=BATCH_SIZE_TEST_MNIST,
    shuffle=False,
)

# %%
mnist_model = LPADirNN(x=100)
loss_function = torch.nn.CrossEntropyLoss()

#mnist_train_optimizer = torch.optim.Adam(mnist_model.parameters(), lr=LR_TRAIN_MNIST)
mnist_train_optimizer = torch.optim.Adam(mnist_model.parameters(), lr=1e-3, weight_decay=5e-4)
MNIST_PATH = "models/mnist_test_6iter_10c_simpleNN_100.pth"

# %%
#Training routine

for iter in range(MAX_ITER_MNIST):
    for batch_idx, (x, y) in enumerate(mnist_train_loader):
        max_len = int(np.ceil(len(mnist_train_loader.dataset)/BATCH_SIZE_TRAIN_MNIST))
        output = mnist_model(x)

        accuracy = get_accuracy(output, y)

        loss = loss_function(output, y)
        loss.backward()
        mnist_train_optimizer.step()
        mnist_train_optimizer.zero_grad()

        print(
            "Iteration {}; {}/{} \t".format(iter, batch_idx, max_len) +
            "Minibatch Loss %.3f  " % (loss) +
            "Accuracy %.0f" % (accuracy * 100) + "%"
        )

print("saving model at: {}".format(MNIST_PATH))
torch.save(mnist_model.state_dict(), MNIST_PATH)
# Out:
# Iteration 0; 0/469 	Minibatch Loss 2.305  Accuracy 9%
# Iteration 0; 1/469 	Minibatch Loss 2.288  Accuracy 18%
# Iteration 0; 2/469 	Minibatch Loss 2.279  Accuracy 14%
# Iteration 0; 3/469 	Minibatch Loss 2.253  Accuracy 10%
# Iteration 0; 4/469 	Minibatch Loss 2.228  Accuracy 23%
# Iteration 0; 5/469 	Minibatch Loss 2.217  Accuracy 25%
# Iteration 0; 6/469 	Minibatch Loss 2.183  Accuracy 35%
# Iteration 0; 7/469 	Minibatch Loss 2.173  Accuracy 38%
# Iteration 0; 8/469 	Minibatch Loss 2.123  Accuracy 55%
# Iteration 0; 9/469 	Minibatch Loss 2.063  Accuracy 58%
# Iteration 0; 10/469 	Minibatch Loss 2.040  Accuracy 59%
# Iteration 0; 11/469 	Minibatch Loss 2.000  Accuracy 57%
# Iteration 0; 12/469 	Minibatch Loss 1.972  Accuracy 62%
# Iteration 0; 13/469 	Minibatch Loss 1.926  Accuracy 61%
# Iteration 0; 14/469 	Minibatch Loss 1.901  Accuracy 58%
# Iteration 0; 15/469 	Minibatch Loss 1.804  Accuracy 61%
# Iteration 0; 16/469 	Minibatch Loss 1.762  Accuracy 62%
# Iteration 0; 17/469 	Minibatch Loss 1.745  Accuracy 56%
# Iteration 0; 18/469 	Minibatch Loss 1.679  Accuracy 64%
# Iteration 0; 19/469 	Minibatch Loss 1.640  Accuracy 66%
# Iteration 0; 20/469 	Minibatch Loss 1.481  Accuracy 70%
# Iteration 0; 21/469 	Minibatch Loss 1.469  Accuracy 74%
# Iteration 0; 22/469 	Minibatch Loss 1.494  Accuracy 67%
# Iteration 0; 23/469 	Minibatch Loss 1.333  Accuracy 73%
# Iteration 0; 24/469 	Minibatch Loss 1.288  Accuracy 77%
# Iteration 0; 25/469 	Minibatch Loss 1.217  Accuracy 78%
# Iteration 0; 26/469 	Minibatch Loss 1.274  Accuracy 67%
# Iteration 0; 27/469 	Minibatch Loss 1.128  Accuracy 75%
# Iteration 0; 28/469 	Minibatch Loss 1.077  Accuracy 80%
# Iteration 0; 29/469 	Minibatch Loss 1.173  Accuracy 73%
# Iteration 0; 30/469 	Minibatch Loss 1.041  Accuracy 75%
# Iteration 0; 31/469 	Minibatch Loss 0.941  Accuracy 77%
# Iteration 0; 32/469 	Minibatch Loss 1.029  Accuracy 74%
# Iteration 0; 33/469 	Minibatch Loss 0.940  Accuracy 75%
# Iteration 0; 34/469 	Minibatch Loss 0.765  Accuracy 81%
# Iteration 0; 35/469 	Minibatch Loss 0.718  Accuracy 85%
# Iteration 0; 36/469 	Minibatch Loss 0.892  Accuracy 77%
# Iteration 0; 37/469 	Minibatch Loss 0.820  Accuracy 78%
# Iteration 0; 38/469 	Minibatch Loss 0.741  Accuracy 82%
# Iteration 0; 39/469 	Minibatch Loss 0.693  Accuracy 88%
# Iteration 0; 40/469 	Minibatch Loss 0.656  Accuracy 87%
# Iteration 0; 41/469 	Minibatch Loss 0.645  Accuracy 86%
# Iteration 0; 42/469 	Minibatch Loss 0.706  Accuracy 77%
# Iteration 0; 43/469 	Minibatch Loss 0.868  Accuracy 74%
# Iteration 0; 44/469 	Minibatch Loss 0.652  Accuracy 80%
# Iteration 0; 45/469 	Minibatch Loss 0.598  Accuracy 82%
# Iteration 0; 46/469 	Minibatch Loss 0.553  Accuracy 84%
# Iteration 0; 47/469 	Minibatch Loss 0.623  Accuracy 82%
# Iteration 0; 48/469 	Minibatch Loss 0.629  Accuracy 80%
# Iteration 0; 49/469 	Minibatch Loss 0.603  Accuracy 84%
# Iteration 0; 50/469 	Minibatch Loss 0.599  Accuracy 80%
# Iteration 0; 51/469 	Minibatch Loss 0.630  Accuracy 83%
# Iteration 0; 52/469 	Minibatch Loss 0.540  Accuracy 80%
# Iteration 0; 53/469 	Minibatch Loss 0.467  Accuracy 86%
# Iteration 0; 54/469 	Minibatch Loss 0.516  Accuracy 86%
# Iteration 0; 55/469 	Minibatch Loss 0.493  Accuracy 84%
# Iteration 0; 56/469 	Minibatch Loss 0.485  Accuracy 88%
# Iteration 0; 57/469 	Minibatch Loss 0.387  Accuracy 87%
# Iteration 0; 58/469 	Minibatch Loss 0.575  Accuracy 86%
# Iteration 0; 59/469 	Minibatch Loss 0.485  Accuracy 86%
# Iteration 0; 60/469 	Minibatch Loss 0.567  Accuracy 88%
# Iteration 0; 61/469 	Minibatch Loss 0.520  Accuracy 84%
# Iteration 0; 62/469 	Minibatch Loss 0.620  Accuracy 88%
# Iteration 0; 63/469 	Minibatch Loss 0.490  Accuracy 87%
# Iteration 0; 64/469 	Minibatch Loss 0.508  Accuracy 80%
# Iteration 0; 65/469 	Minibatch Loss 0.480  Accuracy 90%
# Iteration 0; 66/469 	Minibatch Loss 0.570  Accuracy 84%
# Iteration 0; 67/469 	Minibatch Loss 0.563  Accuracy 84%
# Iteration 0; 68/469 	Minibatch Loss 0.408  Accuracy 88%
# Iteration 0; 69/469 	Minibatch Loss 0.508  Accuracy 85%
# Iteration 0; 70/469 	Minibatch Loss 0.688  Accuracy 81%
# Iteration 0; 71/469 	Minibatch Loss 0.315  Accuracy 91%
# Iteration 0; 72/469 	Minibatch Loss 0.292  Accuracy 93%
# Iteration 0; 73/469 	Minibatch Loss 0.455  Accuracy 83%
# Iteration 0; 74/469 	Minibatch Loss 0.486  Accuracy 82%
# Iteration 0; 75/469 	Minibatch Loss 0.413  Accuracy 88%
# Iteration 0; 76/469 	Minibatch Loss 0.539  Accuracy 86%
# Iteration 0; 77/469 	Minibatch Loss 0.498  Accuracy 84%
# Iteration 0; 78/469 	Minibatch Loss 0.357  Accuracy 91%
# Iteration 0; 79/469 	Minibatch Loss 0.477  Accuracy 86%
# Iteration 0; 80/469 	Minibatch Loss 0.283  Accuracy 91%
# Iteration 0; 81/469 	Minibatch Loss 0.526  Accuracy 84%
# Iteration 0; 82/469 	Minibatch Loss 0.426  Accuracy 89%
# Iteration 0; 83/469 	Minibatch Loss 0.358  Accuracy 88%
# Iteration 0; 84/469 	Minibatch Loss 0.429  Accuracy 90%
# Iteration 0; 85/469 	Minibatch Loss 0.387  Accuracy 87%
# Iteration 0; 86/469 	Minibatch Loss 0.313  Accuracy 95%
# Iteration 0; 87/469 	Minibatch Loss 0.450  Accuracy 86%
# Iteration 0; 88/469 	Minibatch Loss 0.389  Accuracy 88%
# Iteration 0; 89/469 	Minibatch Loss 0.399  Accuracy 84%
# Iteration 0; 90/469 	Minibatch Loss 0.357  Accuracy 91%
# Iteration 0; 91/469 	Minibatch Loss 0.386  Accuracy 89%
# Iteration 0; 92/469 	Minibatch Loss 0.340  Accuracy 91%
# Iteration 0; 93/469 	Minibatch Loss 0.453  Accuracy 86%
# Iteration 0; 94/469 	Minibatch Loss 0.402  Accuracy 89%
# Iteration 0; 95/469 	Minibatch Loss 0.419  Accuracy 90%
# Iteration 0; 96/469 	Minibatch Loss 0.371  Accuracy 88%
# Iteration 0; 97/469 	Minibatch Loss 0.372  Accuracy 88%
# Iteration 0; 98/469 	Minibatch Loss 0.465  Accuracy 89%
# Iteration 0; 99/469 	Minibatch Loss 0.334  Accuracy 90%
# Iteration 0; 100/469 	Minibatch Loss 0.371  Accuracy 90%
# Iteration 0; 101/469 	Minibatch Loss 0.398  Accuracy 88%
# Iteration 0; 102/469 	Minibatch Loss 0.440  Accuracy 88%
# Iteration 0; 103/469 	Minibatch Loss 0.430  Accuracy 91%
# Iteration 0; 104/469 	Minibatch Loss 0.284  Accuracy 93%
# Iteration 0; 105/469 	Minibatch Loss 0.372  Accuracy 91%
# Iteration 0; 106/469 	Minibatch Loss 0.450  Accuracy 87%
# Iteration 0; 107/469 	Minibatch Loss 0.304  Accuracy 93%
# Iteration 0; 108/469 	Minibatch Loss 0.343  Accuracy 90%
# Iteration 0; 109/469 	Minibatch Loss 0.405  Accuracy 88%
# Iteration 0; 110/469 	Minibatch Loss 0.432  Accuracy 85%
# Iteration 0; 111/469 	Minibatch Loss 0.501  Accuracy 85%
# Iteration 0; 112/469 	Minibatch Loss 0.302  Accuracy 91%
# Iteration 0; 113/469 	Minibatch Loss 0.465  Accuracy 88%
# Iteration 0; 114/469 	Minibatch Loss 0.385  Accuracy 88%
# Iteration 0; 115/469 	Minibatch Loss 0.349  Accuracy 95%
# Iteration 0; 116/469 	Minibatch Loss 0.460  Accuracy 86%
# Iteration 0; 117/469 	Minibatch Loss 0.431  Accuracy 89%
# Iteration 0; 118/469 	Minibatch Loss 0.313  Accuracy 91%
# Iteration 0; 119/469 	Minibatch Loss 0.313  Accuracy 91%
# Iteration 0; 120/469 	Minibatch Loss 0.242  Accuracy 95%
# Iteration 0; 121/469 	Minibatch Loss 0.325  Accuracy 92%
# Iteration 0; 122/469 	Minibatch Loss 0.290  Accuracy 91%
# Iteration 0; 123/469 	Minibatch Loss 0.504  Accuracy 87%
# Iteration 0; 124/469 	Minibatch Loss 0.372  Accuracy 89%
# Iteration 0; 125/469 	Minibatch Loss 0.359  Accuracy 91%
# Iteration 0; 126/469 	Minibatch Loss 0.352  Accuracy 91%
# Iteration 0; 127/469 	Minibatch Loss 0.296  Accuracy 90%
# Iteration 0; 128/469 	Minibatch Loss 0.305  Accuracy 92%
# Iteration 0; 129/469 	Minibatch Loss 0.263  Accuracy 89%
# Iteration 0; 130/469 	Minibatch Loss 0.334  Accuracy 91%
# Iteration 0; 131/469 	Minibatch Loss 0.324  Accuracy 86%
# Iteration 0; 132/469 	Minibatch Loss 0.375  Accuracy 89%
# Iteration 0; 133/469 	Minibatch Loss 0.292  Accuracy 89%
# Iteration 0; 134/469 	Minibatch Loss 0.248  Accuracy 93%
# Iteration 0; 135/469 	Minibatch Loss 0.492  Accuracy 86%
# Iteration 0; 136/469 	Minibatch Loss 0.298  Accuracy 90%
# Iteration 0; 137/469 	Minibatch Loss 0.236  Accuracy 93%
# Iteration 0; 138/469 	Minibatch Loss 0.275  Accuracy 93%
# Iteration 0; 139/469 	Minibatch Loss 0.404  Accuracy 90%
# Iteration 0; 140/469 	Minibatch Loss 0.266  Accuracy 93%
# Iteration 0; 141/469 	Minibatch Loss 0.293  Accuracy 92%
# Iteration 0; 142/469 	Minibatch Loss 0.398  Accuracy 91%
# Iteration 0; 143/469 	Minibatch Loss 0.327  Accuracy 91%
# Iteration 0; 144/469 	Minibatch Loss 0.357  Accuracy 88%
# Iteration 0; 145/469 	Minibatch Loss 0.334  Accuracy 91%
# Iteration 0; 146/469 	Minibatch Loss 0.276  Accuracy 92%
# Iteration 0; 147/469 	Minibatch Loss 0.354  Accuracy 90%
# Iteration 0; 148/469 	Minibatch Loss 0.436  Accuracy 88%
# Iteration 0; 149/469 	Minibatch Loss 0.323  Accuracy 91%
# Iteration 0; 150/469 	Minibatch Loss 0.290  Accuracy 93%
# Iteration 0; 151/469 	Minibatch Loss 0.458  Accuracy 86%
# Iteration 0; 152/469 	Minibatch Loss 0.232  Accuracy 96%
# Iteration 0; 153/469 	Minibatch Loss 0.276  Accuracy 91%
# Iteration 0; 154/469 	Minibatch Loss 0.425  Accuracy 87%
# Iteration 0; 155/469 	Minibatch Loss 0.464  Accuracy 88%
# Iteration 0; 156/469 	Minibatch Loss 0.298  Accuracy 91%
# Iteration 0; 157/469 	Minibatch Loss 0.327  Accuracy 90%
# Iteration 0; 158/469 	Minibatch Loss 0.306  Accuracy 91%
# Iteration 0; 159/469 	Minibatch Loss 0.339  Accuracy 88%
# Iteration 0; 160/469 	Minibatch Loss 0.249  Accuracy 93%
# Iteration 0; 161/469 	Minibatch Loss 0.203  Accuracy 96%
# Iteration 0; 162/469 	Minibatch Loss 0.286  Accuracy 93%
# Iteration 0; 163/469 	Minibatch Loss 0.274  Accuracy 88%
# Iteration 0; 164/469 	Minibatch Loss 0.404  Accuracy 91%
# Iteration 0; 165/469 	Minibatch Loss 0.241  Accuracy 92%
# Iteration 0; 166/469 	Minibatch Loss 0.340  Accuracy 90%
# Iteration 0; 167/469 	Minibatch Loss 0.418  Accuracy 89%
# Iteration 0; 168/469 	Minibatch Loss 0.343  Accuracy 90%
# Iteration 0; 169/469 	Minibatch Loss 0.299  Accuracy 91%
# Iteration 0; 170/469 	Minibatch Loss 0.227  Accuracy 94%
# Iteration 0; 171/469 	Minibatch Loss 0.221  Accuracy 95%
# Iteration 0; 172/469 	Minibatch Loss 0.614  Accuracy 83%
# Iteration 0; 173/469 	Minibatch Loss 0.334  Accuracy 88%
# Iteration 0; 174/469 	Minibatch Loss 0.340  Accuracy 94%
# Iteration 0; 175/469 	Minibatch Loss 0.279  Accuracy 94%
# Iteration 0; 176/469 	Minibatch Loss 0.309  Accuracy 91%
# Iteration 0; 177/469 	Minibatch Loss 0.321  Accuracy 93%
# Iteration 0; 178/469 	Minibatch Loss 0.309  Accuracy 91%
# Iteration 0; 179/469 	Minibatch Loss 0.326  Accuracy 93%
# Iteration 0; 180/469 	Minibatch Loss 0.398  Accuracy 87%
# Iteration 0; 181/469 	Minibatch Loss 0.324  Accuracy 90%
# Iteration 0; 182/469 	Minibatch Loss 0.316  Accuracy 91%
# Iteration 0; 183/469 	Minibatch Loss 0.353  Accuracy 90%
# Iteration 0; 184/469 	Minibatch Loss 0.360  Accuracy 89%
# Iteration 0; 185/469 	Minibatch Loss 0.305  Accuracy 91%
# Iteration 0; 186/469 	Minibatch Loss 0.325  Accuracy 91%
# Iteration 0; 187/469 	Minibatch Loss 0.336  Accuracy 91%
# Iteration 0; 188/469 	Minibatch Loss 0.206  Accuracy 95%
# Iteration 0; 189/469 	Minibatch Loss 0.438  Accuracy 88%
# Iteration 0; 190/469 	Minibatch Loss 0.326  Accuracy 90%
# Iteration 0; 191/469 	Minibatch Loss 0.358  Accuracy 91%
# Iteration 0; 192/469 	Minibatch Loss 0.348  Accuracy 90%
# Iteration 0; 193/469 	Minibatch Loss 0.344  Accuracy 91%
# Iteration 0; 194/469 	Minibatch Loss 0.257  Accuracy 95%
# Iteration 0; 195/469 	Minibatch Loss 0.344  Accuracy 90%
# Iteration 0; 196/469 	Minibatch Loss 0.280  Accuracy 92%
# Iteration 0; 197/469 	Minibatch Loss 0.344  Accuracy 92%
# Iteration 0; 198/469 	Minibatch Loss 0.268  Accuracy 91%
# Iteration 0; 199/469 	Minibatch Loss 0.533  Accuracy 84%
# Iteration 0; 200/469 	Minibatch Loss 0.365  Accuracy 88%
# Iteration 0; 201/469 	Minibatch Loss 0.268  Accuracy 91%
# Iteration 0; 202/469 	Minibatch Loss 0.266  Accuracy 92%
# Iteration 0; 203/469 	Minibatch Loss 0.370  Accuracy 91%
# Iteration 0; 204/469 	Minibatch Loss 0.365  Accuracy 89%
# Iteration 0; 205/469 	Minibatch Loss 0.247  Accuracy 93%
# Iteration 0; 206/469 	Minibatch Loss 0.287  Accuracy 90%
# Iteration 0; 207/469 	Minibatch Loss 0.220  Accuracy 94%
# Iteration 0; 208/469 	Minibatch Loss 0.331  Accuracy 90%
# Iteration 0; 209/469 	Minibatch Loss 0.196  Accuracy 94%
# Iteration 0; 210/469 	Minibatch Loss 0.390  Accuracy 90%
# Iteration 0; 211/469 	Minibatch Loss 0.390  Accuracy 90%
# Iteration 0; 212/469 	Minibatch Loss 0.309  Accuracy 93%
# Iteration 0; 213/469 	Minibatch Loss 0.282  Accuracy 95%
# Iteration 0; 214/469 	Minibatch Loss 0.203  Accuracy 95%
# Iteration 0; 215/469 	Minibatch Loss 0.184  Accuracy 95%
# Iteration 0; 216/469 	Minibatch Loss 0.222  Accuracy 94%
# Iteration 0; 217/469 	Minibatch Loss 0.180  Accuracy 97%
# Iteration 0; 218/469 	Minibatch Loss 0.266  Accuracy 91%
# Iteration 0; 219/469 	Minibatch Loss 0.356  Accuracy 90%
# Iteration 0; 220/469 	Minibatch Loss 0.260  Accuracy 93%
# Iteration 0; 221/469 	Minibatch Loss 0.270  Accuracy 91%
# Iteration 0; 222/469 	Minibatch Loss 0.317  Accuracy 92%
# Iteration 0; 223/469 	Minibatch Loss 0.276  Accuracy 90%
# Iteration 0; 224/469 	Minibatch Loss 0.323  Accuracy 89%
# Iteration 0; 225/469 	Minibatch Loss 0.274  Accuracy 92%
# Iteration 0; 226/469 	Minibatch Loss 0.395  Accuracy 86%
# Iteration 0; 227/469 	Minibatch Loss 0.358  Accuracy 90%
# Iteration 0; 228/469 	Minibatch Loss 0.344  Accuracy 90%
# Iteration 0; 229/469 	Minibatch Loss 0.187  Accuracy 93%
# Iteration 0; 230/469 	Minibatch Loss 0.218  Accuracy 95%
# Iteration 0; 231/469 	Minibatch Loss 0.403  Accuracy 89%
# Iteration 0; 232/469 	Minibatch Loss 0.383  Accuracy 89%
# Iteration 0; 233/469 	Minibatch Loss 0.268  Accuracy 90%
# Iteration 0; 234/469 	Minibatch Loss 0.231  Accuracy 95%
# Iteration 0; 235/469 	Minibatch Loss 0.234  Accuracy 94%
# Iteration 0; 236/469 	Minibatch Loss 0.221  Accuracy 93%
# Iteration 0; 237/469 	Minibatch Loss 0.367  Accuracy 91%
# Iteration 0; 238/469 	Minibatch Loss 0.266  Accuracy 91%
# Iteration 0; 239/469 	Minibatch Loss 0.319  Accuracy 88%
# Iteration 0; 240/469 	Minibatch Loss 0.374  Accuracy 91%
# Iteration 0; 241/469 	Minibatch Loss 0.246  Accuracy 93%
# Iteration 0; 242/469 	Minibatch Loss 0.233  Accuracy 94%
# Iteration 0; 243/469 	Minibatch Loss 0.284  Accuracy 90%
# Iteration 0; 244/469 	Minibatch Loss 0.162  Accuracy 95%
# Iteration 0; 245/469 	Minibatch Loss 0.379  Accuracy 89%
# Iteration 0; 246/469 	Minibatch Loss 0.394  Accuracy 88%
# Iteration 0; 247/469 	Minibatch Loss 0.211  Accuracy 92%
# Iteration 0; 248/469 	Minibatch Loss 0.264  Accuracy 93%
# Iteration 0; 249/469 	Minibatch Loss 0.259  Accuracy 92%
# Iteration 0; 250/469 	Minibatch Loss 0.343  Accuracy 90%
# Iteration 0; 251/469 	Minibatch Loss 0.334  Accuracy 89%
# Iteration 0; 252/469 	Minibatch Loss 0.155  Accuracy 96%
# Iteration 0; 253/469 	Minibatch Loss 0.215  Accuracy 95%
# Iteration 0; 254/469 	Minibatch Loss 0.246  Accuracy 91%
# Iteration 0; 255/469 	Minibatch Loss 0.175  Accuracy 97%
# Iteration 0; 256/469 	Minibatch Loss 0.446  Accuracy 90%
# Iteration 0; 257/469 	Minibatch Loss 0.360  Accuracy 91%
# Iteration 0; 258/469 	Minibatch Loss 0.399  Accuracy 87%
# Iteration 0; 259/469 	Minibatch Loss 0.248  Accuracy 92%
# Iteration 0; 260/469 	Minibatch Loss 0.236  Accuracy 96%
# Iteration 0; 261/469 	Minibatch Loss 0.286  Accuracy 89%
# Iteration 0; 262/469 	Minibatch Loss 0.216  Accuracy 92%
# Iteration 0; 263/469 	Minibatch Loss 0.257  Accuracy 93%
# Iteration 0; 264/469 	Minibatch Loss 0.222  Accuracy 95%
# Iteration 0; 265/469 	Minibatch Loss 0.145  Accuracy 96%
# Iteration 0; 266/469 	Minibatch Loss 0.441  Accuracy 88%
# Iteration 0; 267/469 	Minibatch Loss 0.290  Accuracy 95%
# Iteration 0; 268/469 	Minibatch Loss 0.311  Accuracy 91%
# Iteration 0; 269/469 	Minibatch Loss 0.219  Accuracy 94%
# Iteration 0; 270/469 	Minibatch Loss 0.290  Accuracy 92%
# Iteration 0; 271/469 	Minibatch Loss 0.207  Accuracy 92%
# Iteration 0; 272/469 	Minibatch Loss 0.268  Accuracy 91%
# Iteration 0; 273/469 	Minibatch Loss 0.195  Accuracy 94%
# Iteration 0; 274/469 	Minibatch Loss 0.215  Accuracy 91%
# Iteration 0; 275/469 	Minibatch Loss 0.193  Accuracy 95%
# Iteration 0; 276/469 	Minibatch Loss 0.284  Accuracy 90%
# Iteration 0; 277/469 	Minibatch Loss 0.377  Accuracy 89%
# Iteration 0; 278/469 	Minibatch Loss 0.276  Accuracy 92%
# Iteration 0; 279/469 	Minibatch Loss 0.283  Accuracy 93%
# Iteration 0; 280/469 	Minibatch Loss 0.266  Accuracy 93%
# Iteration 0; 281/469 	Minibatch Loss 0.240  Accuracy 94%
# Iteration 0; 282/469 	Minibatch Loss 0.241  Accuracy 95%
# Iteration 0; 283/469 	Minibatch Loss 0.334  Accuracy 88%
# Iteration 0; 284/469 	Minibatch Loss 0.226  Accuracy 92%
# Iteration 0; 285/469 	Minibatch Loss 0.187  Accuracy 95%
# Iteration 0; 286/469 	Minibatch Loss 0.269  Accuracy 91%
# Iteration 0; 287/469 	Minibatch Loss 0.254  Accuracy 93%
# Iteration 0; 288/469 	Minibatch Loss 0.222  Accuracy 92%
# Iteration 0; 289/469 	Minibatch Loss 0.297  Accuracy 87%
# Iteration 0; 290/469 	Minibatch Loss 0.244  Accuracy 95%
# Iteration 0; 291/469 	Minibatch Loss 0.197  Accuracy 94%
# Iteration 0; 292/469 	Minibatch Loss 0.250  Accuracy 92%
# Iteration 0; 293/469 	Minibatch Loss 0.193  Accuracy 96%
# Iteration 0; 294/469 	Minibatch Loss 0.310  Accuracy 95%
# Iteration 0; 295/469 	Minibatch Loss 0.217  Accuracy 94%
# Iteration 0; 296/469 	Minibatch Loss 0.236  Accuracy 91%
# Iteration 0; 297/469 	Minibatch Loss 0.258  Accuracy 92%
# Iteration 0; 298/469 	Minibatch Loss 0.358  Accuracy 89%
# Iteration 0; 299/469 	Minibatch Loss 0.189  Accuracy 93%
# Iteration 0; 300/469 	Minibatch Loss 0.276  Accuracy 91%
# Iteration 0; 301/469 	Minibatch Loss 0.401  Accuracy 88%
# Iteration 0; 302/469 	Minibatch Loss 0.358  Accuracy 90%
# Iteration 0; 303/469 	Minibatch Loss 0.279  Accuracy 94%
# Iteration 0; 304/469 	Minibatch Loss 0.311  Accuracy 95%
# Iteration 0; 305/469 	Minibatch Loss 0.303  Accuracy 91%
# Iteration 0; 306/469 	Minibatch Loss 0.170  Accuracy 95%
# Iteration 0; 307/469 	Minibatch Loss 0.231  Accuracy 95%
# Iteration 0; 308/469 	Minibatch Loss 0.316  Accuracy 90%
# Iteration 0; 309/469 	Minibatch Loss 0.200  Accuracy 94%
# Iteration 0; 310/469 	Minibatch Loss 0.449  Accuracy 90%
# Iteration 0; 311/469 	Minibatch Loss 0.255  Accuracy 91%
# Iteration 0; 312/469 	Minibatch Loss 0.376  Accuracy 90%
# Iteration 0; 313/469 	Minibatch Loss 0.203  Accuracy 94%
# Iteration 0; 314/469 	Minibatch Loss 0.213  Accuracy 95%
# Iteration 0; 315/469 	Minibatch Loss 0.231  Accuracy 91%
# Iteration 0; 316/469 	Minibatch Loss 0.165  Accuracy 98%
# Iteration 0; 317/469 	Minibatch Loss 0.289  Accuracy 93%
# Iteration 0; 318/469 	Minibatch Loss 0.193  Accuracy 95%
# Iteration 0; 319/469 	Minibatch Loss 0.218  Accuracy 92%
# Iteration 0; 320/469 	Minibatch Loss 0.324  Accuracy 91%
# Iteration 0; 321/469 	Minibatch Loss 0.366  Accuracy 87%
# Iteration 0; 322/469 	Minibatch Loss 0.330  Accuracy 91%
# Iteration 0; 323/469 	Minibatch Loss 0.168  Accuracy 98%
# Iteration 0; 324/469 	Minibatch Loss 0.263  Accuracy 93%
# Iteration 0; 325/469 	Minibatch Loss 0.268  Accuracy 91%
# Iteration 0; 326/469 	Minibatch Loss 0.228  Accuracy 94%
# Iteration 0; 327/469 	Minibatch Loss 0.267  Accuracy 90%
# Iteration 0; 328/469 	Minibatch Loss 0.172  Accuracy 95%
# Iteration 0; 329/469 	Minibatch Loss 0.222  Accuracy 93%
# Iteration 0; 330/469 	Minibatch Loss 0.231  Accuracy 93%
# Iteration 0; 331/469 	Minibatch Loss 0.321  Accuracy 91%
# Iteration 0; 332/469 	Minibatch Loss 0.226  Accuracy 93%
# Iteration 0; 333/469 	Minibatch Loss 0.346  Accuracy 91%
# Iteration 0; 334/469 	Minibatch Loss 0.193  Accuracy 95%
# Iteration 0; 335/469 	Minibatch Loss 0.200  Accuracy 94%
# Iteration 0; 336/469 	Minibatch Loss 0.214  Accuracy 95%
# Iteration 0; 337/469 	Minibatch Loss 0.227  Accuracy 91%
# Iteration 0; 338/469 	Minibatch Loss 0.210  Accuracy 95%
# Iteration 0; 339/469 	Minibatch Loss 0.276  Accuracy 90%
# Iteration 0; 340/469 	Minibatch Loss 0.297  Accuracy 92%
# Iteration 0; 341/469 	Minibatch Loss 0.277  Accuracy 93%
# Iteration 0; 342/469 	Minibatch Loss 0.178  Accuracy 94%
# Iteration 0; 343/469 	Minibatch Loss 0.187  Accuracy 92%
# Iteration 0; 344/469 	Minibatch Loss 0.187  Accuracy 93%
# Iteration 0; 345/469 	Minibatch Loss 0.447  Accuracy 93%
# Iteration 0; 346/469 	Minibatch Loss 0.297  Accuracy 89%
# Iteration 0; 347/469 	Minibatch Loss 0.231  Accuracy 94%
# Iteration 0; 348/469 	Minibatch Loss 0.185  Accuracy 94%
# Iteration 0; 349/469 	Minibatch Loss 0.236  Accuracy 94%
# Iteration 0; 350/469 	Minibatch Loss 0.312  Accuracy 91%
# Iteration 0; 351/469 	Minibatch Loss 0.179  Accuracy 95%
# Iteration 0; 352/469 	Minibatch Loss 0.279  Accuracy 91%
# Iteration 0; 353/469 	Minibatch Loss 0.304  Accuracy 91%
# Iteration 0; 354/469 	Minibatch Loss 0.238  Accuracy 94%
# Iteration 0; 355/469 	Minibatch Loss 0.264  Accuracy 93%
# Iteration 0; 356/469 	Minibatch Loss 0.316  Accuracy 90%
# Iteration 0; 357/469 	Minibatch Loss 0.233  Accuracy 93%
# Iteration 0; 358/469 	Minibatch Loss 0.194  Accuracy 93%
# Iteration 0; 359/469 	Minibatch Loss 0.115  Accuracy 96%
# Iteration 0; 360/469 	Minibatch Loss 0.271  Accuracy 94%
# Iteration 0; 361/469 	Minibatch Loss 0.160  Accuracy 97%
# Iteration 0; 362/469 	Minibatch Loss 0.226  Accuracy 95%
# Iteration 0; 363/469 	Minibatch Loss 0.277  Accuracy 91%
# Iteration 0; 364/469 	Minibatch Loss 0.242  Accuracy 89%
# Iteration 0; 365/469 	Minibatch Loss 0.155  Accuracy 97%
# Iteration 0; 366/469 	Minibatch Loss 0.207  Accuracy 95%
# Iteration 0; 367/469 	Minibatch Loss 0.200  Accuracy 95%
# Iteration 0; 368/469 	Minibatch Loss 0.267  Accuracy 91%
# Iteration 0; 369/469 	Minibatch Loss 0.345  Accuracy 84%
# Iteration 0; 370/469 	Minibatch Loss 0.326  Accuracy 91%
# Iteration 0; 371/469 	Minibatch Loss 0.371  Accuracy 91%
# Iteration 0; 372/469 	Minibatch Loss 0.367  Accuracy 91%
# Iteration 0; 373/469 	Minibatch Loss 0.216  Accuracy 94%
# Iteration 0; 374/469 	Minibatch Loss 0.334  Accuracy 91%
# Iteration 0; 375/469 	Minibatch Loss 0.233  Accuracy 92%
# Iteration 0; 376/469 	Minibatch Loss 0.213  Accuracy 92%
# Iteration 0; 377/469 	Minibatch Loss 0.381  Accuracy 91%
# Iteration 0; 378/469 	Minibatch Loss 0.214  Accuracy 94%
# Iteration 0; 379/469 	Minibatch Loss 0.228  Accuracy 94%
# Iteration 0; 380/469 	Minibatch Loss 0.346  Accuracy 88%
# Iteration 0; 381/469 	Minibatch Loss 0.235  Accuracy 92%
# Iteration 0; 382/469 	Minibatch Loss 0.261  Accuracy 91%
# Iteration 0; 383/469 	Minibatch Loss 0.277  Accuracy 90%
# Iteration 0; 384/469 	Minibatch Loss 0.260  Accuracy 91%
# Iteration 0; 385/469 	Minibatch Loss 0.173  Accuracy 94%
# Iteration 0; 386/469 	Minibatch Loss 0.263  Accuracy 92%
# Iteration 0; 387/469 	Minibatch Loss 0.378  Accuracy 88%
# Iteration 0; 388/469 	Minibatch Loss 0.277  Accuracy 88%
# Iteration 0; 389/469 	Minibatch Loss 0.188  Accuracy 95%
# Iteration 0; 390/469 	Minibatch Loss 0.274  Accuracy 94%
# Iteration 0; 391/469 	Minibatch Loss 0.204  Accuracy 94%
# Iteration 0; 392/469 	Minibatch Loss 0.140  Accuracy 95%
# Iteration 0; 393/469 	Minibatch Loss 0.239  Accuracy 95%
# Iteration 0; 394/469 	Minibatch Loss 0.183  Accuracy 95%
# Iteration 0; 395/469 	Minibatch Loss 0.296  Accuracy 92%
# Iteration 0; 396/469 	Minibatch Loss 0.256  Accuracy 91%
# Iteration 0; 397/469 	Minibatch Loss 0.321  Accuracy 88%
# Iteration 0; 398/469 	Minibatch Loss 0.199  Accuracy 94%
# Iteration 0; 399/469 	Minibatch Loss 0.227  Accuracy 91%
# Iteration 0; 400/469 	Minibatch Loss 0.336  Accuracy 91%
# Iteration 0; 401/469 	Minibatch Loss 0.288  Accuracy 94%
# Iteration 0; 402/469 	Minibatch Loss 0.247  Accuracy 93%
# Iteration 0; 403/469 	Minibatch Loss 0.138  Accuracy 97%
# Iteration 0; 404/469 	Minibatch Loss 0.279  Accuracy 91%
# Iteration 0; 405/469 	Minibatch Loss 0.353  Accuracy 93%
# Iteration 0; 406/469 	Minibatch Loss 0.274  Accuracy 94%
# Iteration 0; 407/469 	Minibatch Loss 0.189  Accuracy 96%
# Iteration 0; 408/469 	Minibatch Loss 0.190  Accuracy 94%
# Iteration 0; 409/469 	Minibatch Loss 0.302  Accuracy 89%
# Iteration 0; 410/469 	Minibatch Loss 0.242  Accuracy 94%
# Iteration 0; 411/469 	Minibatch Loss 0.115  Accuracy 98%
# Iteration 0; 412/469 	Minibatch Loss 0.368  Accuracy 92%
# Iteration 0; 413/469 	Minibatch Loss 0.240  Accuracy 90%
# Iteration 0; 414/469 	Minibatch Loss 0.108  Accuracy 98%
# Iteration 0; 415/469 	Minibatch Loss 0.346  Accuracy 91%
# Iteration 0; 416/469 	Minibatch Loss 0.180  Accuracy 97%
# Iteration 0; 417/469 	Minibatch Loss 0.194  Accuracy 93%
# Iteration 0; 418/469 	Minibatch Loss 0.194  Accuracy 95%
# Iteration 0; 419/469 	Minibatch Loss 0.261  Accuracy 94%
# Iteration 0; 420/469 	Minibatch Loss 0.144  Accuracy 96%
# Iteration 0; 421/469 	Minibatch Loss 0.318  Accuracy 92%
# Iteration 0; 422/469 	Minibatch Loss 0.315  Accuracy 93%
# Iteration 0; 423/469 	Minibatch Loss 0.308  Accuracy 92%
# Iteration 0; 424/469 	Minibatch Loss 0.178  Accuracy 95%
# Iteration 0; 425/469 	Minibatch Loss 0.244  Accuracy 92%
# Iteration 0; 426/469 	Minibatch Loss 0.166  Accuracy 95%
# Iteration 0; 427/469 	Minibatch Loss 0.158  Accuracy 94%
# Iteration 0; 428/469 	Minibatch Loss 0.233  Accuracy 95%
# Iteration 0; 429/469 	Minibatch Loss 0.210  Accuracy 95%
# Iteration 0; 430/469 	Minibatch Loss 0.259  Accuracy 91%
# Iteration 0; 431/469 	Minibatch Loss 0.215  Accuracy 93%
# Iteration 0; 432/469 	Minibatch Loss 0.122  Accuracy 97%
# Iteration 0; 433/469 	Minibatch Loss 0.291  Accuracy 93%
# Iteration 0; 434/469 	Minibatch Loss 0.200  Accuracy 94%
# Iteration 0; 435/469 	Minibatch Loss 0.307  Accuracy 92%
# Iteration 0; 436/469 	Minibatch Loss 0.238  Accuracy 92%
# Iteration 0; 437/469 	Minibatch Loss 0.137  Accuracy 95%
# Iteration 0; 438/469 	Minibatch Loss 0.384  Accuracy 92%
# Iteration 0; 439/469 	Minibatch Loss 0.211  Accuracy 91%
# Iteration 0; 440/469 	Minibatch Loss 0.342  Accuracy 88%
# Iteration 0; 441/469 	Minibatch Loss 0.360  Accuracy 88%
# Iteration 0; 442/469 	Minibatch Loss 0.241  Accuracy 91%
# Iteration 0; 443/469 	Minibatch Loss 0.112  Accuracy 97%
# Iteration 0; 444/469 	Minibatch Loss 0.129  Accuracy 95%
# Iteration 0; 445/469 	Minibatch Loss 0.155  Accuracy 96%
# Iteration 0; 446/469 	Minibatch Loss 0.144  Accuracy 96%
# Iteration 0; 447/469 	Minibatch Loss 0.168  Accuracy 95%
# Iteration 0; 448/469 	Minibatch Loss 0.228  Accuracy 95%
# Iteration 0; 449/469 	Minibatch Loss 0.182  Accuracy 93%
# Iteration 0; 450/469 	Minibatch Loss 0.196  Accuracy 95%
# Iteration 0; 451/469 	Minibatch Loss 0.162  Accuracy 96%
# Iteration 0; 452/469 	Minibatch Loss 0.235  Accuracy 92%
# Iteration 0; 453/469 	Minibatch Loss 0.203  Accuracy 94%
# Iteration 0; 454/469 	Minibatch Loss 0.235  Accuracy 95%
# Iteration 0; 455/469 	Minibatch Loss 0.241  Accuracy 93%
# Iteration 0; 456/469 	Minibatch Loss 0.245  Accuracy 95%
# Iteration 0; 457/469 	Minibatch Loss 0.232  Accuracy 94%
# Iteration 0; 458/469 	Minibatch Loss 0.267  Accuracy 94%
# Iteration 0; 459/469 	Minibatch Loss 0.232  Accuracy 95%
# Iteration 0; 460/469 	Minibatch Loss 0.294  Accuracy 92%
# Iteration 0; 461/469 	Minibatch Loss 0.327  Accuracy 92%
# Iteration 0; 462/469 	Minibatch Loss 0.298  Accuracy 91%
# Iteration 0; 463/469 	Minibatch Loss 0.174  Accuracy 96%
# Iteration 0; 464/469 	Minibatch Loss 0.192  Accuracy 94%
# Iteration 0; 465/469 	Minibatch Loss 0.189  Accuracy 95%
# Iteration 0; 466/469 	Minibatch Loss 0.215  Accuracy 95%
# Iteration 0; 467/469 	Minibatch Loss 0.290  Accuracy 91%
# Iteration 0; 468/469 	Minibatch Loss 0.096  Accuracy 99%
# Iteration 1; 0/469 	Minibatch Loss 0.298  Accuracy 91%
# Iteration 1; 1/469 	Minibatch Loss 0.159  Accuracy 95%
# Iteration 1; 2/469 	Minibatch Loss 0.175  Accuracy 95%
# Iteration 1; 3/469 	Minibatch Loss 0.196  Accuracy 95%
# Iteration 1; 4/469 	Minibatch Loss 0.161  Accuracy 93%
# Iteration 1; 5/469 	Minibatch Loss 0.186  Accuracy 95%
# Iteration 1; 6/469 	Minibatch Loss 0.201  Accuracy 95%
# Iteration 1; 7/469 	Minibatch Loss 0.188  Accuracy 95%
# Iteration 1; 8/469 	Minibatch Loss 0.128  Accuracy 95%
# Iteration 1; 9/469 	Minibatch Loss 0.131  Accuracy 97%
# Iteration 1; 10/469 	Minibatch Loss 0.199  Accuracy 96%
# Iteration 1; 11/469 	Minibatch Loss 0.169  Accuracy 95%
# Iteration 1; 12/469 	Minibatch Loss 0.315  Accuracy 94%
# Iteration 1; 13/469 	Minibatch Loss 0.113  Accuracy 97%
# Iteration 1; 14/469 	Minibatch Loss 0.216  Accuracy 95%
# Iteration 1; 15/469 	Minibatch Loss 0.369  Accuracy 90%
# Iteration 1; 16/469 	Minibatch Loss 0.187  Accuracy 95%
# Iteration 1; 17/469 	Minibatch Loss 0.233  Accuracy 95%
# Iteration 1; 18/469 	Minibatch Loss 0.137  Accuracy 95%
# Iteration 1; 19/469 	Minibatch Loss 0.114  Accuracy 97%
# Iteration 1; 20/469 	Minibatch Loss 0.228  Accuracy 95%
# Iteration 1; 21/469 	Minibatch Loss 0.156  Accuracy 95%
# Iteration 1; 22/469 	Minibatch Loss 0.148  Accuracy 96%
# Iteration 1; 23/469 	Minibatch Loss 0.159  Accuracy 95%
# Iteration 1; 24/469 	Minibatch Loss 0.228  Accuracy 93%
# Iteration 1; 25/469 	Minibatch Loss 0.195  Accuracy 91%
# Iteration 1; 26/469 	Minibatch Loss 0.207  Accuracy 94%
# Iteration 1; 27/469 	Minibatch Loss 0.179  Accuracy 94%
# Iteration 1; 28/469 	Minibatch Loss 0.188  Accuracy 94%
# Iteration 1; 29/469 	Minibatch Loss 0.279  Accuracy 92%
# Iteration 1; 30/469 	Minibatch Loss 0.181  Accuracy 95%
# Iteration 1; 31/469 	Minibatch Loss 0.177  Accuracy 96%
# Iteration 1; 32/469 	Minibatch Loss 0.137  Accuracy 98%
# Iteration 1; 33/469 	Minibatch Loss 0.275  Accuracy 91%
# Iteration 1; 34/469 	Minibatch Loss 0.143  Accuracy 96%
# Iteration 1; 35/469 	Minibatch Loss 0.195  Accuracy 95%
# Iteration 1; 36/469 	Minibatch Loss 0.182  Accuracy 95%
# Iteration 1; 37/469 	Minibatch Loss 0.233  Accuracy 93%
# Iteration 1; 38/469 	Minibatch Loss 0.176  Accuracy 95%
# Iteration 1; 39/469 	Minibatch Loss 0.130  Accuracy 95%
# Iteration 1; 40/469 	Minibatch Loss 0.180  Accuracy 95%
# Iteration 1; 41/469 	Minibatch Loss 0.173  Accuracy 95%
# Iteration 1; 42/469 	Minibatch Loss 0.252  Accuracy 94%
# Iteration 1; 43/469 	Minibatch Loss 0.266  Accuracy 95%
# Iteration 1; 44/469 	Minibatch Loss 0.269  Accuracy 91%
# Iteration 1; 45/469 	Minibatch Loss 0.261  Accuracy 95%
# Iteration 1; 46/469 	Minibatch Loss 0.304  Accuracy 89%
# Iteration 1; 47/469 	Minibatch Loss 0.230  Accuracy 94%
# Iteration 1; 48/469 	Minibatch Loss 0.129  Accuracy 96%
# Iteration 1; 49/469 	Minibatch Loss 0.246  Accuracy 91%
# Iteration 1; 50/469 	Minibatch Loss 0.152  Accuracy 96%
# Iteration 1; 51/469 	Minibatch Loss 0.175  Accuracy 95%
# Iteration 1; 52/469 	Minibatch Loss 0.294  Accuracy 91%
# Iteration 1; 53/469 	Minibatch Loss 0.296  Accuracy 92%
# Iteration 1; 54/469 	Minibatch Loss 0.224  Accuracy 96%
# Iteration 1; 55/469 	Minibatch Loss 0.114  Accuracy 97%
# Iteration 1; 56/469 	Minibatch Loss 0.139  Accuracy 98%
# Iteration 1; 57/469 	Minibatch Loss 0.182  Accuracy 95%
# Iteration 1; 58/469 	Minibatch Loss 0.320  Accuracy 94%
# Iteration 1; 59/469 	Minibatch Loss 0.218  Accuracy 95%
# Iteration 1; 60/469 	Minibatch Loss 0.299  Accuracy 91%
# Iteration 1; 61/469 	Minibatch Loss 0.148  Accuracy 95%
# Iteration 1; 62/469 	Minibatch Loss 0.170  Accuracy 97%
# Iteration 1; 63/469 	Minibatch Loss 0.172  Accuracy 94%
# Iteration 1; 64/469 	Minibatch Loss 0.308  Accuracy 91%
# Iteration 1; 65/469 	Minibatch Loss 0.240  Accuracy 94%
# Iteration 1; 66/469 	Minibatch Loss 0.190  Accuracy 94%
# Iteration 1; 67/469 	Minibatch Loss 0.117  Accuracy 97%
# Iteration 1; 68/469 	Minibatch Loss 0.137  Accuracy 95%
# Iteration 1; 69/469 	Minibatch Loss 0.198  Accuracy 95%
# Iteration 1; 70/469 	Minibatch Loss 0.302  Accuracy 92%
# Iteration 1; 71/469 	Minibatch Loss 0.178  Accuracy 94%
# Iteration 1; 72/469 	Minibatch Loss 0.164  Accuracy 97%
# Iteration 1; 73/469 	Minibatch Loss 0.135  Accuracy 95%
# Iteration 1; 74/469 	Minibatch Loss 0.267  Accuracy 90%
# Iteration 1; 75/469 	Minibatch Loss 0.134  Accuracy 95%
# Iteration 1; 76/469 	Minibatch Loss 0.173  Accuracy 97%
# Iteration 1; 77/469 	Minibatch Loss 0.177  Accuracy 93%
# Iteration 1; 78/469 	Minibatch Loss 0.201  Accuracy 93%
# Iteration 1; 79/469 	Minibatch Loss 0.126  Accuracy 98%
# Iteration 1; 80/469 	Minibatch Loss 0.230  Accuracy 94%
# Iteration 1; 81/469 	Minibatch Loss 0.124  Accuracy 98%
# Iteration 1; 82/469 	Minibatch Loss 0.196  Accuracy 95%
# Iteration 1; 83/469 	Minibatch Loss 0.243  Accuracy 92%
# Iteration 1; 84/469 	Minibatch Loss 0.181  Accuracy 94%
# Iteration 1; 85/469 	Minibatch Loss 0.269  Accuracy 95%
# Iteration 1; 86/469 	Minibatch Loss 0.119  Accuracy 98%
# Iteration 1; 87/469 	Minibatch Loss 0.166  Accuracy 97%
# Iteration 1; 88/469 	Minibatch Loss 0.174  Accuracy 94%
# Iteration 1; 89/469 	Minibatch Loss 0.128  Accuracy 97%
# Iteration 1; 90/469 	Minibatch Loss 0.130  Accuracy 95%
# Iteration 1; 91/469 	Minibatch Loss 0.160  Accuracy 95%
# Iteration 1; 92/469 	Minibatch Loss 0.199  Accuracy 92%
# Iteration 1; 93/469 	Minibatch Loss 0.268  Accuracy 91%
# Iteration 1; 94/469 	Minibatch Loss 0.206  Accuracy 93%
# Iteration 1; 95/469 	Minibatch Loss 0.159  Accuracy 95%
# Iteration 1; 96/469 	Minibatch Loss 0.154  Accuracy 96%
# Iteration 1; 97/469 	Minibatch Loss 0.183  Accuracy 94%
# Iteration 1; 98/469 	Minibatch Loss 0.146  Accuracy 95%
# Iteration 1; 99/469 	Minibatch Loss 0.233  Accuracy 91%
# Iteration 1; 100/469 	Minibatch Loss 0.239  Accuracy 92%
# Iteration 1; 101/469 	Minibatch Loss 0.187  Accuracy 94%
# Iteration 1; 102/469 	Minibatch Loss 0.181  Accuracy 94%
# Iteration 1; 103/469 	Minibatch Loss 0.086  Accuracy 98%
# Iteration 1; 104/469 	Minibatch Loss 0.122  Accuracy 97%
# Iteration 1; 105/469 	Minibatch Loss 0.108  Accuracy 98%
# Iteration 1; 106/469 	Minibatch Loss 0.173  Accuracy 98%
# Iteration 1; 107/469 	Minibatch Loss 0.129  Accuracy 98%
# Iteration 1; 108/469 	Minibatch Loss 0.265  Accuracy 90%
# Iteration 1; 109/469 	Minibatch Loss 0.262  Accuracy 93%
# Iteration 1; 110/469 	Minibatch Loss 0.259  Accuracy 90%
# Iteration 1; 111/469 	Minibatch Loss 0.128  Accuracy 96%
# Iteration 1; 112/469 	Minibatch Loss 0.260  Accuracy 92%
# Iteration 1; 113/469 	Minibatch Loss 0.161  Accuracy 95%
# Iteration 1; 114/469 	Minibatch Loss 0.168  Accuracy 95%
# Iteration 1; 115/469 	Minibatch Loss 0.297  Accuracy 92%
# Iteration 1; 116/469 	Minibatch Loss 0.164  Accuracy 95%
# Iteration 1; 117/469 	Minibatch Loss 0.118  Accuracy 95%
# Iteration 1; 118/469 	Minibatch Loss 0.188  Accuracy 95%
# Iteration 1; 119/469 	Minibatch Loss 0.174  Accuracy 95%
# Iteration 1; 120/469 	Minibatch Loss 0.213  Accuracy 94%
# Iteration 1; 121/469 	Minibatch Loss 0.138  Accuracy 95%
# Iteration 1; 122/469 	Minibatch Loss 0.153  Accuracy 95%
# Iteration 1; 123/469 	Minibatch Loss 0.118  Accuracy 97%
# Iteration 1; 124/469 	Minibatch Loss 0.213  Accuracy 92%
# Iteration 1; 125/469 	Minibatch Loss 0.298  Accuracy 92%
# Iteration 1; 126/469 	Minibatch Loss 0.130  Accuracy 97%
# Iteration 1; 127/469 	Minibatch Loss 0.316  Accuracy 92%
# Iteration 1; 128/469 	Minibatch Loss 0.206  Accuracy 95%
# Iteration 1; 129/469 	Minibatch Loss 0.195  Accuracy 92%
# Iteration 1; 130/469 	Minibatch Loss 0.128  Accuracy 97%
# Iteration 1; 131/469 	Minibatch Loss 0.230  Accuracy 94%
# Iteration 1; 132/469 	Minibatch Loss 0.342  Accuracy 91%
# Iteration 1; 133/469 	Minibatch Loss 0.259  Accuracy 91%
# Iteration 1; 134/469 	Minibatch Loss 0.140  Accuracy 95%
# Iteration 1; 135/469 	Minibatch Loss 0.182  Accuracy 96%
# Iteration 1; 136/469 	Minibatch Loss 0.264  Accuracy 94%
# Iteration 1; 137/469 	Minibatch Loss 0.161  Accuracy 95%
# Iteration 1; 138/469 	Minibatch Loss 0.282  Accuracy 88%
# Iteration 1; 139/469 	Minibatch Loss 0.235  Accuracy 95%
# Iteration 1; 140/469 	Minibatch Loss 0.136  Accuracy 97%
# Iteration 1; 141/469 	Minibatch Loss 0.154  Accuracy 95%
# Iteration 1; 142/469 	Minibatch Loss 0.194  Accuracy 94%
# Iteration 1; 143/469 	Minibatch Loss 0.172  Accuracy 95%
# Iteration 1; 144/469 	Minibatch Loss 0.284  Accuracy 95%
# Iteration 1; 145/469 	Minibatch Loss 0.273  Accuracy 91%
# Iteration 1; 146/469 	Minibatch Loss 0.190  Accuracy 95%
# Iteration 1; 147/469 	Minibatch Loss 0.083  Accuracy 99%
# Iteration 1; 148/469 	Minibatch Loss 0.235  Accuracy 95%
# Iteration 1; 149/469 	Minibatch Loss 0.117  Accuracy 98%
# Iteration 1; 150/469 	Minibatch Loss 0.238  Accuracy 92%
# Iteration 1; 151/469 	Minibatch Loss 0.249  Accuracy 92%
# Iteration 1; 152/469 	Minibatch Loss 0.198  Accuracy 92%
# Iteration 1; 153/469 	Minibatch Loss 0.258  Accuracy 92%
# Iteration 1; 154/469 	Minibatch Loss 0.229  Accuracy 93%
# Iteration 1; 155/469 	Minibatch Loss 0.196  Accuracy 95%
# Iteration 1; 156/469 	Minibatch Loss 0.247  Accuracy 93%
# Iteration 1; 157/469 	Minibatch Loss 0.208  Accuracy 95%
# Iteration 1; 158/469 	Minibatch Loss 0.203  Accuracy 94%
# Iteration 1; 159/469 	Minibatch Loss 0.257  Accuracy 89%
# Iteration 1; 160/469 	Minibatch Loss 0.136  Accuracy 98%
# Iteration 1; 161/469 	Minibatch Loss 0.219  Accuracy 95%
# Iteration 1; 162/469 	Minibatch Loss 0.226  Accuracy 94%
# Iteration 1; 163/469 	Minibatch Loss 0.128  Accuracy 96%
# Iteration 1; 164/469 	Minibatch Loss 0.143  Accuracy 93%
# Iteration 1; 165/469 	Minibatch Loss 0.191  Accuracy 95%
# Iteration 1; 166/469 	Minibatch Loss 0.142  Accuracy 97%
# Iteration 1; 167/469 	Minibatch Loss 0.167  Accuracy 95%
# Iteration 1; 168/469 	Minibatch Loss 0.229  Accuracy 91%
# Iteration 1; 169/469 	Minibatch Loss 0.223  Accuracy 92%
# Iteration 1; 170/469 	Minibatch Loss 0.157  Accuracy 95%
# Iteration 1; 171/469 	Minibatch Loss 0.191  Accuracy 95%
# Iteration 1; 172/469 	Minibatch Loss 0.153  Accuracy 98%
# Iteration 1; 173/469 	Minibatch Loss 0.253  Accuracy 92%
# Iteration 1; 174/469 	Minibatch Loss 0.203  Accuracy 95%
# Iteration 1; 175/469 	Minibatch Loss 0.229  Accuracy 95%
# Iteration 1; 176/469 	Minibatch Loss 0.111  Accuracy 98%
# Iteration 1; 177/469 	Minibatch Loss 0.213  Accuracy 93%
# Iteration 1; 178/469 	Minibatch Loss 0.201  Accuracy 96%
# Iteration 1; 179/469 	Minibatch Loss 0.162  Accuracy 95%
# Iteration 1; 180/469 	Minibatch Loss 0.282  Accuracy 90%
# Iteration 1; 181/469 	Minibatch Loss 0.086  Accuracy 99%
# Iteration 1; 182/469 	Minibatch Loss 0.197  Accuracy 94%
# Iteration 1; 183/469 	Minibatch Loss 0.226  Accuracy 93%
# Iteration 1; 184/469 	Minibatch Loss 0.195  Accuracy 95%
# Iteration 1; 185/469 	Minibatch Loss 0.201  Accuracy 92%
# Iteration 1; 186/469 	Minibatch Loss 0.222  Accuracy 93%
# Iteration 1; 187/469 	Minibatch Loss 0.155  Accuracy 96%
# Iteration 1; 188/469 	Minibatch Loss 0.176  Accuracy 95%
# Iteration 1; 189/469 	Minibatch Loss 0.125  Accuracy 98%
# Iteration 1; 190/469 	Minibatch Loss 0.159  Accuracy 94%
# Iteration 1; 191/469 	Minibatch Loss 0.201  Accuracy 96%
# Iteration 1; 192/469 	Minibatch Loss 0.265  Accuracy 94%
# Iteration 1; 193/469 	Minibatch Loss 0.228  Accuracy 92%
# Iteration 1; 194/469 	Minibatch Loss 0.233  Accuracy 93%
# Iteration 1; 195/469 	Minibatch Loss 0.163  Accuracy 96%
# Iteration 1; 196/469 	Minibatch Loss 0.174  Accuracy 96%
# Iteration 1; 197/469 	Minibatch Loss 0.246  Accuracy 93%
# Iteration 1; 198/469 	Minibatch Loss 0.178  Accuracy 95%
# Iteration 1; 199/469 	Minibatch Loss 0.229  Accuracy 95%
# Iteration 1; 200/469 	Minibatch Loss 0.180  Accuracy 94%
# Iteration 1; 201/469 	Minibatch Loss 0.185  Accuracy 94%
# Iteration 1; 202/469 	Minibatch Loss 0.275  Accuracy 95%
# Iteration 1; 203/469 	Minibatch Loss 0.133  Accuracy 97%
# Iteration 1; 204/469 	Minibatch Loss 0.136  Accuracy 96%
# Iteration 1; 205/469 	Minibatch Loss 0.147  Accuracy 97%
# Iteration 1; 206/469 	Minibatch Loss 0.369  Accuracy 88%
# Iteration 1; 207/469 	Minibatch Loss 0.208  Accuracy 95%
# Iteration 1; 208/469 	Minibatch Loss 0.174  Accuracy 94%
# Iteration 1; 209/469 	Minibatch Loss 0.127  Accuracy 97%
# Iteration 1; 210/469 	Minibatch Loss 0.153  Accuracy 95%
# Iteration 1; 211/469 	Minibatch Loss 0.194  Accuracy 95%
# Iteration 1; 212/469 	Minibatch Loss 0.121  Accuracy 98%
# Iteration 1; 213/469 	Minibatch Loss 0.195  Accuracy 92%
# Iteration 1; 214/469 	Minibatch Loss 0.148  Accuracy 95%
# Iteration 1; 215/469 	Minibatch Loss 0.187  Accuracy 95%
# Iteration 1; 216/469 	Minibatch Loss 0.302  Accuracy 91%
# Iteration 1; 217/469 	Minibatch Loss 0.211  Accuracy 95%
# Iteration 1; 218/469 	Minibatch Loss 0.217  Accuracy 94%
# Iteration 1; 219/469 	Minibatch Loss 0.210  Accuracy 93%
# Iteration 1; 220/469 	Minibatch Loss 0.177  Accuracy 95%
# Iteration 1; 221/469 	Minibatch Loss 0.235  Accuracy 90%
# Iteration 1; 222/469 	Minibatch Loss 0.158  Accuracy 95%
# Iteration 1; 223/469 	Minibatch Loss 0.128  Accuracy 96%
# Iteration 1; 224/469 	Minibatch Loss 0.190  Accuracy 93%
# Iteration 1; 225/469 	Minibatch Loss 0.187  Accuracy 94%
# Iteration 1; 226/469 	Minibatch Loss 0.270  Accuracy 94%
# Iteration 1; 227/469 	Minibatch Loss 0.155  Accuracy 96%
# Iteration 1; 228/469 	Minibatch Loss 0.282  Accuracy 91%
# Iteration 1; 229/469 	Minibatch Loss 0.186  Accuracy 96%
# Iteration 1; 230/469 	Minibatch Loss 0.228  Accuracy 94%
# Iteration 1; 231/469 	Minibatch Loss 0.149  Accuracy 95%
# Iteration 1; 232/469 	Minibatch Loss 0.295  Accuracy 91%
# Iteration 1; 233/469 	Minibatch Loss 0.199  Accuracy 96%
# Iteration 1; 234/469 	Minibatch Loss 0.172  Accuracy 93%
# Iteration 1; 235/469 	Minibatch Loss 0.247  Accuracy 89%
# Iteration 1; 236/469 	Minibatch Loss 0.172  Accuracy 98%
# Iteration 1; 237/469 	Minibatch Loss 0.238  Accuracy 93%
# Iteration 1; 238/469 	Minibatch Loss 0.193  Accuracy 95%
# Iteration 1; 239/469 	Minibatch Loss 0.227  Accuracy 93%
# Iteration 1; 240/469 	Minibatch Loss 0.190  Accuracy 93%
# Iteration 1; 241/469 	Minibatch Loss 0.114  Accuracy 98%
# Iteration 1; 242/469 	Minibatch Loss 0.166  Accuracy 95%
# Iteration 1; 243/469 	Minibatch Loss 0.158  Accuracy 95%
# Iteration 1; 244/469 	Minibatch Loss 0.124  Accuracy 98%
# Iteration 1; 245/469 	Minibatch Loss 0.168  Accuracy 95%
# Iteration 1; 246/469 	Minibatch Loss 0.144  Accuracy 97%
# Iteration 1; 247/469 	Minibatch Loss 0.121  Accuracy 95%
# Iteration 1; 248/469 	Minibatch Loss 0.175  Accuracy 96%
# Iteration 1; 249/469 	Minibatch Loss 0.236  Accuracy 95%
# Iteration 1; 250/469 	Minibatch Loss 0.213  Accuracy 93%
# Iteration 1; 251/469 	Minibatch Loss 0.199  Accuracy 93%
# Iteration 1; 252/469 	Minibatch Loss 0.168  Accuracy 95%
# Iteration 1; 253/469 	Minibatch Loss 0.160  Accuracy 95%
# Iteration 1; 254/469 	Minibatch Loss 0.179  Accuracy 95%
# Iteration 1; 255/469 	Minibatch Loss 0.189  Accuracy 94%
# Iteration 1; 256/469 	Minibatch Loss 0.163  Accuracy 95%
# Iteration 1; 257/469 	Minibatch Loss 0.121  Accuracy 98%
# Iteration 1; 258/469 	Minibatch Loss 0.166  Accuracy 94%
# Iteration 1; 259/469 	Minibatch Loss 0.106  Accuracy 98%
# Iteration 1; 260/469 	Minibatch Loss 0.259  Accuracy 92%
# Iteration 1; 261/469 	Minibatch Loss 0.119  Accuracy 96%
# Iteration 1; 262/469 	Minibatch Loss 0.129  Accuracy 95%
# Iteration 1; 263/469 	Minibatch Loss 0.177  Accuracy 95%
# Iteration 1; 264/469 	Minibatch Loss 0.138  Accuracy 97%
# Iteration 1; 265/469 	Minibatch Loss 0.096  Accuracy 96%
# Iteration 1; 266/469 	Minibatch Loss 0.156  Accuracy 97%
# Iteration 1; 267/469 	Minibatch Loss 0.262  Accuracy 95%
# Iteration 1; 268/469 	Minibatch Loss 0.201  Accuracy 95%
# Iteration 1; 269/469 	Minibatch Loss 0.178  Accuracy 93%
# Iteration 1; 270/469 	Minibatch Loss 0.156  Accuracy 95%
# Iteration 1; 271/469 	Minibatch Loss 0.176  Accuracy 94%
# Iteration 1; 272/469 	Minibatch Loss 0.095  Accuracy 98%
# Iteration 1; 273/469 	Minibatch Loss 0.123  Accuracy 95%
# Iteration 1; 274/469 	Minibatch Loss 0.053  Accuracy 99%
# Iteration 1; 275/469 	Minibatch Loss 0.104  Accuracy 97%
# Iteration 1; 276/469 	Minibatch Loss 0.228  Accuracy 94%
# Iteration 1; 277/469 	Minibatch Loss 0.155  Accuracy 96%
# Iteration 1; 278/469 	Minibatch Loss 0.166  Accuracy 94%
# Iteration 1; 279/469 	Minibatch Loss 0.200  Accuracy 91%
# Iteration 1; 280/469 	Minibatch Loss 0.174  Accuracy 96%
# Iteration 1; 281/469 	Minibatch Loss 0.124  Accuracy 95%
# Iteration 1; 282/469 	Minibatch Loss 0.245  Accuracy 94%
# Iteration 1; 283/469 	Minibatch Loss 0.141  Accuracy 96%
# Iteration 1; 284/469 	Minibatch Loss 0.132  Accuracy 96%
# Iteration 1; 285/469 	Minibatch Loss 0.187  Accuracy 93%
# Iteration 1; 286/469 	Minibatch Loss 0.127  Accuracy 97%
# Iteration 1; 287/469 	Minibatch Loss 0.190  Accuracy 95%
# Iteration 1; 288/469 	Minibatch Loss 0.144  Accuracy 96%
# Iteration 1; 289/469 	Minibatch Loss 0.096  Accuracy 98%
# Iteration 1; 290/469 	Minibatch Loss 0.110  Accuracy 97%
# Iteration 1; 291/469 	Minibatch Loss 0.221  Accuracy 94%
# Iteration 1; 292/469 	Minibatch Loss 0.164  Accuracy 94%
# Iteration 1; 293/469 	Minibatch Loss 0.189  Accuracy 92%
# Iteration 1; 294/469 	Minibatch Loss 0.119  Accuracy 98%
# Iteration 1; 295/469 	Minibatch Loss 0.108  Accuracy 98%
# Iteration 1; 296/469 	Minibatch Loss 0.195  Accuracy 92%
# Iteration 1; 297/469 	Minibatch Loss 0.184  Accuracy 95%
# Iteration 1; 298/469 	Minibatch Loss 0.170  Accuracy 94%
# Iteration 1; 299/469 	Minibatch Loss 0.233  Accuracy 94%
# Iteration 1; 300/469 	Minibatch Loss 0.171  Accuracy 96%
# Iteration 1; 301/469 	Minibatch Loss 0.170  Accuracy 95%
# Iteration 1; 302/469 	Minibatch Loss 0.208  Accuracy 93%
# Iteration 1; 303/469 	Minibatch Loss 0.133  Accuracy 95%
# Iteration 1; 304/469 	Minibatch Loss 0.139  Accuracy 96%
# Iteration 1; 305/469 	Minibatch Loss 0.230  Accuracy 92%
# Iteration 1; 306/469 	Minibatch Loss 0.116  Accuracy 95%
# Iteration 1; 307/469 	Minibatch Loss 0.161  Accuracy 95%
# Iteration 1; 308/469 	Minibatch Loss 0.133  Accuracy 96%
# Iteration 1; 309/469 	Minibatch Loss 0.140  Accuracy 95%
# Iteration 1; 310/469 	Minibatch Loss 0.211  Accuracy 94%
# Iteration 1; 311/469 	Minibatch Loss 0.087  Accuracy 98%
# Iteration 1; 312/469 	Minibatch Loss 0.159  Accuracy 96%
# Iteration 1; 313/469 	Minibatch Loss 0.139  Accuracy 97%
# Iteration 1; 314/469 	Minibatch Loss 0.174  Accuracy 94%
# Iteration 1; 315/469 	Minibatch Loss 0.189  Accuracy 96%
# Iteration 1; 316/469 	Minibatch Loss 0.164  Accuracy 95%
# Iteration 1; 317/469 	Minibatch Loss 0.092  Accuracy 98%
# Iteration 1; 318/469 	Minibatch Loss 0.275  Accuracy 93%
# Iteration 1; 319/469 	Minibatch Loss 0.153  Accuracy 96%
# Iteration 1; 320/469 	Minibatch Loss 0.134  Accuracy 98%
# Iteration 1; 321/469 	Minibatch Loss 0.099  Accuracy 97%
# Iteration 1; 322/469 	Minibatch Loss 0.161  Accuracy 95%
# Iteration 1; 323/469 	Minibatch Loss 0.114  Accuracy 95%
# Iteration 1; 324/469 	Minibatch Loss 0.189  Accuracy 95%
# Iteration 1; 325/469 	Minibatch Loss 0.182  Accuracy 94%
# Iteration 1; 326/469 	Minibatch Loss 0.147  Accuracy 97%
# Iteration 1; 327/469 	Minibatch Loss 0.198  Accuracy 96%
# Iteration 1; 328/469 	Minibatch Loss 0.186  Accuracy 95%
# Iteration 1; 329/469 	Minibatch Loss 0.137  Accuracy 94%
# Iteration 1; 330/469 	Minibatch Loss 0.131  Accuracy 95%
# Iteration 1; 331/469 	Minibatch Loss 0.169  Accuracy 97%
# Iteration 1; 332/469 	Minibatch Loss 0.094  Accuracy 98%
# Iteration 1; 333/469 	Minibatch Loss 0.149  Accuracy 95%
# Iteration 1; 334/469 	Minibatch Loss 0.185  Accuracy 95%
# Iteration 1; 335/469 	Minibatch Loss 0.105  Accuracy 97%
# Iteration 1; 336/469 	Minibatch Loss 0.147  Accuracy 95%
# Iteration 1; 337/469 	Minibatch Loss 0.188  Accuracy 96%
# Iteration 1; 338/469 	Minibatch Loss 0.160  Accuracy 96%
# Iteration 1; 339/469 	Minibatch Loss 0.077  Accuracy 98%
# Iteration 1; 340/469 	Minibatch Loss 0.244  Accuracy 93%
# Iteration 1; 341/469 	Minibatch Loss 0.122  Accuracy 95%
# Iteration 1; 342/469 	Minibatch Loss 0.175  Accuracy 97%
# Iteration 1; 343/469 	Minibatch Loss 0.156  Accuracy 96%
# Iteration 1; 344/469 	Minibatch Loss 0.157  Accuracy 95%
# Iteration 1; 345/469 	Minibatch Loss 0.170  Accuracy 95%
# Iteration 1; 346/469 	Minibatch Loss 0.109  Accuracy 97%
# Iteration 1; 347/469 	Minibatch Loss 0.280  Accuracy 96%
# Iteration 1; 348/469 	Minibatch Loss 0.228  Accuracy 95%
# Iteration 1; 349/469 	Minibatch Loss 0.134  Accuracy 96%
# Iteration 1; 350/469 	Minibatch Loss 0.120  Accuracy 96%
# Iteration 1; 351/469 	Minibatch Loss 0.101  Accuracy 98%
# Iteration 1; 352/469 	Minibatch Loss 0.115  Accuracy 96%
# Iteration 1; 353/469 	Minibatch Loss 0.144  Accuracy 94%
# Iteration 1; 354/469 	Minibatch Loss 0.100  Accuracy 97%
# Iteration 1; 355/469 	Minibatch Loss 0.141  Accuracy 95%
# Iteration 1; 356/469 	Minibatch Loss 0.167  Accuracy 96%
# Iteration 1; 357/469 	Minibatch Loss 0.179  Accuracy 95%
# Iteration 1; 358/469 	Minibatch Loss 0.222  Accuracy 91%
# Iteration 1; 359/469 	Minibatch Loss 0.107  Accuracy 97%
# Iteration 1; 360/469 	Minibatch Loss 0.163  Accuracy 95%
# Iteration 1; 361/469 	Minibatch Loss 0.141  Accuracy 95%
# Iteration 1; 362/469 	Minibatch Loss 0.144  Accuracy 95%
# Iteration 1; 363/469 	Minibatch Loss 0.188  Accuracy 93%
# Iteration 1; 364/469 	Minibatch Loss 0.210  Accuracy 94%
# Iteration 1; 365/469 	Minibatch Loss 0.154  Accuracy 95%
# Iteration 1; 366/469 	Minibatch Loss 0.172  Accuracy 95%
# Iteration 1; 367/469 	Minibatch Loss 0.149  Accuracy 97%
# Iteration 1; 368/469 	Minibatch Loss 0.066  Accuracy 98%
# Iteration 1; 369/469 	Minibatch Loss 0.297  Accuracy 91%
# Iteration 1; 370/469 	Minibatch Loss 0.208  Accuracy 94%
# Iteration 1; 371/469 	Minibatch Loss 0.176  Accuracy 95%
# Iteration 1; 372/469 	Minibatch Loss 0.083  Accuracy 98%
# Iteration 1; 373/469 	Minibatch Loss 0.115  Accuracy 95%
# Iteration 1; 374/469 	Minibatch Loss 0.104  Accuracy 97%
# Iteration 1; 375/469 	Minibatch Loss 0.088  Accuracy 97%
# ...
# Iteration 5; 190/469 	Minibatch Loss 0.075  Accuracy 98%
# Iteration 5; 191/469 	Minibatch Loss 0.088  Accuracy 98%
# Iteration 5; 192/469 	Minibatch Loss 0.052  Accuracy 98%
# Iteration 5; 193/469 	Minibatch Loss 0.078  Accuracy 98%
# Iteration 5; 194/469 	Minibatch Loss 0.072  Accuracy 97%
# Iteration 5; 195/469 	Minibatch Loss 0.056  Accuracy 97%
# Iteration 5; 196/469 	Minibatch Loss 0.111  Accuracy 95%
# Iteration 5; 197/469 	Minibatch Loss 0.071  Accuracy 98%
# Iteration 5; 198/469 	Minibatch Loss 0.052  Accuracy 98%
# Iteration 5; 199/469 	Minibatch Loss 0.072  Accuracy 97%
# Iteration 5; 200/469 	Minibatch Loss 0.148  Accuracy 96%
# Iteration 5; 201/469 	Minibatch Loss 0.085  Accuracy 98%
# Iteration 5; 202/469 	Minibatch Loss 0.109  Accuracy 97%
# Iteration 5; 203/469 	Minibatch Loss 0.041  Accuracy 98%
# Iteration 5; 204/469 	Minibatch Loss 0.039  Accuracy 98%
# Iteration 5; 205/469 	Minibatch Loss 0.037  Accuracy 99%
# Iteration 5; 206/469 	Minibatch Loss 0.082  Accuracy 98%
# Iteration 5; 207/469 	Minibatch Loss 0.053  Accuracy 98%
# Iteration 5; 208/469 	Minibatch Loss 0.173  Accuracy 97%
# Iteration 5; 209/469 	Minibatch Loss 0.069  Accuracy 98%
# Iteration 5; 210/469 	Minibatch Loss 0.064  Accuracy 98%
# Iteration 5; 211/469 	Minibatch Loss 0.033  Accuracy 98%
# Iteration 5; 212/469 	Minibatch Loss 0.053  Accuracy 98%
# Iteration 5; 213/469 	Minibatch Loss 0.054  Accuracy 98%
# Iteration 5; 214/469 	Minibatch Loss 0.060  Accuracy 98%
# Iteration 5; 215/469 	Minibatch Loss 0.083  Accuracy 97%
# Iteration 5; 216/469 	Minibatch Loss 0.065  Accuracy 98%
# Iteration 5; 217/469 	Minibatch Loss 0.085  Accuracy 98%
# Iteration 5; 218/469 	Minibatch Loss 0.082  Accuracy 98%
# Iteration 5; 219/469 	Minibatch Loss 0.044  Accuracy 99%
# Iteration 5; 220/469 	Minibatch Loss 0.060  Accuracy 98%
# Iteration 5; 221/469 	Minibatch Loss 0.038  Accuracy 99%
# Iteration 5; 222/469 	Minibatch Loss 0.042  Accuracy 98%
# Iteration 5; 223/469 	Minibatch Loss 0.095  Accuracy 98%
# Iteration 5; 224/469 	Minibatch Loss 0.071  Accuracy 98%
# Iteration 5; 225/469 	Minibatch Loss 0.094  Accuracy 98%
# Iteration 5; 226/469 	Minibatch Loss 0.079  Accuracy 98%
# Iteration 5; 227/469 	Minibatch Loss 0.040  Accuracy 98%
# Iteration 5; 228/469 	Minibatch Loss 0.026  Accuracy 99%
# Iteration 5; 229/469 	Minibatch Loss 0.035  Accuracy 99%
# Iteration 5; 230/469 	Minibatch Loss 0.057  Accuracy 98%
# Iteration 5; 231/469 	Minibatch Loss 0.191  Accuracy 95%
# Iteration 5; 232/469 	Minibatch Loss 0.085  Accuracy 96%
# Iteration 5; 233/469 	Minibatch Loss 0.070  Accuracy 98%
# Iteration 5; 234/469 	Minibatch Loss 0.036  Accuracy 99%
# Iteration 5; 235/469 	Minibatch Loss 0.096  Accuracy 96%
# Iteration 5; 236/469 	Minibatch Loss 0.051  Accuracy 98%
# Iteration 5; 237/469 	Minibatch Loss 0.071  Accuracy 97%
# Iteration 5; 238/469 	Minibatch Loss 0.077  Accuracy 98%
# Iteration 5; 239/469 	Minibatch Loss 0.073  Accuracy 96%
# Iteration 5; 240/469 	Minibatch Loss 0.060  Accuracy 98%
# Iteration 5; 241/469 	Minibatch Loss 0.079  Accuracy 98%
# Iteration 5; 242/469 	Minibatch Loss 0.060  Accuracy 98%
# Iteration 5; 243/469 	Minibatch Loss 0.069  Accuracy 99%
# Iteration 5; 244/469 	Minibatch Loss 0.063  Accuracy 97%
# Iteration 5; 245/469 	Minibatch Loss 0.066  Accuracy 99%
# Iteration 5; 246/469 	Minibatch Loss 0.084  Accuracy 98%
# Iteration 5; 247/469 	Minibatch Loss 0.065  Accuracy 98%
# Iteration 5; 248/469 	Minibatch Loss 0.084  Accuracy 97%
# Iteration 5; 249/469 	Minibatch Loss 0.068  Accuracy 97%
# Iteration 5; 250/469 	Minibatch Loss 0.043  Accuracy 99%
# Iteration 5; 251/469 	Minibatch Loss 0.130  Accuracy 94%
# Iteration 5; 252/469 	Minibatch Loss 0.096  Accuracy 97%
# Iteration 5; 253/469 	Minibatch Loss 0.031  Accuracy 100%
# Iteration 5; 254/469 	Minibatch Loss 0.052  Accuracy 98%
# Iteration 5; 255/469 	Minibatch Loss 0.091  Accuracy 97%
# Iteration 5; 256/469 	Minibatch Loss 0.135  Accuracy 96%
# Iteration 5; 257/469 	Minibatch Loss 0.086  Accuracy 97%
# Iteration 5; 258/469 	Minibatch Loss 0.089  Accuracy 97%
# Iteration 5; 259/469 	Minibatch Loss 0.043  Accuracy 99%
# Iteration 5; 260/469 	Minibatch Loss 0.068  Accuracy 98%
# Iteration 5; 261/469 	Minibatch Loss 0.073  Accuracy 98%
# Iteration 5; 262/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 5; 263/469 	Minibatch Loss 0.086  Accuracy 97%
# Iteration 5; 264/469 	Minibatch Loss 0.059  Accuracy 98%
# Iteration 5; 265/469 	Minibatch Loss 0.022  Accuracy 100%
# Iteration 5; 266/469 	Minibatch Loss 0.080  Accuracy 99%
# Iteration 5; 267/469 	Minibatch Loss 0.091  Accuracy 98%
# Iteration 5; 268/469 	Minibatch Loss 0.074  Accuracy 97%
# Iteration 5; 269/469 	Minibatch Loss 0.055  Accuracy 98%
# Iteration 5; 270/469 	Minibatch Loss 0.032  Accuracy 99%
# Iteration 5; 271/469 	Minibatch Loss 0.099  Accuracy 97%
# Iteration 5; 272/469 	Minibatch Loss 0.077  Accuracy 96%
# Iteration 5; 273/469 	Minibatch Loss 0.038  Accuracy 100%
# Iteration 5; 274/469 	Minibatch Loss 0.091  Accuracy 98%
# Iteration 5; 275/469 	Minibatch Loss 0.054  Accuracy 98%
# Iteration 5; 276/469 	Minibatch Loss 0.061  Accuracy 98%
# Iteration 5; 277/469 	Minibatch Loss 0.075  Accuracy 96%
# Iteration 5; 278/469 	Minibatch Loss 0.108  Accuracy 95%
# Iteration 5; 279/469 	Minibatch Loss 0.020  Accuracy 100%
# Iteration 5; 280/469 	Minibatch Loss 0.152  Accuracy 97%
# Iteration 5; 281/469 	Minibatch Loss 0.088  Accuracy 98%
# Iteration 5; 282/469 	Minibatch Loss 0.020  Accuracy 100%
# Iteration 5; 283/469 	Minibatch Loss 0.035  Accuracy 98%
# Iteration 5; 284/469 	Minibatch Loss 0.104  Accuracy 98%
# Iteration 5; 285/469 	Minibatch Loss 0.042  Accuracy 100%
# Iteration 5; 286/469 	Minibatch Loss 0.062  Accuracy 98%
# Iteration 5; 287/469 	Minibatch Loss 0.042  Accuracy 98%
# Iteration 5; 288/469 	Minibatch Loss 0.118  Accuracy 96%
# Iteration 5; 289/469 	Minibatch Loss 0.030  Accuracy 99%
# Iteration 5; 290/469 	Minibatch Loss 0.073  Accuracy 97%
# Iteration 5; 291/469 	Minibatch Loss 0.145  Accuracy 97%
# Iteration 5; 292/469 	Minibatch Loss 0.104  Accuracy 97%
# Iteration 5; 293/469 	Minibatch Loss 0.034  Accuracy 99%
# Iteration 5; 294/469 	Minibatch Loss 0.059  Accuracy 98%
# Iteration 5; 295/469 	Minibatch Loss 0.086  Accuracy 97%
# Iteration 5; 296/469 	Minibatch Loss 0.067  Accuracy 98%
# Iteration 5; 297/469 	Minibatch Loss 0.041  Accuracy 99%
# Iteration 5; 298/469 	Minibatch Loss 0.068  Accuracy 99%
# Iteration 5; 299/469 	Minibatch Loss 0.048  Accuracy 98%
# Iteration 5; 300/469 	Minibatch Loss 0.143  Accuracy 95%
# Iteration 5; 301/469 	Minibatch Loss 0.052  Accuracy 98%
# Iteration 5; 302/469 	Minibatch Loss 0.084  Accuracy 98%
# Iteration 5; 303/469 	Minibatch Loss 0.074  Accuracy 98%
# Iteration 5; 304/469 	Minibatch Loss 0.079  Accuracy 96%
# Iteration 5; 305/469 	Minibatch Loss 0.064  Accuracy 98%
# Iteration 5; 306/469 	Minibatch Loss 0.159  Accuracy 96%
# Iteration 5; 307/469 	Minibatch Loss 0.033  Accuracy 99%
# Iteration 5; 308/469 	Minibatch Loss 0.099  Accuracy 98%
# Iteration 5; 309/469 	Minibatch Loss 0.093  Accuracy 98%
# Iteration 5; 310/469 	Minibatch Loss 0.035  Accuracy 100%
# Iteration 5; 311/469 	Minibatch Loss 0.053  Accuracy 98%
# Iteration 5; 312/469 	Minibatch Loss 0.109  Accuracy 95%
# Iteration 5; 313/469 	Minibatch Loss 0.051  Accuracy 99%
# Iteration 5; 314/469 	Minibatch Loss 0.060  Accuracy 98%
# Iteration 5; 315/469 	Minibatch Loss 0.038  Accuracy 98%
# Iteration 5; 316/469 	Minibatch Loss 0.022  Accuracy 100%
# Iteration 5; 317/469 	Minibatch Loss 0.067  Accuracy 98%
# Iteration 5; 318/469 	Minibatch Loss 0.177  Accuracy 96%
# Iteration 5; 319/469 	Minibatch Loss 0.118  Accuracy 95%
# Iteration 5; 320/469 	Minibatch Loss 0.104  Accuracy 96%
# Iteration 5; 321/469 	Minibatch Loss 0.100  Accuracy 97%
# Iteration 5; 322/469 	Minibatch Loss 0.074  Accuracy 98%
# Iteration 5; 323/469 	Minibatch Loss 0.034  Accuracy 99%
# Iteration 5; 324/469 	Minibatch Loss 0.051  Accuracy 98%
# Iteration 5; 325/469 	Minibatch Loss 0.086  Accuracy 98%
# Iteration 5; 326/469 	Minibatch Loss 0.051  Accuracy 99%
# Iteration 5; 327/469 	Minibatch Loss 0.047  Accuracy 99%
# Iteration 5; 328/469 	Minibatch Loss 0.105  Accuracy 97%
# Iteration 5; 329/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 5; 330/469 	Minibatch Loss 0.044  Accuracy 98%
# Iteration 5; 331/469 	Minibatch Loss 0.071  Accuracy 98%
# Iteration 5; 332/469 	Minibatch Loss 0.066  Accuracy 98%
# Iteration 5; 333/469 	Minibatch Loss 0.064  Accuracy 98%
# Iteration 5; 334/469 	Minibatch Loss 0.226  Accuracy 95%
# Iteration 5; 335/469 	Minibatch Loss 0.039  Accuracy 98%
# Iteration 5; 336/469 	Minibatch Loss 0.085  Accuracy 98%
# Iteration 5; 337/469 	Minibatch Loss 0.037  Accuracy 99%
# Iteration 5; 338/469 	Minibatch Loss 0.072  Accuracy 98%
# Iteration 5; 339/469 	Minibatch Loss 0.062  Accuracy 98%
# Iteration 5; 340/469 	Minibatch Loss 0.085  Accuracy 97%
# Iteration 5; 341/469 	Minibatch Loss 0.121  Accuracy 97%
# Iteration 5; 342/469 	Minibatch Loss 0.103  Accuracy 96%
# Iteration 5; 343/469 	Minibatch Loss 0.064  Accuracy 98%
# Iteration 5; 344/469 	Minibatch Loss 0.066  Accuracy 98%
# Iteration 5; 345/469 	Minibatch Loss 0.079  Accuracy 97%
# Iteration 5; 346/469 	Minibatch Loss 0.047  Accuracy 98%
# Iteration 5; 347/469 	Minibatch Loss 0.077  Accuracy 98%
# Iteration 5; 348/469 	Minibatch Loss 0.088  Accuracy 98%
# Iteration 5; 349/469 	Minibatch Loss 0.090  Accuracy 97%
# Iteration 5; 350/469 	Minibatch Loss 0.053  Accuracy 99%
# Iteration 5; 351/469 	Minibatch Loss 0.050  Accuracy 98%
# Iteration 5; 352/469 	Minibatch Loss 0.066  Accuracy 98%
# Iteration 5; 353/469 	Minibatch Loss 0.095  Accuracy 95%
# Iteration 5; 354/469 	Minibatch Loss 0.039  Accuracy 98%
# Iteration 5; 355/469 	Minibatch Loss 0.075  Accuracy 98%
# Iteration 5; 356/469 	Minibatch Loss 0.042  Accuracy 98%
# Iteration 5; 357/469 	Minibatch Loss 0.055  Accuracy 98%
# Iteration 5; 358/469 	Minibatch Loss 0.104  Accuracy 98%
# Iteration 5; 359/469 	Minibatch Loss 0.036  Accuracy 100%
# Iteration 5; 360/469 	Minibatch Loss 0.056  Accuracy 99%
# Iteration 5; 361/469 	Minibatch Loss 0.111  Accuracy 96%
# Iteration 5; 362/469 	Minibatch Loss 0.095  Accuracy 96%
# Iteration 5; 363/469 	Minibatch Loss 0.169  Accuracy 95%
# Iteration 5; 364/469 	Minibatch Loss 0.090  Accuracy 98%
# Iteration 5; 365/469 	Minibatch Loss 0.042  Accuracy 98%
# Iteration 5; 366/469 	Minibatch Loss 0.104  Accuracy 97%
# Iteration 5; 367/469 	Minibatch Loss 0.046  Accuracy 98%
# Iteration 5; 368/469 	Minibatch Loss 0.059  Accuracy 98%
# Iteration 5; 369/469 	Minibatch Loss 0.102  Accuracy 96%
# Iteration 5; 370/469 	Minibatch Loss 0.083  Accuracy 97%
# Iteration 5; 371/469 	Minibatch Loss 0.135  Accuracy 94%
# Iteration 5; 372/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 5; 373/469 	Minibatch Loss 0.026  Accuracy 100%
# Iteration 5; 374/469 	Minibatch Loss 0.083  Accuracy 97%
# Iteration 5; 375/469 	Minibatch Loss 0.135  Accuracy 95%
# Iteration 5; 376/469 	Minibatch Loss 0.068  Accuracy 97%
# Iteration 5; 377/469 	Minibatch Loss 0.038  Accuracy 100%
# Iteration 5; 378/469 	Minibatch Loss 0.045  Accuracy 98%
# Iteration 5; 379/469 	Minibatch Loss 0.045  Accuracy 99%
# Iteration 5; 380/469 	Minibatch Loss 0.049  Accuracy 98%
# Iteration 5; 381/469 	Minibatch Loss 0.141  Accuracy 95%
# Iteration 5; 382/469 	Minibatch Loss 0.117  Accuracy 97%
# Iteration 5; 383/469 	Minibatch Loss 0.034  Accuracy 99%
# Iteration 5; 384/469 	Minibatch Loss 0.134  Accuracy 98%
# Iteration 5; 385/469 	Minibatch Loss 0.044  Accuracy 98%
# Iteration 5; 386/469 	Minibatch Loss 0.042  Accuracy 98%
# Iteration 5; 387/469 	Minibatch Loss 0.048  Accuracy 99%
# Iteration 5; 388/469 	Minibatch Loss 0.087  Accuracy 97%
# Iteration 5; 389/469 	Minibatch Loss 0.101  Accuracy 96%
# Iteration 5; 390/469 	Minibatch Loss 0.055  Accuracy 98%
# Iteration 5; 391/469 	Minibatch Loss 0.074  Accuracy 98%
# Iteration 5; 392/469 	Minibatch Loss 0.063  Accuracy 97%
# Iteration 5; 393/469 	Minibatch Loss 0.059  Accuracy 98%
# Iteration 5; 394/469 	Minibatch Loss 0.042  Accuracy 98%
# Iteration 5; 395/469 	Minibatch Loss 0.060  Accuracy 98%
# Iteration 5; 396/469 	Minibatch Loss 0.042  Accuracy 100%
# Iteration 5; 397/469 	Minibatch Loss 0.079  Accuracy 97%
# Iteration 5; 398/469 	Minibatch Loss 0.123  Accuracy 97%
# Iteration 5; 399/469 	Minibatch Loss 0.141  Accuracy 98%
# Iteration 5; 400/469 	Minibatch Loss 0.087  Accuracy 98%
# Iteration 5; 401/469 	Minibatch Loss 0.034  Accuracy 100%
# Iteration 5; 402/469 	Minibatch Loss 0.041  Accuracy 98%
# Iteration 5; 403/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 5; 404/469 	Minibatch Loss 0.046  Accuracy 98%
# Iteration 5; 405/469 	Minibatch Loss 0.049  Accuracy 98%
# Iteration 5; 406/469 	Minibatch Loss 0.105  Accuracy 96%
# Iteration 5; 407/469 	Minibatch Loss 0.078  Accuracy 98%
# Iteration 5; 408/469 	Minibatch Loss 0.037  Accuracy 100%
# Iteration 5; 409/469 	Minibatch Loss 0.102  Accuracy 96%
# Iteration 5; 410/469 	Minibatch Loss 0.167  Accuracy 94%
# Iteration 5; 411/469 	Minibatch Loss 0.049  Accuracy 99%
# Iteration 5; 412/469 	Minibatch Loss 0.087  Accuracy 97%
# Iteration 5; 413/469 	Minibatch Loss 0.110  Accuracy 96%
# Iteration 5; 414/469 	Minibatch Loss 0.060  Accuracy 98%
# Iteration 5; 415/469 	Minibatch Loss 0.064  Accuracy 98%
# Iteration 5; 416/469 	Minibatch Loss 0.160  Accuracy 93%
# Iteration 5; 417/469 	Minibatch Loss 0.148  Accuracy 94%
# Iteration 5; 418/469 	Minibatch Loss 0.048  Accuracy 99%
# Iteration 5; 419/469 	Minibatch Loss 0.051  Accuracy 99%
# Iteration 5; 420/469 	Minibatch Loss 0.100  Accuracy 95%
# Iteration 5; 421/469 	Minibatch Loss 0.052  Accuracy 98%
# Iteration 5; 422/469 	Minibatch Loss 0.148  Accuracy 98%
# Iteration 5; 423/469 	Minibatch Loss 0.113  Accuracy 98%
# Iteration 5; 424/469 	Minibatch Loss 0.054  Accuracy 98%
# Iteration 5; 425/469 	Minibatch Loss 0.101  Accuracy 98%
# Iteration 5; 426/469 	Minibatch Loss 0.090  Accuracy 98%
# Iteration 5; 427/469 	Minibatch Loss 0.111  Accuracy 98%
# Iteration 5; 428/469 	Minibatch Loss 0.088  Accuracy 97%
# Iteration 5; 429/469 	Minibatch Loss 0.161  Accuracy 95%
# Iteration 5; 430/469 	Minibatch Loss 0.067  Accuracy 98%
# Iteration 5; 431/469 	Minibatch Loss 0.098  Accuracy 98%
# Iteration 5; 432/469 	Minibatch Loss 0.057  Accuracy 99%
# Iteration 5; 433/469 	Minibatch Loss 0.176  Accuracy 95%
# Iteration 5; 434/469 	Minibatch Loss 0.135  Accuracy 94%
# Iteration 5; 435/469 	Minibatch Loss 0.121  Accuracy 95%
# Iteration 5; 436/469 	Minibatch Loss 0.061  Accuracy 97%
# Iteration 5; 437/469 	Minibatch Loss 0.104  Accuracy 97%
# Iteration 5; 438/469 	Minibatch Loss 0.123  Accuracy 96%
# Iteration 5; 439/469 	Minibatch Loss 0.063  Accuracy 98%
# Iteration 5; 440/469 	Minibatch Loss 0.057  Accuracy 98%
# Iteration 5; 441/469 	Minibatch Loss 0.088  Accuracy 97%
# Iteration 5; 442/469 	Minibatch Loss 0.150  Accuracy 98%
# Iteration 5; 443/469 	Minibatch Loss 0.109  Accuracy 97%
# Iteration 5; 444/469 	Minibatch Loss 0.118  Accuracy 97%
# Iteration 5; 445/469 	Minibatch Loss 0.055  Accuracy 99%
# Iteration 5; 446/469 	Minibatch Loss 0.077  Accuracy 96%
# Iteration 5; 447/469 	Minibatch Loss 0.112  Accuracy 98%
# Iteration 5; 448/469 	Minibatch Loss 0.045  Accuracy 99%
# Iteration 5; 449/469 	Minibatch Loss 0.116  Accuracy 96%
# Iteration 5; 450/469 	Minibatch Loss 0.093  Accuracy 98%
# Iteration 5; 451/469 	Minibatch Loss 0.073  Accuracy 98%
# Iteration 5; 452/469 	Minibatch Loss 0.078  Accuracy 97%
# Iteration 5; 453/469 	Minibatch Loss 0.141  Accuracy 95%
# Iteration 5; 454/469 	Minibatch Loss 0.112  Accuracy 97%
# Iteration 5; 455/469 	Minibatch Loss 0.083  Accuracy 96%
# Iteration 5; 456/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 5; 457/469 	Minibatch Loss 0.081  Accuracy 98%
# Iteration 5; 458/469 	Minibatch Loss 0.079  Accuracy 97%
# Iteration 5; 459/469 	Minibatch Loss 0.102  Accuracy 96%
# Iteration 5; 460/469 	Minibatch Loss 0.113  Accuracy 98%
# Iteration 5; 461/469 	Minibatch Loss 0.054  Accuracy 97%
# Iteration 5; 462/469 	Minibatch Loss 0.168  Accuracy 95%
# Iteration 5; 463/469 	Minibatch Loss 0.025  Accuracy 100%
# Iteration 5; 464/469 	Minibatch Loss 0.058  Accuracy 98%
# Iteration 5; 465/469 	Minibatch Loss 0.051  Accuracy 98%
# Iteration 5; 466/469 	Minibatch Loss 0.056  Accuracy 99%
# Iteration 5; 467/469 	Minibatch Loss 0.087  Accuracy 99%
# Iteration 5; 468/469 	Minibatch Loss 0.021  Accuracy 100%
# saving model at: models/mnist_test_6iter_10c_simpleNN_100.pth

# %%
#predict in distribution
MNIST_PATH = "models/mnist_test_6iter_10c_simpleNN_100.pth"

mnist_model = LPADirNN(x=100)
print("loading model from: {}".format(MNIST_PATH))
mnist_model.load_state_dict(torch.load(MNIST_PATH))
mnist_model.eval()

acc = []

for batch_idx, (x, y) in enumerate(mnist_test_loader):
        max_len = int(np.ceil(len(mnist_test_loader.dataset)/BATCH_SIZE_TEST_MNIST))
        output = mnist_model(x)
        
        accuracy = get_accuracy(output, y)
        if batch_idx % 10 == 0:
            print(
                "Batch {}/{} \t".format(batch_idx, max_len) + 
                "Accuracy %.0f" % (accuracy * 100) + "%"
            )
        acc.append(accuracy)
    
avg_acc = np.mean(acc)
print('overall test accuracy on MNIST: {:.02f} %'.format(avg_acc * 100))
# Out:
# loading model from: models/mnist_test_6iter_10c_simpleNN_100.pth
# Batch 0/79 	Accuracy 99%
# Batch 10/79 	Accuracy 95%
# Batch 20/79 	Accuracy 97%
# Batch 30/79 	Accuracy 95%
# Batch 40/79 	Accuracy 98%
# Batch 50/79 	Accuracy 97%
# Batch 60/79 	Accuracy 99%
# Batch 70/79 	Accuracy 95%
# overall test accuracy on MNIST: 97.09 %

# %%
## play around with Backpack
lossfunc = torch.nn.CrossEntropyLoss()

extend(lossfunc, debug=False)
extend(mnist_model, debug=False)

device = 'cpu'

Hessian = []
for param in mnist_model.parameters():
    ps = param.size()
    print("parameter size: ", ps)
    Hessian.append(torch.zeros(ps, device=device))
    #print(param.numel())
    
batch_size = BATCH_SIZE_TRAIN_MNIST

tau = 1/10
    
with backpack(DiagHessian()):
    
    max_len = int(np.ceil(len(mnist_train_loader.dataset)/batch_size))
    
    for batch_idx, (x, y) in enumerate(mnist_train_loader):

        if device == 'cuda':
            x, y = torch.from_numpy(x).float().cuda(), torch.from_numpy(y).long().cuda()

        mnist_model.zero_grad()
        lossfunc(mnist_model(x), y).backward()

        with torch.no_grad():
            # Hessian of weight
            for idx, param in enumerate(mnist_model.parameters()):

                H_ = param.diag_h
                #print(H_.size())
                #H_ = np.sqrt(batch_size)*H_ + np.sqrt(tau)*torch.eye(H_.size(0), device=device)
                
                rho = min(1-1/(batch_idx+1), 0.95)

                Hessian[idx] = rho*Hessian[idx] + (1-rho)*H_

        print("Batch: {}/{}".format(batch_idx, max_len))
        
    #combine all elements of the Hessian to one big vector
    Hessian = torch.cat([el.view(-1) for el in Hessian])
    print("Hessian_size: ", Hessian.size())
    num_params = np.sum([p.numel() for p in mnist_model.parameters()])
    assert(num_params == Hessian.size(-1))
# Out:
# parameter size:  torch.Size([100, 784])
# parameter size:  torch.Size([100])
# parameter size:  torch.Size([100, 100])
# parameter size:  torch.Size([100])
# parameter size:  torch.Size([10, 100])
# parameter size:  torch.Size([10])
# Batch: 0/469
# Batch: 1/469
# Batch: 2/469
# Batch: 3/469
# Batch: 4/469
# Batch: 5/469
# Batch: 6/469
# Batch: 7/469
# Batch: 8/469
# Batch: 9/469
# Batch: 10/469
# Batch: 11/469
# Batch: 12/469
# Batch: 13/469
# Batch: 14/469
# Batch: 15/469
# Batch: 16/469
# Batch: 17/469
# Batch: 18/469
# Batch: 19/469
# Batch: 20/469
# Batch: 21/469
# Batch: 22/469
# Batch: 23/469
# Batch: 24/469
# Batch: 25/469
# Batch: 26/469
# Batch: 27/469
# Batch: 28/469
# Batch: 29/469
# Batch: 30/469
# Batch: 31/469
# Batch: 32/469
# Batch: 33/469
# Batch: 34/469
# Batch: 35/469
# Batch: 36/469
# Batch: 37/469
# Batch: 38/469
# Batch: 39/469
# Batch: 40/469
# Batch: 41/469
# Batch: 42/469
# Batch: 43/469
# Batch: 44/469
# Batch: 45/469
# Batch: 46/469
# Batch: 47/469
# Batch: 48/469
# Batch: 49/469
# Batch: 50/469
# Batch: 51/469
# Batch: 52/469
# Batch: 53/469
# Batch: 54/469
# Batch: 55/469
# Batch: 56/469
# Batch: 57/469
# Batch: 58/469
# Batch: 59/469
# Batch: 60/469
# Batch: 61/469
# Batch: 62/469
# Batch: 63/469
# Batch: 64/469
# Batch: 65/469
# Batch: 66/469
# Batch: 67/469
# Batch: 68/469
# Batch: 69/469
# Batch: 70/469
# Batch: 71/469
# Batch: 72/469
# Batch: 73/469
# Batch: 74/469
# Batch: 75/469
# Batch: 76/469
# Batch: 77/469
# Batch: 78/469
# Batch: 79/469
# Batch: 80/469
# Batch: 81/469
# Batch: 82/469
# Batch: 83/469
# Batch: 84/469
# Batch: 85/469
# Batch: 86/469
# Batch: 87/469
# Batch: 88/469
# Batch: 89/469
# Batch: 90/469
# Batch: 91/469
# Batch: 92/469
# Batch: 93/469
# Batch: 94/469
# Batch: 95/469
# Batch: 96/469
# Batch: 97/469
# Batch: 98/469
# Batch: 99/469
# Batch: 100/469
# Batch: 101/469
# Batch: 102/469
# Batch: 103/469
# Batch: 104/469
# Batch: 105/469
# Batch: 106/469
# Batch: 107/469
# Batch: 108/469
# Batch: 109/469
# Batch: 110/469
# Batch: 111/469
# Batch: 112/469
# Batch: 113/469
# Batch: 114/469
# Batch: 115/469
# Batch: 116/469
# Batch: 117/469
# Batch: 118/469
# Batch: 119/469
# Batch: 120/469
# Batch: 121/469
# Batch: 122/469
# Batch: 123/469
# Batch: 124/469
# Batch: 125/469
# Batch: 126/469
# Batch: 127/469
# Batch: 128/469
# Batch: 129/469
# Batch: 130/469
# Batch: 131/469
# Batch: 132/469
# Batch: 133/469
# Batch: 134/469
# Batch: 135/469
# Batch: 136/469
# Batch: 137/469
# Batch: 138/469
# Batch: 139/469
# Batch: 140/469
# Batch: 141/469
# Batch: 142/469
# Batch: 143/469
# Batch: 144/469
# Batch: 145/469
# Batch: 146/469
# Batch: 147/469
# Batch: 148/469
# Batch: 149/469
# Batch: 150/469
# Batch: 151/469
# Batch: 152/469
# Batch: 153/469
# Batch: 154/469
# Batch: 155/469
# Batch: 156/469
# Batch: 157/469
# Batch: 158/469
# Batch: 159/469
# Batch: 160/469
# Batch: 161/469
# Batch: 162/469
# Batch: 163/469
# Batch: 164/469
# Batch: 165/469
# Batch: 166/469
# Batch: 167/469
# Batch: 168/469
# Batch: 169/469
# Batch: 170/469
# Batch: 171/469
# Batch: 172/469
# Batch: 173/469
# Batch: 174/469
# Batch: 175/469
# Batch: 176/469
# Batch: 177/469
# Batch: 178/469
# Batch: 179/469
# Batch: 180/469
# Batch: 181/469
# Batch: 182/469
# Batch: 183/469
# Batch: 184/469
# Batch: 185/469
# Batch: 186/469
# Batch: 187/469
# Batch: 188/469
# Batch: 189/469
# Batch: 190/469
# Batch: 191/469
# Batch: 192/469
# Batch: 193/469
# Batch: 194/469
# Batch: 195/469
# Batch: 196/469
# Batch: 197/469
# Batch: 198/469
# Batch: 199/469
# Batch: 200/469
# Batch: 201/469
# Batch: 202/469
# Batch: 203/469
# Batch: 204/469
# Batch: 205/469
# Batch: 206/469
# Batch: 207/469
# Batch: 208/469
# Batch: 209/469
# Batch: 210/469
# Batch: 211/469
# Batch: 212/469
# Batch: 213/469
# Batch: 214/469
# Batch: 215/469
# Batch: 216/469
# Batch: 217/469
# Batch: 218/469
# Batch: 219/469
# Batch: 220/469
# Batch: 221/469
# Batch: 222/469
# Batch: 223/469
# Batch: 224/469
# Batch: 225/469
# Batch: 226/469
# Batch: 227/469
# Batch: 228/469
# Batch: 229/469
# Batch: 230/469
# Batch: 231/469
# Batch: 232/469
# Batch: 233/469
# Batch: 234/469
# Batch: 235/469
# Batch: 236/469
# Batch: 237/469
# Batch: 238/469
# Batch: 239/469
# Batch: 240/469
# Batch: 241/469
# Batch: 242/469
# Batch: 243/469
# Batch: 244/469
# Batch: 245/469
# Batch: 246/469
# Batch: 247/469
# Batch: 248/469
# Batch: 249/469
# Batch: 250/469
# Batch: 251/469
# Batch: 252/469
# Batch: 253/469
# Batch: 254/469
# Batch: 255/469
# Batch: 256/469
# Batch: 257/469
# Batch: 258/469
# Batch: 259/469
# Batch: 260/469
# Batch: 261/469
# Batch: 262/469
# Batch: 263/469
# Batch: 264/469
# Batch: 265/469
# Batch: 266/469
# Batch: 267/469
# Batch: 268/469
# Batch: 269/469
# Batch: 270/469
# Batch: 271/469
# Batch: 272/469
# Batch: 273/469
# Batch: 274/469
# Batch: 275/469
# Batch: 276/469
# Batch: 277/469
# Batch: 278/469
# Batch: 279/469
# Batch: 280/469
# Batch: 281/469
# Batch: 282/469
# Batch: 283/469
# Batch: 284/469
# Batch: 285/469
# Batch: 286/469
# Batch: 287/469
# Batch: 288/469
# Batch: 289/469
# Batch: 290/469
# Batch: 291/469
# Batch: 292/469
# Batch: 293/469
# Batch: 294/469
# Batch: 295/469
# Batch: 296/469
# Batch: 297/469
# Batch: 298/469
# Batch: 299/469
# Batch: 300/469
# Batch: 301/469
# Batch: 302/469
# Batch: 303/469
# Batch: 304/469
# Batch: 305/469
# Batch: 306/469
# Batch: 307/469
# Batch: 308/469
# Batch: 309/469
# Batch: 310/469
# Batch: 311/469
# Batch: 312/469
# Batch: 313/469
# Batch: 314/469
# Batch: 315/469
# Batch: 316/469
# Batch: 317/469
# Batch: 318/469
# Batch: 319/469
# Batch: 320/469
# Batch: 321/469
# Batch: 322/469
# Batch: 323/469
# Batch: 324/469
# Batch: 325/469
# Batch: 326/469
# Batch: 327/469
# Batch: 328/469
# Batch: 329/469
# Batch: 330/469
# Batch: 331/469
# Batch: 332/469
# Batch: 333/469
# Batch: 334/469
# Batch: 335/469
# Batch: 336/469
# Batch: 337/469
# Batch: 338/469
# Batch: 339/469
# Batch: 340/469
# Batch: 341/469
# Batch: 342/469
# Batch: 343/469
# Batch: 344/469
# Batch: 345/469
# Batch: 346/469
# Batch: 347/469
# Batch: 348/469
# Batch: 349/469
# Batch: 350/469
# Batch: 351/469
# Batch: 352/469
# Batch: 353/469
# Batch: 354/469
# Batch: 355/469
# Batch: 356/469
# Batch: 357/469
# Batch: 358/469
# Batch: 359/469
# Batch: 360/469
# Batch: 361/469
# Batch: 362/469
# Batch: 363/469
# Batch: 364/469
# Batch: 365/469
# Batch: 366/469
# Batch: 367/469
# Batch: 368/469
# Batch: 369/469
# Batch: 370/469
# Batch: 371/469
# Batch: 372/469
# Batch: 373/469
# Batch: 374/469
# Batch: 375/469
# Batch: 376/469
# Batch: 377/469
# Batch: 378/469
# Batch: 379/469
# Batch: 380/469
# Batch: 381/469
# Batch: 382/469
# Batch: 383/469
# Batch: 384/469
# Batch: 385/469
# Batch: 386/469
# Batch: 387/469
# Batch: 388/469
# Batch: 389/469
# Batch: 390/469
# Batch: 391/469
# Batch: 392/469
# Batch: 393/469
# Batch: 394/469
# Batch: 395/469
# Batch: 396/469
# Batch: 397/469
# Batch: 398/469
# Batch: 399/469
# Batch: 400/469
# Batch: 401/469
# Batch: 402/469
# Batch: 403/469
# Batch: 404/469
# Batch: 405/469
# Batch: 406/469
# Batch: 407/469
# Batch: 408/469
# Batch: 409/469
# Batch: 410/469
# Batch: 411/469
# Batch: 412/469
# Batch: 413/469
# Batch: 414/469
# Batch: 415/469
# Batch: 416/469
# Batch: 417/469
# Batch: 418/469
# Batch: 419/469
# Batch: 420/469
# Batch: 421/469
# Batch: 422/469
# Batch: 423/469
# Batch: 424/469
# Batch: 425/469
# Batch: 426/469
# Batch: 427/469
# Batch: 428/469
# Batch: 429/469
# Batch: 430/469
# Batch: 431/469
# Batch: 432/469
# Batch: 433/469
# Batch: 434/469
# Batch: 435/469
# Batch: 436/469
# Batch: 437/469
# Batch: 438/469
# Batch: 439/469
# Batch: 440/469
# Batch: 441/469
# Batch: 442/469
# Batch: 443/469
# Batch: 444/469
# Batch: 445/469
# Batch: 446/469
# Batch: 447/469
# Batch: 448/469
# Batch: 449/469
# Batch: 450/469
# Batch: 451/469
# Batch: 452/469
# Batch: 453/469
# Batch: 454/469
# Batch: 455/469
# Batch: 456/469
# Batch: 457/469
# Batch: 458/469
# Batch: 459/469
# Batch: 460/469
# Batch: 461/469
# Batch: 462/469
# Batch: 463/469
# Batch: 464/469
# Batch: 465/469
# Batch: 466/469
# Batch: 467/469
# Batch: 468/469
# Hessian_size:  torch.Size([89610])

# %%
def get_Jacobian(model, x):
    
    outputs = model(x)
    batch_size = outputs.shape[0]
    num_classes = outputs.shape[1]
    j_size = np.sum([p.numel() for p in model.parameters()])
    Jacobian = torch.zeros(batch_size, num_classes, j_size)
    
    for i in range(batch_size):
        for j in range(num_classes):
            #Variable(outputs[i,j], requires_grad=True).backward(retain_variables=True)
            outputs[i,j].backward(retain_graph=True)
            single_jacobian = []
            for k, p in enumerate(model.parameters()):
                g = p.grad.clone() # now contains the derivative of the o[i,j] w.r.t. weights
                single_jacobian.append(g)
            
            model.zero_grad()
                
            single_jacobian = torch.cat([el.view(-1) for el in single_jacobian])
            Jacobian[i,j] = single_jacobian
    
    return(Jacobian)

# %%
"""
for batch_idx, (x, y) in enumerate(mnist_train_loader):
    
    J = get_Jacobian(mnist_model, x)
    print("J size: ", J.size())
    batch_size = J.size(0)
    num_classes = J.size(1)
    cov = torch.zeros(batch_size, num_classes, num_classes)
    for i in range(batch_size):
        cov[i] = torch.mul(J[i], Hessian) @ J[i].T
    print(cov.size())
    #print(cov)
"""
# Out:
# '\nfor batch_idx, (x, y) in enumerate(mnist_train_loader):\n    \n    J = get_Jacobian(mnist_model, x)\n    print("J size: ", J.size())\n    batch_size = J.size(0)\n    num_classes = J.size(1)\n    cov = torch.zeros(batch_size, num_classes, num_classes)\n    for i in range(batch_size):\n        cov[i] = torch.mul(J[i], Hessian) @ J[i].T\n    print(cov.size())\n    #print(cov)\n'

# %%
print(Hessian)
# Out:
# tensor([0.0000, 0.0000, 0.0000,  ..., 0.0043, 0.0063, 0.0066])

# %%
def predict_Diagonal_full(model, test_loader, verbose=True, num_samples=100):
    
    py = []
    
    max_len = int(np.ceil(len(test_loader.dataset)/len(test_loader)))
    for batch_idx, (x, y) in enumerate(test_loader):
        
        J = get_Jacobian(model, x)
        batch_size = J.size(0)
        num_classes = J.size(1)
        Cov_pred = torch.zeros(batch_size, num_classes, num_classes)
        for i in range(batch_size):
            Cov_pred[i] = torch.mul(J[i], Hessian) @ J[i].T    #inverting the Hessian give worse results for some reason

        mu_pred = model(x)
        #print(Cov_pred)
        post_pred = MultivariateNormal(mu_pred, Cov_pred)

        # MC-integral
        py_ = 0

        for _ in range(num_samples):
            f_s = post_pred.rsample()
            py_ += torch.softmax(f_s, 1)


        py_ /= num_samples
        py_ = py_.detach()

        py.append(py_)

        if verbose:
            print("Batch: {}/{}".format(batch_idx, max_len))

    return torch.cat(py, dim=0)

# %%
BATCH_SIZE_TEST_FMNIST = 128
BATCH_SIZE_TRAIN_FMNIST = 32

# %%
FMNIST_dataset = torchvision.datasets.FashionMNIST(
        './fmnist', train=True, download=True,
        transform=MNIST_transform) #torchvision.transforms.ToTensor())

train_size = int(0.8 * len(FMNIST_dataset))
val_size = len(FMNIST_dataset) - train_size
FMNIST_train_dataset, FMNIST_val_dataset = torch.utils.data.random_split(FMNIST_dataset, [train_size, val_size])

FMNIST_train_loader = torch.utils.data.DataLoader(
    FMNIST_train_dataset,
    batch_size=BATCH_SIZE_TRAIN_FMNIST, shuffle=True)

FMNIST_val_loader = torch.utils.data.DataLoader(
    FMNIST_val_dataset,
    batch_size=BATCH_SIZE_TRAIN_FMNIST, shuffle=False)


FMNIST_test = torchvision.datasets.FashionMNIST(
        './fmnist', train=False, download=False,
        transform=MNIST_transform)   #torchvision.transforms.ToTensor())

FMNIST_test_loader = torch.utils.data.DataLoader(
    FMNIST_test,
    batch_size=BATCH_SIZE_TEST_FMNIST, shuffle=False)

# %%
KMNIST_test = torchvision.datasets.KMNIST(
        './kmnist', train=False, download=True,
        transform=MNIST_transform)

KMNIST_test_loader = torch.utils.data.DataLoader(
    KMNIST_test,
    batch_size=128, shuffle=False)

# %%
"""Load notMNIST"""

import os
import numpy as np
import torch
from PIL import Image
from torch.utils.data.dataset import Dataset
from matplotlib.pyplot import imread
from torch import Tensor

"""
Loads the train/test set. 
Every image in the dataset is 28x28 pixels and the labels are numbered from 0-9
for A-J respectively.
Set root to point to the Train/Test folders.
"""

# Creating a sub class of torch.utils.data.dataset.Dataset
class notMNIST(Dataset):

    # The init method is called when this class will be instantiated
    def __init__(self, root, transform):
        
        #super(notMNIST, self).__init__(root, transform=transform)

        self.transform = transform
        
        Images, Y = [], []
        folders = os.listdir(root)

        for folder in folders:
            folder_path = os.path.join(root, folder)
            for ims in os.listdir(folder_path):
                try:
                    img_path = os.path.join(folder_path, ims)
                    Images.append(np.array(imread(img_path)))
                    Y.append(ord(folder) - 65)  # Folders are A-J so labels will be 0-9
                except:
                    # Some images in the dataset are damaged
                    print("File {}/{} is broken".format(folder, ims))
        data = [(x, y) for x, y in zip(Images, Y)]
        self.data = data
        self.targets = torch.Tensor(Y)

    # The number of items in the dataset
    def __len__(self):
        return len(self.data)

    # The Dataloader is a generator that repeatedly calls the getitem method.
    # getitem is supposed to return (X, Y) for the specified index.
    def __getitem__(self, index):
        img = self.data[index][0]

        if self.transform is not None:
            img = self.transform(img)
            
        # Input for Conv2D should be Channels x Height x Width
        img_tensor = Tensor(img).view(1, 28, 28).float()
        label = self.data[index][1]
        return (img_tensor, label)

# %%
root = os.path.abspath('')

# Instantiating the notMNIST dataset class we created
notMNIST_test = notMNIST(root=os.path.join(root, 'notMNIST_small'),
                               transform=MNIST_transform)

# Creating a dataloader
not_mnist_test_loader = torch.utils.data.dataloader.DataLoader(
                            dataset=notMNIST_test,
                            batch_size=128,
                            shuffle=False)
# Out:
# File F/Q3Jvc3NvdmVyIEJvbGRPYmxpcXVlLnR0Zg==.png is broken
# File A/RGVtb2NyYXRpY2FCb2xkT2xkc3R5bGUgQm9sZC50dGY=.png is broken

# %%
def get_in_dist_values(py_in, targets):
    acc_in = np.mean(np.argmax(py_in, 1) == targets)
    prob_correct = np.choose(targets, py_in.T).mean()
    average_entropy = -np.sum(py_in*np.log(py_in+1e-8), axis=1).mean()
    MMC = py_in.max(1).mean()
    return(acc_in, prob_correct, average_entropy, MMC)
    
def get_out_dist_values(py_in, py_out, targets):
    average_entropy = -np.sum(py_out*np.log(py_out+1e-8), axis=1).mean()
    acc_out = np.mean(np.argmax(py_out, 1) == targets)
    prob_correct = np.choose(targets, py_out.T).mean()
    labels = np.zeros(len(py_in)+len(py_out), dtype='int32')
    labels[:len(py_in)] = 1
    examples = np.concatenate([py_in.max(1), py_out.max(1)])
    auroc = roc_auc_score(labels, examples)
    MMC = py_out.max(1).mean()
    return(acc_out, prob_correct, average_entropy, MMC, auroc)

def print_in_dist_values(acc_in, prob_correct, average_entropy, MMC, train='mnist', method='LLLA-KF'):
    
    print(f'[In, {method}, {train}] Accuracy: {acc_in:.3f}; average entropy: {average_entropy:.3f}; \
    MMC: {MMC:.3f}; Prob @ correct: {prob_correct:.3f}')


def print_out_dist_values(acc_out, prob_correct, average_entropy, MMC, auroc, train='mnist', test='FMNIST', method='LLLA-KF'):
   
    print(f'[Out-{test}, {method}, {train}] Accuracy: {acc_out:.3f}; Average entropy: {average_entropy:.3f};\
    MMC: {MMC:.3f}; AUROC: {auroc:.3f}; Prob @ correct: {prob_correct:.3f}')

# %% [markdown]
# # MAP estimate

# %%
targets = MNIST_test.targets.numpy()
targets_FMNIST = FMNIST_test.targets.numpy()
targets_notMNIST = notMNIST_test.targets.numpy().astype(int)
targets_KMNIST = KMNIST_test.targets.numpy()

# %%
mnist_test_in_MAP = predict_MAP(mnist_model, mnist_test_loader).numpy()
mnist_test_out_fmnist_MAP = predict_MAP(mnist_model, FMNIST_test_loader).numpy()
mnist_test_out_notMNIST_MAP = predict_MAP(mnist_model, not_mnist_test_loader).numpy()
mnist_test_out_KMNIST_MAP = predict_MAP(mnist_model, KMNIST_test_loader).numpy()

# %%
acc_in_MAP, prob_correct_in_MAP, ent_in_MAP, MMC_in_MAP = get_in_dist_values(mnist_test_in_MAP, targets)
acc_out_FMNIST_MAP, prob_correct_out_FMNIST_MAP, ent_out_FMNIST_MAP, MMC_out_FMNIST_MAP, auroc_out_FMNIST_MAP = get_out_dist_values(mnist_test_in_MAP, mnist_test_out_fmnist_MAP, targets_FMNIST)
acc_out_notMNIST_MAP, prob_correct_out_notMNIST_MAP, ent_out_notMNIST_MAP, MMC_out_notMNIST_MAP, auroc_out_notMNIST_MAP = get_out_dist_values(mnist_test_in_MAP, mnist_test_out_notMNIST_MAP, targets_notMNIST)
acc_out_KMNIST_MAP, prob_correct_out_KMNIST_MAP, ent_out_KMNIST_MAP, MMC_out_KMNIST_MAP, auroc_out_KMNIST_MAP = get_out_dist_values(mnist_test_in_MAP, mnist_test_out_KMNIST_MAP, targets_KMNIST)

# %%
print_in_dist_values(acc_in_MAP, prob_correct_in_MAP, ent_in_MAP, MMC_in_MAP, 'mnist', 'MAP')
print_out_dist_values(acc_out_FMNIST_MAP, prob_correct_out_FMNIST_MAP, ent_out_FMNIST_MAP, MMC_out_FMNIST_MAP, auroc_out_FMNIST_MAP, 'FMNIST', 'MAP')
print_out_dist_values(acc_out_notMNIST_MAP, prob_correct_out_notMNIST_MAP, ent_out_notMNIST_MAP, MMC_out_notMNIST_MAP, auroc_out_notMNIST_MAP, 'notMNIST', 'MAP')
print_out_dist_values(acc_out_KMNIST_MAP, prob_correct_out_KMNIST_MAP, ent_out_KMNIST_MAP, MMC_out_KMNIST_MAP, auroc_out_KMNIST_MAP, 'KMNIST', 'MAP')
# Out:
# [In, MAP, mnist] Accuracy: 0.971; average entropy: 0.105;     MMC: 0.968; Prob @ correct: 0.954
# [Out-MAP, LLLA-KF, FMNIST] Accuracy: 0.056; Average entropy: 0.506;    MMC: 0.824; AUROC: 0.832; Prob @ correct: 0.059
# [Out-MAP, LLLA-KF, notMNIST] Accuracy: 0.121; Average entropy: 0.548;    MMC: 0.799; AUROC: 0.849; Prob @ correct: 0.126
# [Out-MAP, LLLA-KF, KMNIST] Accuracy: 0.102; Average entropy: 0.750;    MMC: 0.728; AUROC: 0.908; Prob @ correct: 0.100

# %% [markdown]
# # Diag Hessian Sampling estimate

# %%
mnist_test_in_D = predict_Diagonal_full(mnist_model, mnist_test_loader, num_samples=100).numpy()
mnist_test_out_FMNIST_D = predict_Diagonal_full(mnist_model, FMNIST_test_loader, num_samples=100).numpy()
mnist_test_out_notMNIST_D = predict_Diagonal_full(mnist_model, not_mnist_test_loader, num_samples=100).numpy()
mnist_test_out_KMNIST_D = predict_Diagonal_full(mnist_model, KMNIST_test_loader, num_samples=100).numpy()
# Out:
# Batch: 0/127
# Batch: 1/127
# Batch: 2/127
# Batch: 3/127
# Batch: 4/127
# Batch: 5/127
# Batch: 6/127
# Batch: 7/127
# Batch: 8/127
# Batch: 9/127
# Batch: 10/127
# Batch: 11/127
# Batch: 12/127
# Batch: 13/127
# Batch: 14/127
# Batch: 15/127
# Batch: 16/127
# Batch: 17/127
# Batch: 18/127
# Batch: 19/127
# Batch: 20/127
# Batch: 21/127
# Batch: 22/127
# Batch: 23/127
# Batch: 24/127
# Batch: 25/127
# Batch: 26/127
# Batch: 27/127
# Batch: 28/127
# Batch: 29/127
# Batch: 30/127
# Batch: 31/127
# Batch: 32/127
# Batch: 33/127
# Batch: 34/127
# Batch: 35/127
# Batch: 36/127
# Batch: 37/127
# Batch: 38/127
# Batch: 39/127
# Batch: 40/127
# Batch: 41/127
# Batch: 42/127
# Batch: 43/127
# Batch: 44/127
# Batch: 45/127
# Batch: 46/127
# Batch: 47/127
# Batch: 48/127
# Batch: 49/127
# Batch: 50/127
# Batch: 51/127
# Batch: 52/127
# Batch: 53/127
# Batch: 54/127
# Batch: 55/127
# Batch: 56/127
# Batch: 57/127
# Batch: 58/127
# Batch: 59/127
# Batch: 60/127
# Batch: 61/127
# Batch: 62/127
# Batch: 63/127
# Batch: 64/127
# Batch: 65/127
# Batch: 66/127
# Batch: 67/127
# Batch: 68/127
# Batch: 69/127
# Batch: 70/127
# Batch: 71/127
# Batch: 72/127
# Batch: 73/127
# Batch: 74/127
# Batch: 75/127
# Batch: 76/127
# Batch: 77/127
# Batch: 78/127
# Batch: 0/127
# Batch: 1/127
# Batch: 2/127
# Batch: 3/127
# Batch: 4/127
# Batch: 5/127
# Batch: 6/127
# Batch: 7/127
# Batch: 8/127
# Batch: 9/127
# Batch: 10/127
# Batch: 11/127
# Batch: 12/127
# Batch: 13/127
# Batch: 14/127
# Batch: 15/127
# Batch: 16/127
# Batch: 17/127
# Batch: 18/127
# Batch: 19/127
# Batch: 20/127
# Batch: 21/127
# Batch: 22/127
# Batch: 23/127
# Batch: 24/127
# Batch: 25/127
# Batch: 26/127
# Batch: 27/127
# Batch: 28/127
# Batch: 29/127
# Batch: 30/127
# Batch: 31/127
# Batch: 32/127
# Batch: 33/127
# Batch: 34/127
# Batch: 35/127
# Batch: 36/127
# Batch: 37/127
# Batch: 38/127
# Batch: 39/127
# Batch: 40/127
# Batch: 41/127
# Batch: 42/127
# Batch: 43/127
# Batch: 44/127
# Batch: 45/127
# Batch: 46/127
# Batch: 47/127
# Batch: 48/127
# Batch: 49/127
# Batch: 50/127
# Batch: 51/127
# Batch: 52/127
# Batch: 53/127
# Batch: 54/127
# Batch: 55/127
# Batch: 56/127
# Batch: 57/127
# Batch: 58/127
# Batch: 59/127
# Batch: 60/127
# Batch: 61/127
# Batch: 62/127
# Batch: 63/127
# Batch: 64/127
# Batch: 65/127
# Batch: 66/127
# Batch: 67/127
# Batch: 68/127
# Batch: 69/127
# Batch: 70/127
# Batch: 71/127
# Batch: 72/127
# Batch: 73/127
# Batch: 74/127
# Batch: 75/127
# Batch: 76/127
# Batch: 77/127
# Batch: 78/127
# Batch: 0/128
# Batch: 1/128
# Batch: 2/128
# Batch: 3/128
# Batch: 4/128
# Batch: 5/128
# Batch: 6/128
# Batch: 7/128
# Batch: 8/128
# Batch: 9/128
# Batch: 10/128
# Batch: 11/128
# Batch: 12/128
# Batch: 13/128
# Batch: 14/128
# Batch: 15/128
# Batch: 16/128
# Batch: 17/128
# Batch: 18/128
# Batch: 19/128
# Batch: 20/128
# Batch: 21/128
# Batch: 22/128
# Batch: 23/128
# Batch: 24/128
# Batch: 25/128
# Batch: 26/128
# Batch: 27/128
# Batch: 28/128
# Batch: 29/128
# Batch: 30/128
# Batch: 31/128
# Batch: 32/128
# Batch: 33/128
# Batch: 34/128
# Batch: 35/128
# Batch: 36/128
# Batch: 37/128
# Batch: 38/128
# Batch: 39/128
# Batch: 40/128
# Batch: 41/128
# Batch: 42/128
# Batch: 43/128
# Batch: 44/128
# Batch: 45/128
# Batch: 46/128
# Batch: 47/128
# Batch: 48/128
# Batch: 49/128
# Batch: 50/128
# Batch: 51/128
# Batch: 52/128
# Batch: 53/128
# Batch: 54/128
# Batch: 55/128
# Batch: 56/128
# Batch: 57/128
# Batch: 58/128
# Batch: 59/128
# Batch: 60/128
# Batch: 61/128
# Batch: 62/128
# Batch: 63/128
# Batch: 64/128
# Batch: 65/128
# Batch: 66/128
# Batch: 67/128
# Batch: 68/128
# Batch: 69/128
# Batch: 70/128
# Batch: 71/128
# Batch: 72/128
# Batch: 73/128
# Batch: 74/128
# Batch: 75/128
# Batch: 76/128
# Batch: 77/128
# Batch: 78/128
# Batch: 79/128
# Batch: 80/128
# Batch: 81/128
# Batch: 82/128
# Batch: 83/128
# Batch: 84/128
# Batch: 85/128
# Batch: 86/128
# Batch: 87/128
# Batch: 88/128
# Batch: 89/128
# Batch: 90/128
# Batch: 91/128
# Batch: 92/128
# Batch: 93/128
# Batch: 94/128
# Batch: 95/128
# Batch: 96/128
# Batch: 97/128
# Batch: 98/128
# Batch: 99/128
# Batch: 100/128
# Batch: 101/128
# Batch: 102/128
# Batch: 103/128
# Batch: 104/128
# Batch: 105/128
# Batch: 106/128
# Batch: 107/128
# Batch: 108/128
# Batch: 109/128
# Batch: 110/128
# Batch: 111/128
# Batch: 112/128
# Batch: 113/128
# Batch: 114/128
# Batch: 115/128
# Batch: 116/128
# Batch: 117/128
# Batch: 118/128
# Batch: 119/128
# Batch: 120/128
# Batch: 121/128
# Batch: 122/128
# Batch: 123/128
# Batch: 124/128
# Batch: 125/128
# Batch: 126/128
# Batch: 127/128
# Batch: 128/128
# Batch: 129/128
# Batch: 130/128
# Batch: 131/128
# Batch: 132/128
# Batch: 133/128
# Batch: 134/128
# Batch: 135/128
# Batch: 136/128
# Batch: 137/128
# Batch: 138/128
# Batch: 139/128
# Batch: 140/128
# Batch: 141/128
# Batch: 142/128
# Batch: 143/128
# Batch: 144/128
# Batch: 145/128
# Batch: 146/128
# Batch: 0/127
# Batch: 1/127
# Batch: 2/127
# Batch: 3/127
# Batch: 4/127
# Batch: 5/127
# Batch: 6/127
# Batch: 7/127
# Batch: 8/127
# Batch: 9/127
# Batch: 10/127
# Batch: 11/127
# Batch: 12/127
# Batch: 13/127
# Batch: 14/127
# Batch: 15/127
# Batch: 16/127
# Batch: 17/127
# Batch: 18/127
# Batch: 19/127
# Batch: 20/127
# Batch: 21/127
# Batch: 22/127
# Batch: 23/127
# Batch: 24/127
# Batch: 25/127
# Batch: 26/127
# Batch: 27/127
# Batch: 28/127
# Batch: 29/127
# Batch: 30/127
# Batch: 31/127
# Batch: 32/127
# Batch: 33/127
# Batch: 34/127
# Batch: 35/127
# Batch: 36/127
# Batch: 37/127
# Batch: 38/127
# Batch: 39/127
# Batch: 40/127
# Batch: 41/127
# Batch: 42/127
# Batch: 43/127
# Batch: 44/127
# Batch: 45/127
# Batch: 46/127
# Batch: 47/127
# Batch: 48/127
# Batch: 49/127
# Batch: 50/127
# Batch: 51/127
# Batch: 52/127
# Batch: 53/127
# Batch: 54/127
# Batch: 55/127
# Batch: 56/127
# Batch: 57/127
# Batch: 58/127
# Batch: 59/127
# Batch: 60/127
# Batch: 61/127
# Batch: 62/127
# Batch: 63/127
# Batch: 64/127
# Batch: 65/127
# Batch: 66/127
# Batch: 67/127
# Batch: 68/127
# Batch: 69/127
# Batch: 70/127
# Batch: 71/127
# Batch: 72/127
# Batch: 73/127
# Batch: 74/127
# Batch: 75/127
# Batch: 76/127
# Batch: 77/127
# Batch: 78/127

# %%
acc_in_D, prob_correct_in_D, ent_in_D, MMC_in_D = get_in_dist_values(mnist_test_in_D, targets)
acc_out_FMNIST_D, prob_correct_out_FMNIST_D, ent_out_FMNIST_D, MMC_out_FMNIST_D, auroc_out_FMNIST_D = get_out_dist_values(mnist_test_in_D, mnist_test_out_FMNIST_D, targets_FMNIST)
acc_out_notMNIST_D, prob_correct_out_notMNIST_D, ent_out_notMNIST_D, MMC_out_notMNIST_D, auroc_out_notMNIST_D = get_out_dist_values(mnist_test_in_D, mnist_test_out_notMNIST_D, targets_notMNIST)
acc_out_KMNIST_D, prob_correct_out_KMNIST_D, ent_out_KMNIST_D, MMC_out_KMNIST_D, auroc_out_KMNIST_D = get_out_dist_values(mnist_test_in_D, mnist_test_out_KMNIST_D, targets_KMNIST)

# %%
print_in_dist_values(acc_in_D, prob_correct_in_D, ent_in_D, MMC_in_D, 'mnist', 'Diag')
print_out_dist_values(acc_out_FMNIST_D, prob_correct_out_FMNIST_D, ent_out_FMNIST_D, MMC_out_FMNIST_D, auroc_out_FMNIST_D, test='fmnist', method='Diag')
print_out_dist_values(acc_out_notMNIST_D, prob_correct_out_notMNIST_D, ent_out_notMNIST_D, MMC_out_notMNIST_D, auroc_out_notMNIST_D, test='notMNIST', method='Diag')
print_out_dist_values(acc_out_KMNIST_D, prob_correct_out_KMNIST_D, ent_out_KMNIST_D, MMC_out_KMNIST_D, auroc_out_KMNIST_D, test='KMNIST', method='Diag')
# Out:
# [In, Diag, mnist] Accuracy: 0.971; average entropy: 0.427;     MMC: 0.876; Prob @ correct: 0.867
# [Out-fmnist, Diag, mnist] Accuracy: 0.058; Average entropy: 1.042;    MMC: 0.625; AUROC: 0.876; Prob @ correct: 0.069
# [Out-notMNIST, Diag, mnist] Accuracy: 0.120; Average entropy: 1.028;    MMC: 0.617; AUROC: 0.881; Prob @ correct: 0.112
# [Out-KMNIST, Diag, mnist] Accuracy: 0.102; Average entropy: 1.145;    MMC: 0.572; AUROC: 0.904; Prob @ correct: 0.101
